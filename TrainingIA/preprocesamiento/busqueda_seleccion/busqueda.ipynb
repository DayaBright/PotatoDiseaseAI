# %% [markdown]
# Fuentes de kaggle

# %% [markdown]
# ## Dataset 1

# %% [markdown]
# https://www.kaggle.com/datasets/warcoder/potato-leaf-disease-dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("warcoder/potato-leaf-disease-dataset")

print("Path to dataset files:", path)

# %% [markdown]
# ## Dataset 2

# %% [markdown]
# https://data.mendeley.com/datasets/rgfhzd5mzw/1

# %% [markdown]
# ## Dataset 3

# %% [markdown]
# ## Dataset 4

# %% [markdown]
# ## Dataset 5

# %% [markdown]
# ## Dataset 6

# %% [markdown]
# ## Dataset 7
