# %% [markdown]
# # Entrenamiento — MobileNetV2 + TFLite
# Pipeline completo: tf.data en memoria → transfer learning → fine-tuning → exportación TFLite + GradCAM estático.
#
# **No escribe imágenes procesadas a disco.** Todo el preprocesamiento ocurre en el pipeline de tf.data durante el entrenamiento.

# %% [markdown]
# ## 1. Configuración

# %%
import os, random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from pathlib import Path
from PIL import Image, ImageOps, ImageEnhance
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

print('TensorFlow:', tf.__version__)
print('GPU disponible:', tf.config.list_physical_devices('GPU'))

# ---------------------------------------------------------
# CONFIGURACION - ajusta esta seccion
# ---------------------------------------------------------
DATASET_PATH   = Path('/kaggle/input/datasets/kevinvichicela/leaf-potato-disease')
OUTPUT_DIR     = Path('/kaggle/working')
IMG_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp', '.webp'}

IMG_SIZE       = 224
BATCH_SIZE     = 32
RANDOM_SEED    = 42
MEAN_SAMPLE_N  = 500

# Desbalance y oversampling (solo train)
OVERSAMPLE_ENABLED       = True
IMBALANCE_TRIGGER_RATIO  = 1.5   # activar oversampling si max/min supera este valor
OVERSAMPLE_TO_MAX_FRAC   = 0.80  # objetivo por clase minoritaria = 80% de la clase mayor
MAX_OVERSAMPLE_MULTIPLER = 3.0   # no duplicar mas de 3x una clase

# Hiperparametros fase 1 (base congelada)
LR_PHASE1      = 1e-3
EPOCHS_PHASE1  = 15

# Hiperparametros fase 2 (fine-tuning)
LR_PHASE2      = 1e-4
EPOCHS_PHASE2  = 20
UNFREEZE_FROM  = 100

# Pérdida para controlar desbalance
USE_FOCAL_LOSS = True
FOCAL_GAMMA    = 2.0
LABEL_SMOOTHING = 0.05

# Split
TRAIN_RATIO    = 0.70
VAL_RATIO      = 0.15
# TEST_RATIO   = 0.15 (implicito)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print('Configuracion cargada.')
# Out:
# 2026-03-31 21:44:20.725244: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774993460.748781   19403 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774993460.756485   19403 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774993460.775903   19403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774993460.775924   19403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774993460.775927   19403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774993460.775929   19403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow: 2.19.0
# GPU disponible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Configuración cargada.

# %% [markdown]
# ## 2. Inventario, split estratificado y diagnostico de desbalance

# %%
records = []
for class_dir in sorted(DATASET_PATH.iterdir()):
    if not class_dir.is_dir():
        continue
    for img_path in class_dir.iterdir():
        if img_path.suffix.lower() in IMG_EXTENSIONS:
            records.append({'class': class_dir.name, 'path': str(img_path)})

classes      = sorted(set(r['class'] for r in records))
class_to_idx = {c: i for i, c in enumerate(classes)}
idx_to_class = {i: c for c, i in class_to_idx.items()}
NUM_CLASSES  = len(classes)

paths  = [r['path'] for r in records]
labels = [r['class'] for r in records]

# Split estratificado en dos pasos
train_paths, temp_paths, train_labels, temp_labels = train_test_split(
    paths, labels, test_size=VAL_RATIO * 2,
    stratify=labels, random_state=RANDOM_SEED
)
val_paths, test_paths, val_labels, test_labels = train_test_split(
    temp_paths, temp_labels, test_size=0.5,
    stratify=temp_labels, random_state=RANDOM_SEED
)

print(f'Clases ({NUM_CLASSES}): {classes}')
print(f'Train: {len(train_paths)} | Val: {len(val_paths)} | Test: {len(test_paths)}')


def summarize_split(split_labels, split_name):
    counts = Counter(split_labels)
    vals = np.array([counts[c] for c in classes], dtype=np.int32)
    max_count = int(vals.max())
    min_count = int(vals.min())
    ratio = (max_count / min_count) if min_count > 0 else float('inf')
    print(f'[{split_name}] max={max_count} | min={min_count} | ratio max/min={ratio:.2f}')
    for c in classes:
        print(f'  - {c:<20} {counts[c]:>5}')
    return counts, ratio

print('\nDiagnostico de desbalance por split:')
train_count, train_imbalance_ratio = summarize_split(train_labels, 'Train')
_, _ = summarize_split(val_labels, 'Val')
_, _ = summarize_split(test_labels, 'Test')


def build_oversample_plan(counts):
    max_count = max(counts.values())
    target = int(max_count * OVERSAMPLE_TO_MAX_FRAC)
    plan = {}

    if (not OVERSAMPLE_ENABLED) or (train_imbalance_ratio <= IMBALANCE_TRIGGER_RATIO):
        return plan

    for cls in classes:
        n = counts[cls]
        if n >= target:
            continue
        capped_target = min(target, int(round(n * MAX_OVERSAMPLE_MULTIPLER)))
        if capped_target > n:
            plan[cls] = capped_target
    return plan

oversample_plan = build_oversample_plan(train_count)

print('\nPlan de oversampling (solo train):')
if oversample_plan:
    for cls in classes:
        if cls in oversample_plan:
            print(f'  - {cls}: {train_count[cls]} -> {oversample_plan[cls]}')
else:
    print('  No se aplicara oversampling (dataset suficientemente balanceado o desactivado).')
# Out:
# Clases (7): ['early_blight', 'healthy', 'late_blight', 'leafroll_virus', 'mosaic_virus', 'nematode', 'pest']
# Train: 6734 | Val: 1443 | Test: 1443

# %% [markdown]
# ## 3. Color medio del dataset (para padding)

# %%
sample_paths = random.sample(paths, min(MEAN_SAMPLE_N, len(paths)))
r_vals, g_vals, b_vals = [], [], []
for p in sample_paths:
    try:
        arr = np.array(Image.open(p).convert('RGB').resize((64, 64)))
        r_vals.append(arr[:,:,0].mean())
        g_vals.append(arr[:,:,1].mean())
        b_vals.append(arr[:,:,2].mean())
    except Exception:
        pass

MEAN_COLOR = (
    int(round(np.mean(r_vals))),
    int(round(np.mean(g_vals))),
    int(round(np.mean(b_vals)))
)
print(f'Color medio del dataset (RGB): {MEAN_COLOR}')
# Out:
# Color medio del dataset (RGB): (115, 127, 96)

# %% [markdown]
# ## 4. Funciones de preprocesamiento y augmentation

# %%
def letterbox_pil(img: Image.Image) -> Image.Image:
    """Padding con color medio → imagen cuadrada, sin deformar."""
    img  = img.convert('RGB')
    w, h = img.size
    side = max(w, h)
    pl   = (side - w) // 2
    pt   = (side - h) // 2
    img  = ImageOps.expand(img, border=(pl, pt, side-w-pl, side-h-pt), fill=MEAN_COLOR)
    return img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)

def augment_pil(img: Image.Image) -> Image.Image:
    """Augmentation estándar + efectos climáticos simples (solo para train)."""
    # Geométricas
    if random.random() < 0.5:
        img = ImageOps.mirror(img)
    if random.random() < 0.3:
        img = ImageOps.flip(img)
    img = img.rotate(random.uniform(-20, 20), fillcolor=MEAN_COLOR, expand=False)
    # Zoom
    zf  = random.uniform(0.85, 1.0)
    w, h = img.size
    nw, nh = int(w*zf), int(h*zf)
    l, t = (w-nw)//2, (h-nh)//2
    img = img.crop((l, t, l+nw, t+nh)).resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
    # Fotométricas
    img = ImageEnhance.Brightness(img).enhance(random.uniform(0.70, 1.30))
    img = ImageEnhance.Contrast(img).enhance(random.uniform(0.75, 1.25))
    img = ImageEnhance.Color(img).enhance(random.uniform(0.80, 1.20))
    # Efecto climático leve (niebla: blend con blanco)
    if random.random() < 0.15:
        fog = Image.new('RGB', img.size, (220, 220, 220))
        img = Image.blend(img, fog, alpha=random.uniform(0.05, 0.20))
    return img

def load_and_preprocess(path: str, label: int,
                         augment: bool = False) -> tuple:
    """Carga, letterbox, opcional augment, normalización MobileNetV2."""
    img = Image.open(path)
    img = letterbox_pil(img)
    if augment:
        img = augment_pil(img)
    arr = np.array(img, dtype=np.float32)
    # Normalización específica de MobileNetV2: [-1, 1]
    arr = tf.keras.applications.mobilenet_v2.preprocess_input(arr)
    return arr, label

print('Funciones de preprocesamiento listas.')
# Out:
# Funciones de preprocesamiento listas.

# %% [markdown]
# ## 5. Pipeline tf.data con augmentation en memoria

# %%
def build_augmented_train_lists():
    """
    Expande solo clases minoritarias segun oversample_plan.
    Duplica paths solo en train; el augment visual se aplica en cada epoch.
    """
    count = Counter(train_labels)
    aug_paths, aug_labels = list(train_paths), list(train_labels)

    if not oversample_plan:
        return aug_paths, aug_labels

    for cls in classes:
        target = oversample_plan.get(cls)
        if target is None:
            continue

        n = count[cls]
        needed = target - n
        if needed <= 0:
            continue

        cls_pool = [p for p, l in zip(train_paths, train_labels) if l == cls]
        extras = random.choices(cls_pool, k=needed)
        aug_paths.extend(extras)
        aug_labels.extend([cls] * needed)
        print(f'  {cls}: {n} -> {n + needed}')

    return aug_paths, aug_labels

print('Construyendo listas de train con oversampling + augmentation...')
aug_train_paths, aug_train_labels = build_augmented_train_lists()
aug_train_idx = [class_to_idx[l] for l in aug_train_labels]
val_idx       = [class_to_idx[l] for l in val_labels]
test_idx      = [class_to_idx[l] for l in test_labels]

# Shuffle antes de crear el dataset
combined = list(zip(aug_train_paths, aug_train_idx))
random.shuffle(combined)
aug_train_paths, aug_train_idx = zip(*combined)

print(f'Train original: {len(train_paths)}')
print(f'Train final (oversampling): {len(aug_train_paths)}')


def make_dataset(paths_list, labels_list, augment=False, cache=False):
    def load_fn(path, label):
        arr, lbl = tf.py_function(
            func=lambda p, l: load_and_preprocess(
                p.numpy().decode(), int(l.numpy()), augment),
            inp=[path, label],
            Tout=[tf.float32, tf.int32]
        )
        arr.set_shape([IMG_SIZE, IMG_SIZE, 3])
        lbl.set_shape([])
        return arr, lbl

    ds = tf.data.Dataset.from_tensor_slices(
        (list(paths_list), list(labels_list))
    )
    if augment:
        ds = ds.shuffle(buffer_size=2000, seed=RANDOM_SEED)
    ds = ds.map(load_fn, num_parallel_calls=tf.data.AUTOTUNE)
    if cache:
        ds = ds.cache()
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

# Oversampling y augmentation solo en train
train_ds = make_dataset(aug_train_paths, aug_train_idx, augment=True)
val_ds   = make_dataset(val_paths,  val_idx,  augment=False, cache=True)
test_ds  = make_dataset(test_paths, test_idx, augment=False, cache=True)

print('Datasets listos.')
print(f'Steps por epoch: {math.ceil(len(aug_train_paths) / BATCH_SIZE)}')
# Out:
# Construyendo listas de train con augmentation...
#   healthy: 853 → 1050
#   leafroll_virus: 396 → 1050
#   mosaic_virus: 463 → 1050
#   nematode: 564 → 1050
#   pest: 604 → 1050
# Train total (con aug): 9104
# I0000 00:00:1774993475.751784   19403 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Datasets listos.
# Steps por epoch: 285

# %% [markdown]
# ## 6. Construcción del modelo — MobileNetV2

# %%
def build_model(num_classes: int, trainable_base: bool = False):
    base = tf.keras.applications.MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights='imagenet'
    )
    base.trainable = trainable_base

    inputs  = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x       = base(inputs, training=False)
    x       = tf.keras.layers.GlobalAveragePooling2D()(x)
    x       = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model, base

model, base_model = build_model(NUM_CLASSES, trainable_base=False)
model.summary(line_length=80)
print(f'\nCapas en base: {len(base_model.layers)}')
print(f'Parámetros entrenables: {model.trainable_variables.__len__()}')
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224 (Functional) │ (None, 7, 7, 1280)       │     2,257,984 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 1280)             │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dropout (Dropout)                 │ (None, 1280)             │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 7)                │         8,967 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 2,266,951 (8.65 MB)
#  Trainable params: 8,967 (35.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Capas en base: 154
# Parámetros entrenables: 2

# %% [markdown]
# ## 7. Estrategia anti-desbalance: class_weight + focal loss

# %%
# class_weight sobre train original (sin duplicados de oversampling)
train_idx_orig = np.array([class_to_idx[l] for l in train_labels], dtype=np.int32)

weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=train_idx_orig
)
class_weight_dict = {i: float(w) for i, w in enumerate(weights)}

# alpha por clase para focal loss (normalizado)
alpha_vector = (weights / np.sum(weights)).astype(np.float32)

print('class_weight_dict:')
for i, cls in enumerate(classes):
    print(f'  {i} ({cls}): {weights[i]:.4f}')


def sparse_categorical_focal_loss(alpha, gamma=2.0, label_smoothing=0.0):
    alpha = tf.constant(alpha, dtype=tf.float32)

    def loss_fn(y_true, y_pred):
        y_true_int = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_true_oh = tf.one_hot(y_true_int, depth=NUM_CLASSES, dtype=tf.float32)

        if label_smoothing > 0.0:
            y_true_oh = y_true_oh * (1.0 - label_smoothing) + (label_smoothing / NUM_CLASSES)

        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        ce = -tf.reduce_sum(y_true_oh * tf.math.log(y_pred), axis=-1)
        p_t = tf.reduce_sum(y_true_oh * y_pred, axis=-1)
        focal_factor = tf.pow(1.0 - p_t, gamma)
        alpha_t = tf.reduce_sum(y_true_oh * alpha, axis=-1)

        return tf.reduce_mean(alpha_t * focal_factor * ce)

    return loss_fn

if USE_FOCAL_LOSS:
    training_loss = sparse_categorical_focal_loss(
        alpha=alpha_vector,
        gamma=FOCAL_GAMMA,
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: Focal loss (gamma={FOCAL_GAMMA}, label_smoothing={LABEL_SMOOTHING})')
else:
    training_loss = tf.keras.losses.SparseCategoricalCrossentropy(
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: SparseCategoricalCrossentropy (label_smoothing={LABEL_SMOOTHING})')
# Out:
# class_weight_dict:
#   0 (early_blight): 0.4609
#   1 (healthy): 1.1278
#   2 (late_blight): 0.5444
#   3 (leafroll_virus): 2.4293
#   4 (mosaic_virus): 2.0778
#   5 (nematode): 1.7057
#   6 (pest): 1.5927

# %% [markdown]
# ## 8. Fase 1 — Entrenamiento con base congelada
# Solo se entrenan las capas densas superiores. La base MobileNetV2 actúa como extractor de características fijo.

# %%
callbacks_phase1 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=5,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=3, min_lr=1e-6, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase1.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE1),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 1 ({EPOCHS_PHASE1} epocas max., base congelada)...')
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE1,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase1,
    verbose=1
)
# Out:
# Iniciando fase 1 (15 épocas máx., base congelada)...
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774993483.013741   19460 service.cc:152] XLA service 0x7ee4a01103d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774993483.013774   19460 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1774993485.175332   19460 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1774993490.993404   19460 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.5557 - loss: 1.3314
# Epoch 1: val_accuracy improved from -inf to 0.81150, saving model to /kaggle/working/best_phase1.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 147s 469ms/step - accuracy: 0.5562 - loss: 1.3296 - val_accuracy: 0.8115 - val_loss: 0.5445 - learning_rate: 0.0010
# Epoch 2/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8372 - loss: 0.4604
# Epoch 2: val_accuracy improved from 0.81150 to 0.86694, saving model to /kaggle/working/best_phase1.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 107s 376ms/step - accuracy: 0.8372 - loss: 0.4603 - val_accuracy: 0.8669 - val_loss: 0.4014 - learning_rate: 0.0010
# Epoch 3/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.8642 - loss: 0.3495
# Epoch 3: val_accuracy improved from 0.86694 to 0.87803, saving model to /kaggle/working/best_phase1.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 108s 378ms/step - accuracy: 0.8642 - loss: 0.3495 - val_accuracy: 0.8780 - val_loss: 0.3506 - learning_rate: 0.0010
# Epoch 4/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.8715 - loss: 0.3318
# Epoch 4: val_accuracy improved from 0.87803 to 0.88635, saving model to /kaggle/working/best_phase1.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 112s 394ms/step - accuracy: 0.8715 - loss: 0.3318 - val_accuracy: 0.8863 - val_loss: 0.3262 - learning_rate: 0.0010
# Epoch 5/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.8826 - loss: 0.3011
# Epoch 5: val_accuracy did not improve from 0.88635
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 106s 369ms/step - accuracy: 0.8826 - loss: 0.3011 - val_accuracy: 0.8808 - val_loss: 0.3395 - learning_rate: 0.0010
# Epoch 6/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8826 - loss: 0.2842
# Epoch 6: val_accuracy improved from 0.88635 to 0.89674, saving model to /kaggle/working/best_phase1.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 112s 391ms/step - accuracy: 0.8826 - loss: 0.2842 - val_accuracy: 0.8967 - val_loss: 0.2961 - learning_rate: 0.0010
# Epoch 7/15
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8893 - loss: 0.2752
# Epoch 7: val_accuracy did not improve from 0.89674
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 106s 370ms/step - accuracy: 0.8893 - loss: 0.2752 - val_accuracy: 0.8579 - val_loss: 0.4097 - learning_rate: 0.0010
# Epoch 8/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8955 - loss: 0.2690
# Epoch 8: val_accuracy did not improve from 0.89674
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 105s 369ms/step - accuracy: 0.8955 - loss: 0.2690 - val_accuracy: 0.8870 - val_loss: 0.3126 - learning_rate: 0.0010
# Epoch 9/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8953 - loss: 0.2652
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_accuracy did not improve from 0.89674
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 106s 372ms/step - accuracy: 0.8953 - loss: 0.2652 - val_accuracy: 0.8760 - val_loss: 0.3646 - learning_rate: 0.0010
# Epoch 10/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9025 - loss: 0.2505
# Epoch 10: val_accuracy improved from 0.89674 to 0.89744, saving model to /kaggle/working/best_phase1.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 106s 372ms/step - accuracy: 0.9025 - loss: 0.2505 - val_accuracy: 0.8974 - val_loss: 0.2850 - learning_rate: 5.0000e-04
# Epoch 11/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9000 - loss: 0.2424
# Epoch 11: val_accuracy did not improve from 0.89744
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 105s 367ms/step - accuracy: 0.9000 - loss: 0.2424 - val_accuracy: 0.8912 - val_loss: 0.3003 - learning_rate: 5.0000e-04
# Epoch 12/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.9021 - loss: 0.2383
# Epoch 12: val_accuracy did not improve from 0.89744
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 105s 370ms/step - accuracy: 0.9021 - loss: 0.2383 - val_accuracy: 0.8815 - val_loss: 0.3373 - learning_rate: 5.0000e-04
# Epoch 13/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.9004 - loss: 0.2437
# Epoch 13: val_accuracy improved from 0.89744 to 0.90367, saving model to /kaggle/working/best_phase1.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 143s 374ms/step - accuracy: 0.9005 - loss: 0.2437 - val_accuracy: 0.9037 - val_loss: 0.2640 - learning_rate: 5.0000e-04
# Epoch 14/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9061 - loss: 0.2368
# Epoch 14: val_accuracy did not improve from 0.90367
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 113s 394ms/step - accuracy: 0.9061 - loss: 0.2368 - val_accuracy: 0.8995 - val_loss: 0.2870 - learning_rate: 5.0000e-04
# Epoch 15/15
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.8977 - loss: 0.2580
# Epoch 15: val_accuracy did not improve from 0.90367
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 107s 376ms/step - accuracy: 0.8977 - loss: 0.2579 - val_accuracy: 0.9037 - val_loss: 0.2592 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 13.

# %% [markdown]
# ## 9. Fase 2 — Fine-tuning
# Se descongelan las últimas capas de la base (desde `UNFREEZE_FROM` en adelante) con learning rate reducido.

# %%
base_model.trainable = True
for layer in base_model.layers[:UNFREEZE_FROM]:
    layer.trainable = False

trainable_count = sum(1 for l in base_model.layers if l.trainable)
print(f'Capas descongeladas en base: {trainable_count} / {len(base_model.layers)}')

callbacks_phase2 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=7,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=3, min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase2.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE2),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 2 ({EPOCHS_PHASE2} epocas max., fine-tuning)...')
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE2,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase2,
    initial_epoch=len(history1.history['loss']),
    verbose=1
)
# Out:
# Capas descongeladas en base: 54 / 154
# Iniciando fase 2 (20 épocas máx., fine-tuning)...
# Epoch 16/20
# 2026-03-31 22:13:02.632671: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-31 22:13:02.829294: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 284/285 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8296 - loss: 0.5244
# 2026-03-31 22:14:56.009244: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-31 22:14:56.204866: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.8297 - loss: 0.5238
# Epoch 16: val_accuracy improved from -inf to 0.73458, saving model to /kaggle/working/best_phase2.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 144s 429ms/step - accuracy: 0.8299 - loss: 0.5232 - val_accuracy: 0.7346 - val_loss: 1.3723 - learning_rate: 1.0000e-04
# Epoch 17/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.9261 - loss: 0.1878
# Epoch 17: val_accuracy improved from 0.73458 to 0.84407, saving model to /kaggle/working/best_phase2.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 108s 379ms/step - accuracy: 0.9262 - loss: 0.1878 - val_accuracy: 0.8441 - val_loss: 0.8193 - learning_rate: 1.0000e-04
# Epoch 18/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9416 - loss: 0.1352
# Epoch 18: val_accuracy improved from 0.84407 to 0.91199, saving model to /kaggle/working/best_phase2.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 109s 381ms/step - accuracy: 0.9417 - loss: 0.1352 - val_accuracy: 0.9120 - val_loss: 0.4280 - learning_rate: 1.0000e-04
# Epoch 19/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9603 - loss: 0.0911
# Epoch 19: val_accuracy improved from 0.91199 to 0.92793, saving model to /kaggle/working/best_phase2.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 107s 376ms/step - accuracy: 0.9603 - loss: 0.0911 - val_accuracy: 0.9279 - val_loss: 0.3470 - learning_rate: 1.0000e-04
# Epoch 20/20
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9686 - loss: 0.0652
# Epoch 20: val_accuracy improved from 0.92793 to 0.93139, saving model to /kaggle/working/best_phase2.keras
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 107s 375ms/step - accuracy: 0.9685 - loss: 0.0652 - val_accuracy: 0.9314 - val_loss: 0.3312 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 10. Curvas de entrenamiento

# %%
def plot_history(h1, h2):
    acc  = h1.history['accuracy']  + h2.history['accuracy']
    val  = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    vloss= h1.history['val_loss'] + h2.history['val_loss']
    sep  = len(h1.history['accuracy'])  # época donde empieza fase 2

    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    for ax, train_m, val_m, title in zip(
        axes,
        [acc, loss], [val, vloss],
        ['Accuracy', 'Loss']
    ):
        ax.plot(train_m, label='Train', color='steelblue')
        ax.plot(val_m,   label='Val',   color='coral')
        ax.axvline(sep, color='gray', linestyle='--', linewidth=1, label='Fine-tuning')
        ax.set_title(title)
        ax.set_xlabel('Época')
        ax.legend(fontsize=8)
        ax.spines[['top','right']].set_visible(False)

    plt.suptitle('Curvas de entrenamiento — fase 1 + fase 2', fontsize=11)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'training_curves.png', dpi=150, bbox_inches='tight')
    plt.show()

plot_history(history1, history2)

# %% [markdown]
# ## 11. Evaluación en test — métricas completas

# %%
import pandas as pd
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

# Auditoria detallada por imagen para saber en cuales falla el modelo
records_eval = []
y_true, y_pred = [], []

for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    probs = model.predict(np.expand_dims(arr, 0), verbose=0)[0]

    pred_idx = int(np.argmax(probs))
    pred_label = idx_to_class[pred_idx]
    conf = float(probs[pred_idx])

    y_true.append(true_idx)
    y_pred.append(pred_idx)

    records_eval.append({
        'filename': Path(path).name,
        'path': path,
        'true_label': true_label,
        'pred_label': pred_label,
        'confidence': conf,
        'correct': pred_label == true_label,
    })

print('=' * 60)
print('REPORTE DE CLASIFICACION - TEST SET (KERAS FLOAT32)')
print('=' * 60)
print(classification_report(
    y_true,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0,
))

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(9, 7))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusion - test set (Keras float32)', fontsize=11)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# Tabla completa de predicciones y subset de errores
df_test_predictions = pd.DataFrame(records_eval)
df_test_errors = (
    df_test_predictions[~df_test_predictions['correct']]
    .sort_values('confidence', ascending=False)
    .reset_index(drop=True)
)

print('\nResumen de auditoria por imagen:')
print(f"  Total evaluadas: {len(df_test_predictions)}")
print(f"  Aciertos       : {int(df_test_predictions['correct'].sum())}")
print(f"  Errores        : {len(df_test_errors)}")

print('\nPrimeras 20 predicciones:')
display(df_test_predictions.head(20))

print('\nPrimeros 30 errores (si existen):')
display(df_test_errors.head(30))

pred_csv_path = OUTPUT_DIR / 'keras_test_predictions.csv'
err_csv_path = OUTPUT_DIR / 'keras_test_errors.csv'
df_test_predictions.to_csv(pred_csv_path, index=False, encoding='utf-8-sig')
df_test_errors.to_csv(err_csv_path, index=False, encoding='utf-8-sig')

print('\nCSV exportados:')
print(f'  - {pred_csv_path}')
print(f'  - {err_csv_path}')
# Out:
# ============================================================
# REPORTE DE CLASIFICACIÓN — TEST SET
# ============================================================
#                 precision    recall  f1-score   support
#
#   early_blight     0.9850    0.8792    0.9291       447
#        healthy     0.8273    0.9945    0.9032       183
#    late_blight     0.9590    0.9261    0.9423       379
# leafroll_virus     1.0000    1.0000    1.0000        85
#   mosaic_virus     0.8033    0.9899    0.8869        99
#       nematode     0.9675    0.9835    0.9754       121
#           pest     0.8516    0.8450    0.8482       129
#
#       accuracy                         0.9265      1443
#      macro avg     0.9134    0.9455    0.9264      1443
#   weighted avg     0.9332    0.9265    0.9272      1443

# %% [markdown]
# ## 12. Exportación a TFLite (int8)
# Cuantización post-entrenamiento. Reduce el modelo a ~14–25 MB para el APK.

# %%
# Dataset representativo para calibración int8 (100 imágenes de val)
def representative_dataset():
    count = 0
    for img_batch, _ in val_ds:
        for img in img_batch:
            yield [tf.expand_dims(img, 0)]
            count += 1
            if count >= 100:
                return

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.uint8

# Guardar el modelo base .tflite
tflite_model = converter.convert()
tflite_path = OUTPUT_DIR / 'potato_classifier.tflite'
tflite_path.write_bytes(tflite_model)

# Guardar las etiquetas aparte (ya que no se pueden incrustar directamente aquí)
labels_path = OUTPUT_DIR / 'labels.txt'
with open(labels_path, 'w') as f:
    f.write('\n'.join(classes))

size_mb = tflite_path.stat().st_size / 1_048_576
print(f'Modelo TFLite guardado: {tflite_path}')
print(f'Etiquetas guardadas en: {labels_path}')
print(f'Tamaño del modelo: {size_mb:.2f} MB')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpse01_hp8/assets
# INFO:tensorflow:Assets written to: /tmp/tmpse01_hp8/assets
# Saved artifact at '/tmp/tmpse01_hp8'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   139523494760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494763536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494762960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494762192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494763728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494764496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494764112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494763152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494765648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494765840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494762768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494762576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494766416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494768528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494768720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494767568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494766992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494765456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494769872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494770064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494769296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494766800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494768912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494767376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494768336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494769488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494771024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494770448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494770640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494770832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494769680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494771984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494771408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494771600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494772176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494772560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494771216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494771792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491316752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491316176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494767760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523494770256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491317520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491317712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491316944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491317328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491318288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491316368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491317904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491318096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491315792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491319248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491318672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491318864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491319056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491316560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491320208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491319632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491319824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491320016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491317136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491321168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491320592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491320784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491320976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491318480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491322128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491321552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491321744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491321936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491319440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491323088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491322512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491322704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491322896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491320400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491324048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491323472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491323664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491323856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491321360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491325008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491324432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491324624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491324816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491322320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491325968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491325392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491325584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491325776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491323280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491326928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491326352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491326544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491326736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491324240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491327888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491327312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491327504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491327696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491325200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491328848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491328272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491328464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491328656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491326160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491329808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491329232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491329424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491329616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491327120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491330768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491330192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491330384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491330576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491328080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491331728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491331152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491330000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491331536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491331344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491330960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491329040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492004304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492005456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523491331920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492004880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492005264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492003920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492004112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492004496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492006416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492005840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492006032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492006224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492005072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492007376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492006800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492006992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492007184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492004688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492008336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492007760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492007952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492008144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492005648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492009296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492008720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492008912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492009104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492006608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492010256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492009680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492009872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492010064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492007568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492011216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492010640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492010832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492011024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492008528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492012176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492011600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492011984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492009488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492013136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492012752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492012944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492010448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492014096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492013520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492013712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492013904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492011408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492015056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492014480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492014672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492014864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492012368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492016016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492015440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492015632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492015824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492013328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492016976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492016400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492016592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492016784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492014288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492017936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492017360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492017552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492017744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492015248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492018896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492018320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492018512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492018704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492016208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492019280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492018128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492019664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492019472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492019088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492017168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490857424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490858576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523492020048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490858000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490858384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490857040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490857232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490857616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490859536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490858960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490859152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490859344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490858192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490860496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490859920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490860112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490860304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490857808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490861456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490860880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490861072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490861264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490858768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490862416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490861840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490862032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490862224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490859728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490863376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490862800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490862992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490863184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490860688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490864336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490863760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490863952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490864144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490861648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490865296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490864720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490864912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490865104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490862608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490866256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490865680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490865872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490866064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490863568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490867216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490864528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139523490866832: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1774995774.954988   19403 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1774995774.955017   19403 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1774995775.096324   19403 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Modelo TFLite guardado: /kaggle/working/potato_classifier.tflite
# Tamaño: 2.59 MB
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %% [markdown]
# ## 12.1 Evaluación del modelo TFLite cuantificado (int8)
# Comparación directa con el modelo Keras para medir el impacto real de la cuantización en precisión.

# %%
import pandas as pd
from sklearn.metrics import accuracy_score

# Cargar el modelo TFLite exportado
interpreter = tf.lite.Interpreter(model_path=str(tflite_path))
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

in_scale, in_zero_point = input_details['quantization']
out_scale, out_zero_point = output_details['quantization']

print('Entrada TFLite:', input_details['dtype'], input_details['shape'], input_details['quantization'])
print('Salida TFLite :', output_details['dtype'], output_details['shape'], output_details['quantization'])


def run_tflite_int8_single(img_float_m1_1):
    """
    img_float_m1_1: np.ndarray [H,W,3] normalizada en [-1, 1]
    Retorna probs float32 des-cuantizadas.
    """
    x = np.expand_dims(img_float_m1_1, axis=0).astype(np.float32)

    # Cuantizar entrada float -> uint8 usando parametros del tensor de entrada
    if in_scale > 0:
        x_q = np.round(x / in_scale + in_zero_point)
    else:
        x_q = x
    x_q = np.clip(x_q, 0, 255).astype(np.uint8)

    interpreter.set_tensor(input_details['index'], x_q)
    interpreter.invoke()
    y_q = interpreter.get_tensor(output_details['index'])

    # Des-cuantizar salida uint8 -> float
    if out_scale > 0:
        y = (y_q.astype(np.float32) - out_zero_point) * out_scale
    else:
        y = y_q.astype(np.float32)

    return y[0]


# Evaluacion del TFLite en el mismo test set
y_true_tflite, y_pred_tflite = [], []
records_tflite = []

for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    probs = run_tflite_int8_single(arr)
    pred_idx = int(np.argmax(probs))
    pred_label = idx_to_class[pred_idx]
    conf = float(probs[pred_idx])

    y_true_tflite.append(true_idx)
    y_pred_tflite.append(pred_idx)

    records_tflite.append({
        'filename': Path(path).name,
        'path': path,
        'true_label': true_label,
        'pred_label': pred_label,
        'confidence': conf,
        'correct': pred_label == true_label,
    })

acc_tflite = accuracy_score(y_true_tflite, y_pred_tflite)

# Accuracy Keras float ya calculada antes (si no existe, la recalculamos rapido)
if 'y_true' in globals() and 'y_pred' in globals() and len(y_true) == len(y_pred):
    acc_keras = accuracy_score(y_true, y_pred)
else:
    y_true_keras, y_pred_keras = [], []
    for batch_imgs, batch_labels in test_ds:
        preds = model.predict(batch_imgs, verbose=0)
        y_pred_keras.extend(np.argmax(preds, axis=1))
        y_true_keras.extend(batch_labels.numpy())
    acc_keras = accuracy_score(y_true_keras, y_pred_keras)

print('\n' + '=' * 65)
print('COMPARACION DE ACCURACY EN TEST')
print('=' * 65)
print(f'Keras (float32): {acc_keras:.4f}')
print(f'TFLite (int8) : {acc_tflite:.4f}')
print(f'Delta (int8 - float): {acc_tflite - acc_keras:+.4f}')
print('=' * 65)

# Tabla de errores del TFLite
_df_tfl = pd.DataFrame(records_tflite)
_df_tfl_errors = (
    _df_tfl[~_df_tfl['correct']]
    .sort_values('confidence', ascending=False)
    .reset_index(drop=True)
)

print('\nPrimeros 30 errores TFLite (si existen):')
display(_df_tfl_errors.head(30))

# %% [markdown]
# ## 12.2 Reporte completo TFLite para tesis
# Incluye accuracy, precision, recall, F1 (por clase y promedios), matriz de confusión y exportación de tablas/figuras para documentación.

# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# -----------------------------
# 1) Reporte de clasificacion
# -----------------------------
report_dict = classification_report(
    y_true_tflite,
    y_pred_tflite,
    target_names=classes,
    digits=4,
    output_dict=True,
    zero_division=0
)

# Tabla por clase
rows = []
for cls in classes:
    rows.append({
        'clase': cls,
        'precision': report_dict[cls]['precision'],
        'recall': report_dict[cls]['recall'],
        'f1-score': report_dict[cls]['f1-score'],
        'support': int(report_dict[cls]['support'])
    })

df_cls = pd.DataFrame(rows)

# Tabla de resumen
df_summary = pd.DataFrame([
    {
        'metrica': 'accuracy',
        'valor': float(report_dict['accuracy'])
    },
    {
        'metrica': 'macro avg precision',
        'valor': float(report_dict['macro avg']['precision'])
    },
    {
        'metrica': 'macro avg recall',
        'valor': float(report_dict['macro avg']['recall'])
    },
    {
        'metrica': 'macro avg f1-score',
        'valor': float(report_dict['macro avg']['f1-score'])
    },
    {
        'metrica': 'weighted avg precision',
        'valor': float(report_dict['weighted avg']['precision'])
    },
    {
        'metrica': 'weighted avg recall',
        'valor': float(report_dict['weighted avg']['recall'])
    },
    {
        'metrica': 'weighted avg f1-score',
        'valor': float(report_dict['weighted avg']['f1-score'])
    }
])

print('=' * 70)
print('REPORTE TFLITE (INT8) - LISTO PARA TESIS')
print('=' * 70)
print('\nMetricas globales:')
display(df_summary)
print('\nMetricas por clase:')
display(df_cls)

# -----------------------------
# 2) Matriz de confusion
# -----------------------------
cm_tflite = confusion_matrix(y_true_tflite, y_pred_tflite)

fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_tflite, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusion - Modelo TFLite int8 (Test)', fontsize=12)
plt.tight_layout()

cm_img_path = OUTPUT_DIR / 'confusion_matrix_tflite.png'
plt.savefig(cm_img_path, dpi=160, bbox_inches='tight')
plt.show()

# -----------------------------
# 3) Guardar tablas para tesis
# -----------------------------
cls_csv_path = OUTPUT_DIR / 'tflite_report_per_class.csv'
sum_csv_path = OUTPUT_DIR / 'tflite_report_summary.csv'

# Redondeo para reporte
df_cls_out = df_cls.copy()
df_cls_out[['precision', 'recall', 'f1-score']] = df_cls_out[['precision', 'recall', 'f1-score']].round(4)
df_summary_out = df_summary.copy()
df_summary_out['valor'] = df_summary_out['valor'].round(4)

df_cls_out.to_csv(cls_csv_path, index=False, encoding='utf-8-sig')
df_summary_out.to_csv(sum_csv_path, index=False, encoding='utf-8-sig')

print('\nArchivos exportados:')
print(f'  - {cls_csv_path}')
print(f'  - {sum_csv_path}')
print(f'  - {cm_img_path}')

# %% [markdown]
# ## 13. Generación de Grad-CAM estáticos por clase
# Se calcula el mapa de activación de la última capa conv de MobileNetV2 para una imagen
# representativa de cada clase. Estos mapas se empaquetan en el APK como recursos estáticos —
# latencia extra en inferencia: 0 ms.

# %%
import matplotlib as mpl
import numpy as np
import matplotlib as mpl
from PIL import Image

last_conv_layer = None
for layer in reversed(base_model.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_layer = layer
        break

if last_conv_layer is None:
    raise ValueError("No se encontró ninguna capa Conv2D en base_model")

print("Usando capa:", last_conv_layer.name)
print("Output shape:", last_conv_layer.output.shape)

# Submodelo interno: base_model.input → (base_model.output, conv_outputs)
# Evita el problema de Graph disconnected al no cruzar el límite base→model
base_grad_model = tf.keras.Model(
    inputs=base_model.inputs,
    outputs=[base_model.output, last_conv_layer.output]
)

# Capas superiores del modelo principal (fuera de la base)
gap_layer     = model.get_layer('global_average_pooling2d')
dropout_layer = model.get_layer('dropout')
dense_layer   = model.get_layer('dense')

# Verificación
print("\nVerificación base_grad_model:")
print("  Input shape :", base_grad_model.input_shape)
print("  Output[0]   :", base_grad_model.output[0].shape, "← base output")
print("  Output[1]   :", base_grad_model.output[1].shape, "← conv activations")


def compute_gradcam(img_array: np.ndarray, class_idx: int) -> np.ndarray:
    """Retorna heatmap normalizado [0,1] del tamaño IMG_SIZE×IMG_SIZE."""
    img_tensor = tf.cast(tf.expand_dims(img_array, 0), tf.float32)

    with tf.GradientTape() as tape:
        base_out, conv_outputs = base_grad_model(img_tensor, training=False)
        tape.watch(conv_outputs)
        # Reconstruir el forward pass de las capas superiores
        x      = gap_layer(base_out)
        x      = dropout_layer(x, training=False)
        preds  = dense_layer(x)
        class_score = preds[:, class_idx]

    grads = tape.gradient(class_score, conv_outputs)

    if grads is None:
        raise ValueError(
            f"Gradientes None para clase {class_idx}. "
            "Verificar conexión de base_grad_model."
        )

    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs[0]), axis=-1)
    cam = tf.maximum(cam, 0)
    cam_np = cam.numpy()
    cam_max = np.max(cam_np)
    cam_min = np.min(cam_np)

    
    if (cam_max - cam_min) > 1e-8:
      
        cam_np = (cam_np - cam_min) / (cam_max - cam_min)
    else:
        
        cam_np = np.zeros_like(cam_np)

    cam_img = Image.fromarray((cam_np * 255).astype(np.uint8))
    cam_img = cam_img.resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR)
    
    return np.array(cam_img) / 255.0


def overlay_heatmap(original_arr: np.ndarray,
                    heatmap: np.ndarray,
                    color_alpha: float = 0.6) -> np.ndarray: # CAMBIADO DE alpha A color_alpha
    """Superpone el heatmap coloreado (jet) sobre la imagen original."""

    orig_uint8 = ((original_arr + 1.0) * 127.5).astype(np.uint8)
    orig_img = Image.fromarray(orig_uint8).convert("RGBA")
    
    colormap = mpl.colormaps['jet']
    heatmap_rgb = (colormap(heatmap)[:, :, :3] * 255).astype(np.uint8)
    
    dynamic_alpha = np.power(heatmap, 1.5) 
    
    dynamic_alpha = dynamic_alpha * color_alpha
    
    alpha_mask_uint8 = (dynamic_alpha * 255).astype(np.uint8)
    
    rgba_heatmap_np = np.dstack((heatmap_rgb, alpha_mask_uint8))
    heatmap_img = Image.fromarray(rgba_heatmap_np, "RGBA")
    
    blended_img = Image.alpha_composite(orig_img, heatmap_img)
    
    return np.array(blended_img.convert("RGB"))

print('\nFunciones Grad-CAM listas.')
# Out:
# Usando capa: Conv_1
# Output shape: (None, 7, 7, 1280)
#
# Verificación base_grad_model:
#   Input shape : (None, 224, 224, 3)
#   Output[0]   : (None, 7, 7, 1280) ← base output
#   Output[1]   : (None, 7, 7, 1280) ← conv activations
#
# Funciones Grad-CAM listas.

# %%
# Buscar las TOP 10 imágenes de test con mayor confianza por clase
TOP_N = 5
gradcam_dir = OUTPUT_DIR / 'gradcam_static'
gradcam_dir.mkdir(exist_ok=True)

# Ahora guardamos una lista de resultados por clase, no solo uno
top_per_class = {i: [] for i in range(NUM_CLASSES)}

print("Analizando imágenes y recolectando candidatos...")
for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _   = load_and_preprocess(path, true_idx, augment=False)
    preds    = model.predict(np.expand_dims(arr, 0), verbose=0)[0]
    pred_idx = np.argmax(preds)
    conf     = float(preds[pred_idx])
    
    # Solo candidatos correctamente clasificados y evitando la saturación del 1.0 absoluto
    if pred_idx == true_idx and conf < 0.99:
        top_per_class[true_idx].append({'conf': conf, 'path': path, 'arr': arr})

# Generar y guardar los Grad-CAM en la carpeta
print(f"\nGenerando y guardando las mejores {TOP_N} imágenes por clase...")
for cls_idx, cls_name in enumerate(classes):
    
    # Ordenamos todas las imágenes de esta clase de mayor a menor confianza
    # y nos quedamos solo con la cantidad definida en TOP_N
    candidates = sorted(top_per_class[cls_idx], key=lambda x: x['conf'], reverse=True)[:TOP_N]
    
    if not candidates:
        print(f'  AVISO: no se encontraron imágenes para {cls_name}')
        continue
        
    print(f"  -> Guardando {len(candidates)} opciones para {cls_name}...")
    
    for rank, info in enumerate(candidates):
        arr     = info['arr']
        heatmap = compute_gradcam(arr, cls_idx)
        overlay = overlay_heatmap(arr, heatmap)

        # Guardar directamente la imagen procesada con un nombre descriptivo
        # Ejemplo: gradcam_late_blight_top1_conf0.985.jpg
        filename = f'gradcam_{cls_name}_top{rank+1}_conf{info["conf"]:.3f}.jpg'
        out_path = gradcam_dir / filename
        Image.fromarray(overlay).save(str(out_path), quality=90)

print(f'\n¡Proceso terminado!')
print(f'Ve al panel derecho de Kaggle, entra a la carpeta: {gradcam_dir}')
print('Ahí tendrás todas las imágenes listas para descargar y elegir la mejor.')
# Out:
# Analizando imágenes y recolectando candidatos...
#
# Generando y guardando las mejores 10 imágenes por clase...
#   -> Guardando 10 opciones para early_blight...
#   -> Guardando 8 opciones para healthy...
#   -> Guardando 10 opciones para late_blight...
#   -> Guardando 2 opciones para leafroll_virus...
#   -> Guardando 1 opciones para mosaic_virus...
#   -> Guardando 10 opciones para nematode...
#   -> Guardando 10 opciones para pest...
#
# ¡Proceso terminado!
# Ve al panel derecho de Kaggle, entra a la carpeta: /kaggle/working/gradcam_static
# Ahí tendrás todas las imágenes listas para descargar y elegir la mejor.

# %% [markdown]
# ## 14. Resumen de archivos generados

# %%
print('=' * 55)
print('ARCHIVOS GENERADOS')
print('=' * 55)

outputs = [
    OUTPUT_DIR / 'potato_classifier.tflite',
    OUTPUT_DIR / 'best_phase2.keras',
    OUTPUT_DIR / 'training_curves.png',
    OUTPUT_DIR / 'confusion_matrix.png',
    OUTPUT_DIR / 'confusion_matrix_tflite.png',
    OUTPUT_DIR / 'keras_test_predictions.csv',
    OUTPUT_DIR / 'keras_test_errors.csv',
    OUTPUT_DIR / 'tflite_report_per_class.csv',
    OUTPUT_DIR / 'tflite_report_summary.csv',
    OUTPUT_DIR / 'gradcam_all_classes.png',
]
outputs += list(gradcam_dir.glob('*.jpg'))

for f in outputs:
    if Path(f).exists():
        size = Path(f).stat().st_size / 1024
        print(f'  {Path(f).name:<40} {size:>8.1f} KB')
    else:
        print(f'  {Path(f).name:<40}  NO ENCONTRADO')

print('=' * 55)
print()
print('Para Android necesitas:')
print('  1. potato_classifier.tflite  -> /assets/ en el proyecto Android')
print('  2. gradcam_*.jpg             -> /res/drawable/ en el proyecto Android')
print()
print('Reportes para tesis:')
print('  1. tflite_report_per_class.csv')
print('  2. tflite_report_summary.csv')
print('  3. confusion_matrix_tflite.png')
print('  4. keras_test_predictions.csv')
print('  5. keras_test_errors.csv')
print()
print('class_to_idx (para el clasificador en Kotlin):')
for cls, idx in class_to_idx.items():
    print(f'  {idx}: "{cls}"')
# Out:
# =======================================================
# ARCHIVOS GENERADOS
# =======================================================
#   potato_classifier.tflite                   2654.9 KB
#   best_phase2.keras                         24080.4 KB
#   training_curves.png                          92.8 KB
#   confusion_matrix.png                         85.7 KB
#   gradcam_all_classes.png                    1941.5 KB
#   gradcam_healthy.jpg                          11.5 KB
#   gradcam_nematode.jpg                          8.6 KB
#   gradcam_late_blight.jpg                       8.3 KB
#   gradcam_pest.jpg                             10.6 KB
#   gradcam_early_blight.jpg                     14.4 KB
#   gradcam_leafroll_virus.jpg                    4.3 KB
#   gradcam_mosaic_virus.jpg                      8.4 KB
# =======================================================
#
# Para Android necesitas:
#   1. potato_classifier.tflite  → /assets/ en el proyecto Android
#   2. gradcam_*.jpg             → /res/drawable/ en el proyecto Android
#
# class_to_idx (para el clasificador en Kotlin):
#   0: "early_blight"
#   1: "healthy"
#   2: "late_blight"
#   3: "leafroll_virus"
#   4: "mosaic_virus"
#   5: "nematode"
#   6: "pest"
