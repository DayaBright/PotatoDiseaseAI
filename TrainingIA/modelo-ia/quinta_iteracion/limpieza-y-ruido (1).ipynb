# %% [markdown]
# # Entrenamiento — MobileNetV2 + TFLite
# Pipeline completo: tf.data en memoria → transfer learning → fine-tuning → exportación TFLite + GradCAM estático.
#
# **No escribe imágenes procesadas a disco.** Todo el preprocesamiento ocurre en el pipeline de tf.data durante el entrenamiento.

# %% [markdown]
# ## 1. Configuración

# %%
import os, random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from pathlib import Path
from PIL import Image, ImageOps, ImageEnhance
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

print('TensorFlow:', tf.__version__)
print('GPU disponible:', tf.config.list_physical_devices('GPU'))

# ---------------------------------------------------------
# CONFIGURACION - ajusta esta seccion
# ---------------------------------------------------------
DATASET_PATH   = Path('/kaggle/input/datasets/kevinvichicela/potato-3')
OUTPUT_DIR     = Path('/kaggle/working')
IMG_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp', '.webp'}

IMG_SIZE       = 224
BATCH_SIZE     = 32
RANDOM_SEED    = 42
MEAN_SAMPLE_N  = 500

# Desbalance y oversampling (solo train)
OVERSAMPLE_ENABLED       = True
IMBALANCE_TRIGGER_RATIO  = 1.5   # activar oversampling si max/min supera este valor
OVERSAMPLE_TO_MAX_FRAC   = 0.80  # objetivo por clase minoritaria = 80% de la clase mayor
MAX_OVERSAMPLE_MULTIPLER = 3.0   # no duplicar mas de 3x una clase

# Hiperparametros fase 1 (base congelada)
LR_PHASE1      = 1e-3
EPOCHS_PHASE1  = 15

# Hiperparametros fase 2 (fine-tuning)
LR_PHASE2      = 1e-4
EPOCHS_PHASE2  = 20
UNFREEZE_FROM  = 100

# Pérdida para controlar desbalance
USE_FOCAL_LOSS = True
FOCAL_GAMMA    = 2.0
LABEL_SMOOTHING = 0.05

# Split
TRAIN_RATIO    = 0.70
VAL_RATIO      = 0.15
# TEST_RATIO   = 0.15 (implicito)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print('Configuracion cargada.')
# Out:
# TensorFlow: 2.19.0
# GPU disponible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Configuracion cargada.

# %% [markdown]
# ## 2. Inventario, split estratificado y diagnostico de desbalance

# %%
records = []
for class_dir in sorted(DATASET_PATH.iterdir()):
    if not class_dir.is_dir():
        continue
    for img_path in class_dir.iterdir():
        if img_path.suffix.lower() in IMG_EXTENSIONS:
            records.append({'class': class_dir.name, 'path': str(img_path)})

classes      = sorted(set(r['class'] for r in records))
class_to_idx = {c: i for i, c in enumerate(classes)}
idx_to_class = {i: c for c, i in class_to_idx.items()}
NUM_CLASSES  = len(classes)

paths  = [r['path'] for r in records]
labels = [r['class'] for r in records]

# Split estratificado en dos pasos
train_paths, temp_paths, train_labels, temp_labels = train_test_split(
    paths, labels, test_size=VAL_RATIO * 2,
    stratify=labels, random_state=RANDOM_SEED
)
val_paths, test_paths, val_labels, test_labels = train_test_split(
    temp_paths, temp_labels, test_size=0.5,
    stratify=temp_labels, random_state=RANDOM_SEED
)

print(f'Clases ({NUM_CLASSES}): {classes}')
print(f'Train: {len(train_paths)} | Val: {len(val_paths)} | Test: {len(test_paths)}')


def summarize_split(split_labels, split_name):
    counts = Counter(split_labels)
    vals = np.array([counts[c] for c in classes], dtype=np.int32)
    max_count = int(vals.max())
    min_count = int(vals.min())
    ratio = (max_count / min_count) if min_count > 0 else float('inf')
    print(f'[{split_name}] max={max_count} | min={min_count} | ratio max/min={ratio:.2f}')
    for c in classes:
        print(f'  - {c:<20} {counts[c]:>5}')
    return counts, ratio

print('\nDiagnostico de desbalance por split:')
train_count, train_imbalance_ratio = summarize_split(train_labels, 'Train')
_, _ = summarize_split(val_labels, 'Val')
_, _ = summarize_split(test_labels, 'Test')


def build_oversample_plan(counts):
    max_count = max(counts.values())
    target = int(max_count * OVERSAMPLE_TO_MAX_FRAC)
    plan = {}

    if (not OVERSAMPLE_ENABLED) or (train_imbalance_ratio <= IMBALANCE_TRIGGER_RATIO):
        return plan

    for cls in classes:
        n = counts[cls]
        if n >= target:
            continue
        capped_target = min(target, int(round(n * MAX_OVERSAMPLE_MULTIPLER)))
        if capped_target > n:
            plan[cls] = capped_target
    return plan

oversample_plan = build_oversample_plan(train_count)

print('\nPlan de oversampling (solo train):')
if oversample_plan:
    for cls in classes:
        if cls in oversample_plan:
            print(f'  - {cls}: {train_count[cls]} -> {oversample_plan[cls]}')
else:
    print('  No se aplicara oversampling (dataset suficientemente balanceado o desactivado).')
# Out:
# Clases (8): ['early_blight', 'healthy', 'late_blight', 'leafroll_virus', 'mosaic_virus', 'nematode', 'pest', 'z_no_potato']
# Train: 6923 | Val: 1483 | Test: 1484
#
# Diagnostico de desbalance por split:
# [Train] max=2078 | min=298 | ratio max/min=6.97
#   - early_blight          2078
#   - healthy                636
#   - late_blight           1527
#   - leafroll_virus         421
#   - mosaic_virus           463
#   - nematode               298
#   - pest                   519
#   - z_no_potato            981
# [Val] max=445 | min=64 | ratio max/min=6.95
#   - early_blight           445
#   - healthy                136
#   - late_blight            327
#   - leafroll_virus          91
#   - mosaic_virus            99
#   - nematode                64
#   - pest                   111
#   - z_no_potato            210
# [Test] max=446 | min=64 | ratio max/min=6.97
#   - early_blight           446
#   - healthy                136
#   - late_blight            327
#   - leafroll_virus          90
#   - mosaic_virus            99
#   - nematode                64
#   - pest                   111
#   - z_no_potato            211
#
# Plan de oversampling (solo train):
#   - healthy: 636 -> 1662
#   - late_blight: 1527 -> 1662
#   - leafroll_virus: 421 -> 1263
#   - mosaic_virus: 463 -> 1389
#   - nematode: 298 -> 894
#   - pest: 519 -> 1557
#   - z_no_potato: 981 -> 1662

# %% [markdown]
# ## 3. Color medio del dataset (para padding)

# %%
sample_paths = random.sample(paths, min(MEAN_SAMPLE_N, len(paths)))
r_vals, g_vals, b_vals = [], [], []
for p in sample_paths:
    try:
        arr = np.array(Image.open(p).convert('RGB').resize((64, 64)))
        r_vals.append(arr[:,:,0].mean())
        g_vals.append(arr[:,:,1].mean())
        b_vals.append(arr[:,:,2].mean())
    except Exception:
        pass

MEAN_COLOR = (
    int(round(np.mean(r_vals))),
    int(round(np.mean(g_vals))),
    int(round(np.mean(b_vals)))
)
print(f'Color medio del dataset (RGB): {MEAN_COLOR}')
# Out:
# Color medio del dataset (RGB): (112, 122, 95)

# %% [markdown]
# ## 4. Funciones de preprocesamiento y augmentation

# %%
def letterbox_pil(img: Image.Image) -> Image.Image:
    """Padding con color medio → imagen cuadrada, sin deformar."""
    img  = img.convert('RGB')
    w, h = img.size
    side = max(w, h)
    pl   = (side - w) // 2
    pt   = (side - h) // 2
    img  = ImageOps.expand(img, border=(pl, pt, side-w-pl, side-h-pt), fill=MEAN_COLOR)
    return img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)

def augment_pil(img: Image.Image) -> Image.Image:
    """Augmentation estándar + efectos climáticos simples (solo para train)."""
    # Geométricas
    if random.random() < 0.5:
        img = ImageOps.mirror(img)
    if random.random() < 0.3:
        img = ImageOps.flip(img)
    img = img.rotate(random.uniform(-20, 20), fillcolor=MEAN_COLOR, expand=False)
    # Zoom
    zf  = random.uniform(0.85, 1.0)
    w, h = img.size
    nw, nh = int(w*zf), int(h*zf)
    l, t = (w-nw)//2, (h-nh)//2
    img = img.crop((l, t, l+nw, t+nh)).resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
    # Fotométricas
    img = ImageEnhance.Brightness(img).enhance(random.uniform(0.70, 1.30))
    img = ImageEnhance.Contrast(img).enhance(random.uniform(0.75, 1.25))
    img = ImageEnhance.Color(img).enhance(random.uniform(0.80, 1.20))
    # Efecto climático leve (niebla: blend con blanco)
    if random.random() < 0.15:
        fog = Image.new('RGB', img.size, (220, 220, 220))
        img = Image.blend(img, fog, alpha=random.uniform(0.05, 0.20))
    return img

def load_and_preprocess(path: str, label: int,
                         augment: bool = False) -> tuple:
    """Carga, letterbox, opcional augment, normalización MobileNetV2."""
    img = Image.open(path)
    img = letterbox_pil(img)
    if augment:
        img = augment_pil(img)
    arr = np.array(img, dtype=np.float32)
    # Normalización específica de MobileNetV2: [-1, 1]
    arr = tf.keras.applications.mobilenet_v2.preprocess_input(arr)
    return arr, label

print('Funciones de preprocesamiento listas.')
# Out:
# Funciones de preprocesamiento listas.

# %% [markdown]
# ## 5. Pipeline tf.data con augmentation en memoria

# %%
def build_augmented_train_lists():
    """
    Expande solo clases minoritarias segun oversample_plan.
    Duplica paths solo en train; el augment visual se aplica en cada epoch.
    """
    count = Counter(train_labels)
    aug_paths, aug_labels = list(train_paths), list(train_labels)

    if not oversample_plan:
        return aug_paths, aug_labels

    for cls in classes:
        target = oversample_plan.get(cls)
        if target is None:
            continue

        n = count[cls]
        needed = target - n
        if needed <= 0:
            continue

        cls_pool = [p for p, l in zip(train_paths, train_labels) if l == cls]
        extras = random.choices(cls_pool, k=needed)
        aug_paths.extend(extras)
        aug_labels.extend([cls] * needed)
        print(f'  {cls}: {n} -> {n + needed}')

    return aug_paths, aug_labels

print('Construyendo listas de train con oversampling + augmentation...')
aug_train_paths, aug_train_labels = build_augmented_train_lists()
aug_train_idx = [class_to_idx[l] for l in aug_train_labels]
val_idx       = [class_to_idx[l] for l in val_labels]
test_idx      = [class_to_idx[l] for l in test_labels]

# Shuffle antes de crear el dataset
combined = list(zip(aug_train_paths, aug_train_idx))
random.shuffle(combined)
aug_train_paths, aug_train_idx = zip(*combined)

print(f'Train original: {len(train_paths)}')
print(f'Train final (oversampling): {len(aug_train_paths)}')


def make_dataset(paths_list, labels_list, augment=False, cache=False):
    def load_fn(path, label):
        arr, lbl = tf.py_function(
            func=lambda p, l: load_and_preprocess(
                p.numpy().decode(), int(l.numpy()), augment),
            inp=[path, label],
            Tout=[tf.float32, tf.int32]
        )
        arr.set_shape([IMG_SIZE, IMG_SIZE, 3])
        lbl.set_shape([])
        return arr, lbl

    ds = tf.data.Dataset.from_tensor_slices(
        (list(paths_list), list(labels_list))
    )
    if augment:
        ds = ds.shuffle(buffer_size=2000, seed=RANDOM_SEED)
    ds = ds.map(load_fn, num_parallel_calls=tf.data.AUTOTUNE)
    if cache:
        ds = ds.cache()
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

# Oversampling y augmentation solo en train
train_ds = make_dataset(aug_train_paths, aug_train_idx, augment=True)
val_ds   = make_dataset(val_paths,  val_idx,  augment=False, cache=True)
test_ds  = make_dataset(test_paths, test_idx, augment=False, cache=True)

print('Datasets listos.')
print(f'Steps por epoch: {math.ceil(len(aug_train_paths) / BATCH_SIZE)}')
# Out:
# Construyendo listas de train con oversampling + augmentation...
#   healthy: 636 -> 1662
#   late_blight: 1527 -> 1662
#   leafroll_virus: 421 -> 1263
#   mosaic_virus: 463 -> 1389
#   nematode: 298 -> 894
#   pest: 519 -> 1557
#   z_no_potato: 981 -> 1662
# Train original: 6923
# Train final (oversampling): 12167
# Datasets listos.
# Steps por epoch: 381

# %% [markdown]
# ## 6. Construcción del modelo — MobileNetV2

# %%
def build_model(num_classes: int, trainable_base: bool = False):
    base = tf.keras.applications.MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights='imagenet'
    )
    base.trainable = trainable_base

    inputs  = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x       = base(inputs, training=False)
    x       = tf.keras.layers.GlobalAveragePooling2D()(x)
    x       = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model, base

model, base_model = build_model(NUM_CLASSES, trainable_base=False)
model.summary(line_length=80)
print(f'\nCapas en base: {len(base_model.layers)}')
print(f'Parámetros entrenables: {model.trainable_variables.__len__()}')
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)        │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224 (Functional) │ (None, 7, 7, 1280)       │     2,257,984 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_1        │ (None, 1280)             │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)               │ (None, 1280)             │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_1 (Dense)                   │ (None, 8)                │        10,248 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 2,268,232 (8.65 MB)
#  Trainable params: 10,248 (40.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Capas en base: 154
# Parámetros entrenables: 2

# %% [markdown]
# ## 7. Estrategia anti-desbalance: class_weight + focal loss

# %%
# class_weight sobre train original (sin duplicados de oversampling)
train_idx_orig = np.array([class_to_idx[l] for l in train_labels], dtype=np.int32)

weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=train_idx_orig
)
class_weight_dict = {i: float(w) for i, w in enumerate(weights)}

# alpha por clase para focal loss (normalizado)
alpha_vector = (weights / np.sum(weights)).astype(np.float32)

print('class_weight_dict:')
for i, cls in enumerate(classes):
    print(f'  {i} ({cls}): {weights[i]:.4f}')


def sparse_categorical_focal_loss(alpha, gamma=2.0, label_smoothing=0.0):
    alpha = tf.constant(alpha, dtype=tf.float32)

    def loss_fn(y_true, y_pred):
        y_true_int = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_true_oh = tf.one_hot(y_true_int, depth=NUM_CLASSES, dtype=tf.float32)

        if label_smoothing > 0.0:
            y_true_oh = y_true_oh * (1.0 - label_smoothing) + (label_smoothing / NUM_CLASSES)

        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        ce = -tf.reduce_sum(y_true_oh * tf.math.log(y_pred), axis=-1)
        p_t = tf.reduce_sum(y_true_oh * y_pred, axis=-1)
        focal_factor = tf.pow(1.0 - p_t, gamma)
        alpha_t = tf.reduce_sum(y_true_oh * alpha, axis=-1)

        return tf.reduce_mean(alpha_t * focal_factor * ce)

    return loss_fn

if USE_FOCAL_LOSS:
    training_loss = sparse_categorical_focal_loss(
        alpha=alpha_vector,
        gamma=FOCAL_GAMMA,
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: Focal loss (gamma={FOCAL_GAMMA}, label_smoothing={LABEL_SMOOTHING})')
else:
    training_loss = tf.keras.losses.SparseCategoricalCrossentropy(
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: SparseCategoricalCrossentropy (label_smoothing={LABEL_SMOOTHING})')
# Out:
# class_weight_dict:
#   0 (early_blight): 0.4164
#   1 (healthy): 1.3607
#   2 (late_blight): 0.5667
#   3 (leafroll_virus): 2.0555
#   4 (mosaic_virus): 1.8691
#   5 (nematode): 2.9039
#   6 (pest): 1.6674
#   7 (z_no_potato): 0.8821
# Loss activa: Focal loss (gamma=2.0, label_smoothing=0.05)

# %% [markdown]
# ## 8. Fase 1 — Entrenamiento con base congelada
# Solo se entrenan las capas densas superiores. La base MobileNetV2 actúa como extractor de características fijo.

# %%
callbacks_phase1 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=5,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=3, min_lr=1e-6, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase1.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE1),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 1 ({EPOCHS_PHASE1} epocas max., base congelada)...')
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE1,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase1,
    verbose=1
)
# Out:
# Iniciando fase 1 (15 epocas max., base congelada)...
# Epoch 1/15
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.6070 - loss: 0.1012
# Epoch 1: val_accuracy improved from -inf to 0.84221, saving model to /kaggle/working/best_phase1.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 167s 413ms/step - accuracy: 0.6074 - loss: 0.1011 - val_accuracy: 0.8422 - val_loss: 0.0183 - learning_rate: 0.0010
# Epoch 2/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8587 - loss: 0.0279
# Epoch 2: val_accuracy improved from 0.84221 to 0.87525, saving model to /kaggle/working/best_phase1.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 132s 347ms/step - accuracy: 0.8587 - loss: 0.0279 - val_accuracy: 0.8753 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 3/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8753 - loss: 0.0234
# Epoch 3: val_accuracy did not improve from 0.87525
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 132s 346ms/step - accuracy: 0.8753 - loss: 0.0234 - val_accuracy: 0.8739 - val_loss: 0.0141 - learning_rate: 0.0010
# Epoch 4/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8894 - loss: 0.0187
# Epoch 4: val_accuracy improved from 0.87525 to 0.89144, saving model to /kaggle/working/best_phase1.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 132s 347ms/step - accuracy: 0.8894 - loss: 0.0187 - val_accuracy: 0.8914 - val_loss: 0.0119 - learning_rate: 0.0010
# Epoch 5/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8933 - loss: 0.0188
# Epoch 5: val_accuracy did not improve from 0.89144
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 132s 345ms/step - accuracy: 0.8933 - loss: 0.0188 - val_accuracy: 0.8860 - val_loss: 0.0112 - learning_rate: 0.0010
# Epoch 6/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8966 - loss: 0.0174
# Epoch 6: val_accuracy improved from 0.89144 to 0.89751, saving model to /kaggle/working/best_phase1.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 133s 349ms/step - accuracy: 0.8967 - loss: 0.0174 - val_accuracy: 0.8975 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 7/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9002 - loss: 0.0172
# Epoch 7: val_accuracy did not improve from 0.89751
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 132s 346ms/step - accuracy: 0.9002 - loss: 0.0172 - val_accuracy: 0.8955 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 8/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9036 - loss: 0.0161
# Epoch 8: val_accuracy did not improve from 0.89751
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 134s 350ms/step - accuracy: 0.9036 - loss: 0.0161 - val_accuracy: 0.8847 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 9/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9003 - loss: 0.0173
# Epoch 9: val_accuracy did not improve from 0.89751
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 131s 343ms/step - accuracy: 0.9003 - loss: 0.0173 - val_accuracy: 0.8968 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 10/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9062 - loss: 0.0164
# Epoch 10: val_accuracy did not improve from 0.89751
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 131s 342ms/step - accuracy: 0.9062 - loss: 0.0164 - val_accuracy: 0.8935 - val_loss: 0.0116 - learning_rate: 0.0010
# Epoch 11/15
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9114 - loss: 0.0150
# Epoch 11: val_accuracy did not improve from 0.89751
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 133s 349ms/step - accuracy: 0.9114 - loss: 0.0150 - val_accuracy: 0.8867 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %% [markdown]
# ## 9. Fase 2 — Fine-tuning
# Se descongelan las últimas capas de la base (desde `UNFREEZE_FROM` en adelante) con learning rate reducido.

# %%
base_model.trainable = True
for layer in base_model.layers[:UNFREEZE_FROM]:
    layer.trainable = False

trainable_count = sum(1 for l in base_model.layers if l.trainable)
print(f'Capas descongeladas en base: {trainable_count} / {len(base_model.layers)}')

callbacks_phase2 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=7,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=3, min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase2.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE2),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 2 ({EPOCHS_PHASE2} epocas max., fine-tuning)...')
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE2,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase2,
    initial_epoch=len(history1.history['loss']),
    verbose=1
)
# Out:
# Capas descongeladas en base: 54 / 154
# Iniciando fase 2 (20 epocas max., fine-tuning)...
# Epoch 12/20
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.8006 - loss: 0.0762
# Epoch 12: val_accuracy improved from -inf to 0.80715, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 177s 406ms/step - accuracy: 0.8008 - loss: 0.0761 - val_accuracy: 0.8071 - val_loss: 0.0442 - learning_rate: 1.0000e-04
# Epoch 13/20
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9277 - loss: 0.0116
# Epoch 13: val_accuracy improved from 0.80715 to 0.85772, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 136s 358ms/step - accuracy: 0.9277 - loss: 0.0116 - val_accuracy: 0.8577 - val_loss: 0.0345 - learning_rate: 1.0000e-04
# Epoch 14/20
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9464 - loss: 0.0080
# Epoch 14: val_accuracy improved from 0.85772 to 0.91032, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 137s 358ms/step - accuracy: 0.9464 - loss: 0.0080 - val_accuracy: 0.9103 - val_loss: 0.0173 - learning_rate: 1.0000e-04
# Epoch 15/20
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9617 - loss: 0.0057
# Epoch 15: val_accuracy improved from 0.91032 to 0.93257, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 136s 356ms/step - accuracy: 0.9617 - loss: 0.0057 - val_accuracy: 0.9326 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 16/20
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9698 - loss: 0.0043
# Epoch 16: val_accuracy improved from 0.93257 to 0.94268, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 136s 356ms/step - accuracy: 0.9698 - loss: 0.0043 - val_accuracy: 0.9427 - val_loss: 0.0087 - learning_rate: 1.0000e-04
# Epoch 17/20
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.9727 - loss: 0.0040
# Epoch 17: val_accuracy improved from 0.94268 to 0.95954, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 135s 355ms/step - accuracy: 0.9727 - loss: 0.0040 - val_accuracy: 0.9595 - val_loss: 0.0109 - learning_rate: 1.0000e-04
# Epoch 18/20
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9687 - loss: 0.0062
# Epoch 18: val_accuracy did not improve from 0.95954
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 136s 357ms/step - accuracy: 0.9687 - loss: 0.0062 - val_accuracy: 0.9595 - val_loss: 0.0074 - learning_rate: 1.0000e-04
# Epoch 19/20
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9732 - loss: 0.0037
# Epoch 19: val_accuracy improved from 0.95954 to 0.96494, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 136s 356ms/step - accuracy: 0.9733 - loss: 0.0037 - val_accuracy: 0.9649 - val_loss: 0.0064 - learning_rate: 1.0000e-04
# Epoch 20/20
# 380/381 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9784 - loss: 0.0034
# Epoch 20: val_accuracy improved from 0.96494 to 0.97235, saving model to /kaggle/working/best_phase2.keras
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 136s 357ms/step - accuracy: 0.9784 - loss: 0.0034 - val_accuracy: 0.9724 - val_loss: 0.0053 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 10. Curvas de entrenamiento

# %%
def plot_history(h1, h2):
    acc  = h1.history['accuracy']  + h2.history['accuracy']
    val  = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    vloss= h1.history['val_loss'] + h2.history['val_loss']
    sep  = len(h1.history['accuracy'])  # época donde empieza fase 2

    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    for ax, train_m, val_m, title in zip(
        axes,
        [acc, loss], [val, vloss],
        ['Accuracy', 'Loss']
    ):
        ax.plot(train_m, label='Train', color='steelblue')
        ax.plot(val_m,   label='Val',   color='coral')
        ax.axvline(sep, color='gray', linestyle='--', linewidth=1, label='Fine-tuning')
        ax.set_title(title)
        ax.set_xlabel('Época')
        ax.legend(fontsize=8)
        ax.spines[['top','right']].set_visible(False)

    plt.suptitle('Curvas de entrenamiento — fase 1 + fase 2', fontsize=11)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'training_curves.png', dpi=150, bbox_inches='tight')
    plt.show()

plot_history(history1, history2)

# %% [markdown]
# ## 11. Evaluación en test — métricas completas

# %%
import pandas as pd
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

# Auditoria detallada por imagen para saber en cuales falla el modelo
records_eval = []
y_true, y_pred = [], []

for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    probs = model.predict(np.expand_dims(arr, 0), verbose=0)[0]

    pred_idx = int(np.argmax(probs))
    pred_label = idx_to_class[pred_idx]
    conf = float(probs[pred_idx])

    y_true.append(true_idx)
    y_pred.append(pred_idx)

    records_eval.append({
        'filename': Path(path).name,
        'path': path,
        'true_label': true_label,
        'pred_label': pred_label,
        'confidence': conf,
        'correct': pred_label == true_label,
    })

print('=' * 60)
print('REPORTE DE CLASIFICACION - TEST SET (KERAS FLOAT32)')
print('=' * 60)
print(classification_report(
    y_true,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0,
))

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(9, 7))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusion - test set (Keras float32)', fontsize=11)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# Tabla completa de predicciones y subset de errores
df_test_predictions = pd.DataFrame(records_eval)
df_test_errors = (
    df_test_predictions[~df_test_predictions['correct']]
    .sort_values('confidence', ascending=False)
    .reset_index(drop=True)
)

print('\nResumen de auditoria por imagen:')
print(f"  Total evaluadas: {len(df_test_predictions)}")
print(f"  Aciertos       : {int(df_test_predictions['correct'].sum())}")
print(f"  Errores        : {len(df_test_errors)}")

print('\nPrimeras 20 predicciones:')
display(df_test_predictions.head(20))

print('\nPrimeros 30 errores (si existen):')
display(df_test_errors.head(30))

pred_csv_path = OUTPUT_DIR / 'keras_test_predictions.csv'
err_csv_path = OUTPUT_DIR / 'keras_test_errors.csv'
df_test_predictions.to_csv(pred_csv_path, index=False, encoding='utf-8-sig')
df_test_errors.to_csv(err_csv_path, index=False, encoding='utf-8-sig')

print('\nCSV exportados:')
print(f'  - {pred_csv_path}')
print(f'  - {err_csv_path}')
# Out:
# ============================================================
# REPORTE DE CLASIFICACION - TEST SET (KERAS FLOAT32)
# ============================================================
#                 precision    recall  f1-score   support
#
#   early_blight     0.9816    0.9574    0.9694       446
#        healthy     0.9774    0.9559    0.9665       136
#    late_blight     0.9634    0.9664    0.9649       327
# leafroll_virus     1.0000    1.0000    1.0000        90
#   mosaic_virus     0.9612    1.0000    0.9802        99
#       nematode     0.9844    0.9844    0.9844        64
#           pest     0.8908    0.9550    0.9217       111
#    z_no_potato     0.9858    0.9905    0.9882       211
#
#       accuracy                         0.9704      1484
#      macro avg     0.9681    0.9762    0.9719      1484
#   weighted avg     0.9709    0.9704    0.9705      1484
# Resumen de auditoria por imagen:
#   Total evaluadas: 1484
#   Aciertos       : 1440
#   Errores        : 44
#
# Primeras 20 predicciones:
#                                              filename  \
# 0                                         9002577.jpg
# 1                               late blight (102).JPG
# 2                                   1692335403690.jpg
# 3                                         5000205.jpg
# 4                                         ys2 (8).jpg
# 5   b995ac55-e42d-4fb6-9b91-310a4d046c21___RS_HL 9...
# 6                               plant pests (268).jpg
# 7                                 20230712_144204.jpg
# 8                             IMG_20230816_140721.jpg
# 9                                        DSC_0272.JPG
# 10                                          69341.jpg
# 11                                       DSC_0064.JPG
# 12                                20230816_121133.jpg
# 13                      potato cyst nematode (84).jpg
# 14                                20230802_115325.jpg
# 15                                20230922_163736.jpg
# 16                                          68930.jpg
# 17                                       ls1 (17).jpg
# 18                                          67467.jpg
# 19  410dea1e-836e-4d41-9039-9cfc2ec30c1e___GH_HL L...
#
#                                                  path    true_label  \
# 0   /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 1   /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 2   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 3   /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 4   /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 5   /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 6   /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 7   /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 8   /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 9   /kaggle/input/datasets/kevinvichicela/potato-3...  mosaic_virus
# 10  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 11  /kaggle/input/datasets/kevinvichicela/potato-3...  mosaic_virus
# 12  /kaggle/input/datasets/kevinvichicela/potato-3...       healthy
# 13  /kaggle/input/datasets/kevinvichicela/potato-3...      nematode
# 14  /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 15  /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 16  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 17  /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 18  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 19  /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
#
#       pred_label  confidence  correct
# 0    z_no_potato    0.999967     True
# 1    late_blight    0.999863     True
# 2   early_blight    0.946583     True
# 3    z_no_potato    1.000000     True
# 4    z_no_potato    1.000000     True
# 5    z_no_potato    0.999999     True
# 6           pest    0.999987     True
# 7           pest    0.989523     True
# 8           pest    0.999757     True
# 9   mosaic_virus    0.971687     True
# 10   late_blight    0.995800     True
# 11  mosaic_virus    0.998675     True
# 12       healthy    0.999593     True
# 13      nematode    0.999999     True
# 14          pest    0.782428     True
# 15          pest    0.997640     True
# 16   late_blight    0.998739     True
# 17   z_no_potato    1.000000     True
# 18  early_blight    0.999981     True
# 19   z_no_potato    1.000000     True
# Primeros 30 errores (si existen):
#                                              filename  \
# 0                                        IMG_0290.JPG
# 1                             IMG_20210811_121728.jpg
# 2   3d8e1f90-be34-4da7-b124-a98eddb346d1___RS_Erly...
# 3                                 20230816_143423.jpg
# 4                                   1692334247342.jpg
# 5                                        IMG_8124.JPG
# 6                                          116100.jpg
# 7                                           97098.jpg
# 8                                 20230712_154637.jpg
# 9                                        IMG_9423.JPG
# 10                              Late_Blight (676).jpg
# 11                                       IMG_0355.JPG
# 12                                20230712_160344.jpg
# 13                                          96909.jpg
# 14                              Late_Blight (702).jpg
# 15                                20230712_145457.jpg
# 16                                    Healthy (4).JPG
# 17                            IMG_20230816_122017.jpg
# 18                            IMG_20230816_115039.jpg
# 19                                       IMG_4729.JPG
# 20                                20230815_113141.jpg
# 21                                          97959.jpg
# 22                                       IMG_0255.JPG
# 23                                          96816.jpg
# 24                          IMG_20230816_135810~2.jpg
# 25                             20230802_105056702.jpg
# 26                                          98070.jpg
# 27                            IMG_20210811_122111.jpg
# 28                                       IMG_8140.JPG
# 29                                20230712_122415.jpg
#
#                                                  path    true_label  \
# 0   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 1   /kaggle/input/datasets/kevinvichicela/potato-3...       healthy
# 2   /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 3   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 4   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 5   /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 6   /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 7   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 8   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 9   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 10  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 11  /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 12  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 13  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 14  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 15  /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 16  /kaggle/input/datasets/kevinvichicela/potato-3...       healthy
# 17  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 18  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 19  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 20  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 21  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 22  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 23  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 24  /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 25  /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 26  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 27  /kaggle/input/datasets/kevinvichicela/potato-3...       healthy
# 28  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 29  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
#
#       pred_label  confidence  correct
# 0           pest    0.999738    False
# 1   mosaic_virus    0.998889    False
# 2    late_blight    0.994102    False
# 3           pest    0.991166    False
# 4           pest    0.989825    False
# 5   early_blight    0.956527    False
# 6    z_no_potato    0.924145    False
# 7    late_blight    0.904547    False
# 8    late_blight    0.898361    False
# 9    late_blight    0.885420    False
# 10  early_blight    0.877649    False
# 11   late_blight    0.840348    False
# 12      nematode    0.828542    False
# 13   late_blight    0.803238    False
# 14  early_blight    0.777305    False
# 15  early_blight    0.769037    False
# 16   z_no_potato    0.743162    False
# 17          pest    0.737812    False
# 18          pest    0.733342    False
# 19   late_blight    0.728986    False
# 20       healthy    0.703758    False
# 21   late_blight    0.679456    False
# 22          pest    0.676396    False
# 23   late_blight    0.671937    False
# 24  early_blight    0.669191    False
# 25  early_blight    0.652308    False
# 26   late_blight    0.630917    False
# 27  mosaic_virus    0.627608    False
# 28  early_blight    0.615670    False
# 29          pest    0.583173    False
# CSV exportados:
#   - /kaggle/working/keras_test_predictions.csv
#   - /kaggle/working/keras_test_errors.csv

# %% [markdown]
# ## 12. Exportación a TFLite (int8)
# Cuantización post-entrenamiento. Reduce el modelo a ~14–25 MB para el APK.

# %%
# Dataset representativo para calibración int8 (100 imágenes de val)
def representative_dataset():
    count = 0
    for img_batch, _ in val_ds:
        for img in img_batch:
            yield [tf.expand_dims(img, 0)]
            count += 1
            if count >= 100:
                return

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.uint8

# Guardar el modelo base .tflite
tflite_model = converter.convert()
tflite_path = OUTPUT_DIR / 'potato_classifier.tflite'
tflite_path.write_bytes(tflite_model)

# Guardar las etiquetas aparte (ya que no se pueden incrustar directamente aquí)
labels_path = OUTPUT_DIR / 'labels.txt'
with open(labels_path, 'w') as f:
    f.write('\n'.join(classes))

size_mb = tflite_path.stat().st_size / 1_048_576
print(f'Modelo TFLite guardado: {tflite_path}')
print(f'Etiquetas guardadas en: {labels_path}')
print(f'Tamaño del modelo: {size_mb:.2f} MB')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpfwvkfnk4/assets
# INFO:tensorflow:Assets written to: /tmp/tmpfwvkfnk4/assets
# Saved artifact at '/tmp/tmpfwvkfnk4'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_313')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   132638591163024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591163216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591162448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591161872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591162640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591160912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591162832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591163408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591158608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591161680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638706546832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591158416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591159184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591158800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591163600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638706547600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634295828304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638706542992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591158992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638706548368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500113296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500108496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638706545680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638591162256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500113872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500111568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500110800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500107344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500106384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500106000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500108688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500112336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500113488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500117904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500112720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500119056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500120400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500109840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500118288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500107728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500120016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500106768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500117136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500111376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500114064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500114256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500107536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500116944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500116560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500118864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500110992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500113680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500110032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500112144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500116176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500108112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500115792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500106960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500119440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500105808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500109072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500114832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500114448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500109264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500112528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500105616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500115408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500107920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500115024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500120208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500116368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500109648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500104272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500119824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500112912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500118480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500106576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500113104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500111184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500117328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500107152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500119632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500114640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500118672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500109456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500115216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500117520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500116752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500108880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634500110608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972985040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972983888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972988688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972979856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972988880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972980432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972988304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972992720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972990992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972982736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972985616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972980240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972986000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972991376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972990416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972984464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972993104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972991952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972989456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972990608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972987536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972981968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972985232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972990224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972992144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972980048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972979664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972995216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972994832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972981776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972984656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972979280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972984080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972983504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972986768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972995024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972987152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972987920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972989648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972991568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972989840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972981008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972992912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972984848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972994256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972989072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972986384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972982928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972989264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972986960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972991184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972994640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972980816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972981584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972993488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972987728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972980624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972992336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972982544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972982352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972993296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972992528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972987344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972979472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972990800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972988496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972993680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972991760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972995408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972983696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972993872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972994448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972981392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972986576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972982160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132634972990032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699422544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699421968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699421776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699422160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699423888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699423312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699423504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699423696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699422736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699422352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699425424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699423120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699426192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699426576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699427728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699427152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699427344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699428304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699429648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699429264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699426960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699430032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699430224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699431568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699430992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699431184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699431376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699428880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699431952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699432144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699429840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699433488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699432912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699433104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699433296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699430800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699434448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699433872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699434064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699434256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699431760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699435408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699434832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699435024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699435216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699432720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699436368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699435792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699435984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699436176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699433680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699437328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699436752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699436944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699437520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699437904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699436560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699437136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132638699435600: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1779165396.939868      57 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1779165396.939906      57 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Modelo TFLite guardado: /kaggle/working/potato_classifier.tflite
# Etiquetas guardadas en: /kaggle/working/labels.txt
# Tamaño del modelo: 2.59 MB
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %%
from sklearn.metrics import accuracy_score

# Cargar el modelo TFLite exportado
interpreter = tf.lite.Interpreter(model_path=str(tflite_path))
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

in_scale, in_zero_point = input_details['quantization']
out_scale, out_zero_point = output_details['quantization']

print('Entrada TFLite:', input_details['dtype'], input_details['shape'], input_details['quantization'])
print('Salida TFLite :', output_details['dtype'], output_details['shape'], output_details['quantization'])


def run_tflite_int8_single(img_float_m1_1):
    """
    img_float_m1_1: np.ndarray [H,W,3] normalizada en [-1, 1]
    Retorna probs float32 des-cuantizadas.
    """
    x = np.expand_dims(img_float_m1_1, axis=0).astype(np.float32)

    # Cuantizar entrada float -> uint8 usando parametros del tensor de entrada
    if in_scale > 0:
        x_q = np.round(x / in_scale + in_zero_point)
    else:
        x_q = x
    x_q = np.clip(x_q, 0, 255).astype(np.uint8)

    interpreter.set_tensor(input_details['index'], x_q)
    interpreter.invoke()
    y_q = interpreter.get_tensor(output_details['index'])

    # Des-cuantizar salida uint8 -> float
    if out_scale > 0:
        y = (y_q.astype(np.float32) - out_zero_point) * out_scale
    else:
        y = y_q.astype(np.float32)

    return y[0]


# Evaluacion del TFLite en el mismo test set
y_true_tflite, y_pred_tflite = [], []
for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    probs = run_tflite_int8_single(arr)
    pred_idx = int(np.argmax(probs))

    y_true_tflite.append(true_idx)
    y_pred_tflite.append(pred_idx)

acc_tflite = accuracy_score(y_true_tflite, y_pred_tflite)

# Accuracy Keras float ya calculada antes (si no existe, la recalculamos rapido)
if 'y_true' in globals() and 'y_pred' in globals() and len(y_true) == len(y_pred):
    acc_keras = accuracy_score(y_true, y_pred)
else:
    y_true_keras, y_pred_keras = [], []
    for batch_imgs, batch_labels in test_ds:
        preds = model.predict(batch_imgs, verbose=0)
        y_pred_keras.extend(np.argmax(preds, axis=1))
        y_true_keras.extend(batch_labels.numpy())
    acc_keras = accuracy_score(y_true_keras, y_pred_keras)

print('\n' + '=' * 65)
print('COMPARACION DE ACCURACY EN TEST')
print('=' * 65)
print(f'Keras (float32): {acc_keras:.4f}')
print(f'TFLite (int8) : {acc_tflite:.4f}')
print(f'Delta (int8 - float): {acc_tflite - acc_keras:+.4f}')
print('=' * 65)
# Out:
# Entrada TFLite: <class 'numpy.uint8'> [  1 224 224   3] (0.007843137718737125, 127)
# Salida TFLite : <class 'numpy.uint8'> [1 8] (0.00390625, 0)
#
# =================================================================
# COMPARACION DE ACCURACY EN TEST
# =================================================================
# Keras (float32): 0.9704
# TFLite (int8) : 0.9683
# Delta (int8 - float): -0.0020
# =================================================================

# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# -----------------------------
# 1) Reporte de clasificacion
# -----------------------------
report_dict = classification_report(
    y_true_tflite,
    y_pred_tflite,
    target_names=classes,
    digits=4,
    output_dict=True,
    zero_division=0
)

# Tabla por clase
rows = []
for cls in classes:
    rows.append({
        'clase': cls,
        'precision': report_dict[cls]['precision'],
        'recall': report_dict[cls]['recall'],
        'f1-score': report_dict[cls]['f1-score'],
        'support': int(report_dict[cls]['support'])
    })

df_cls = pd.DataFrame(rows)

# Tabla de resumen
df_summary = pd.DataFrame([
    {
        'metrica': 'accuracy',
        'valor': float(report_dict['accuracy'])
    },
    {
        'metrica': 'macro avg precision',
        'valor': float(report_dict['macro avg']['precision'])
    },
    {
        'metrica': 'macro avg recall',
        'valor': float(report_dict['macro avg']['recall'])
    },
    {
        'metrica': 'macro avg f1-score',
        'valor': float(report_dict['macro avg']['f1-score'])
    },
    {
        'metrica': 'weighted avg precision',
        'valor': float(report_dict['weighted avg']['precision'])
    },
    {
        'metrica': 'weighted avg recall',
        'valor': float(report_dict['weighted avg']['recall'])
    },
    {
        'metrica': 'weighted avg f1-score',
        'valor': float(report_dict['weighted avg']['f1-score'])
    }
])

print('=' * 70)
print('REPORTE TFLITE (INT8) - LISTO PARA TESIS')
print('=' * 70)
print('\nMetricas globales:')
display(df_summary)
print('\nMetricas por clase:')
display(df_cls)

# -----------------------------
# 2) Matriz de confusion
# -----------------------------
cm_tflite = confusion_matrix(y_true_tflite, y_pred_tflite)

fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_tflite, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusion - Modelo TFLite int8 (Test)', fontsize=12)
plt.tight_layout()

cm_img_path = OUTPUT_DIR / 'confusion_matrix_tflite.png'
plt.savefig(cm_img_path, dpi=160, bbox_inches='tight')
plt.show()

# -----------------------------
# 3) Guardar tablas para tesis
# -----------------------------
cls_csv_path = OUTPUT_DIR / 'tflite_report_per_class.csv'
sum_csv_path = OUTPUT_DIR / 'tflite_report_summary.csv'

# Redondeo para reporte
df_cls_out = df_cls.copy()
df_cls_out[['precision', 'recall', 'f1-score']] = df_cls_out[['precision', 'recall', 'f1-score']].round(4)
df_summary_out = df_summary.copy()
df_summary_out['valor'] = df_summary_out['valor'].round(4)

df_cls_out.to_csv(cls_csv_path, index=False, encoding='utf-8-sig')
df_summary_out.to_csv(sum_csv_path, index=False, encoding='utf-8-sig')

print('\nArchivos exportados:')
print(f'  - {cls_csv_path}')
print(f'  - {sum_csv_path}')
print(f'  - {cm_img_path}')

# -----------------------------
# 4) Auditoria de errores por imagen (TFLite)
# -----------------------------
records_tflite = []

for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    
    # Inferencia con TFLite
    probs = run_tflite_int8_single(arr)
    
    pred_idx = int(np.argmax(probs))
    pred_label = idx_to_class[pred_idx]
    conf = float(probs[pred_idx])
    
    records_tflite.append({
        'filename': Path(path).name,
        'path': path,
        'true_label': true_label,
        'pred_label': pred_label,
        'confidence': conf,
        'correct': pred_label == true_label,
    })

df_tflite_predictions = pd.DataFrame(records_tflite)
df_tflite_errors = (
    df_tflite_predictions[~df_tflite_predictions['correct']]
    .sort_values('confidence', ascending=False)
    .reset_index(drop=True)
)

tflite_pred_csv = OUTPUT_DIR / 'tflite_test_predictions.csv'
tflite_err_csv = OUTPUT_DIR / 'tflite_test_errors.csv'

df_tflite_predictions.to_csv(tflite_pred_csv, index=False, encoding='utf-8-sig')
df_tflite_errors.to_csv(tflite_err_csv, index=False, encoding='utf-8-sig')

print('\nResumen de auditoria por imagen (TFLite):')
print(f"  Total evaluadas: {len(df_tflite_predictions)}")
print(f"  Aciertos       : {int(df_tflite_predictions['correct'].sum())}")
print(f"  Errores        : {len(df_tflite_errors)}")

print('\nPrimeros 20 errores TFLite (mayor confianza en las fallas):')
display(df_tflite_errors.head(20))

print('\nArchivos de auditoria exportados:')
print(f'  - {tflite_pred_csv}')
print(f'  - {tflite_err_csv}')
# Out:
# ======================================================================
# REPORTE TFLITE (INT8) - LISTO PARA TESIS
# ======================================================================
#
# Metricas globales:
#                   metrica     valor
# 0                accuracy  0.968329
# 1     macro avg precision  0.964325
# 2        macro avg recall  0.972472
# 3      macro avg f1-score  0.968193
# 4  weighted avg precision  0.968764
# 5     weighted avg recall  0.968329
# 6   weighted avg f1-score  0.968343
# Metricas por clase:
#             clase  precision    recall  f1-score  support
# 0    early_blight   0.983721  0.948430  0.965753      446
# 1         healthy   0.962963  0.955882  0.959410      136
# 2     late_blight   0.961078  0.981651  0.971256      327
# 3  leafroll_virus   1.000000  1.000000  1.000000       90
# 4    mosaic_virus   0.933962  1.000000  0.965854       99
# 5        nematode   0.984375  0.984375  0.984375       64
# 6            pest   0.902655  0.918919  0.910714      111
# 7     z_no_potato   0.985849  0.990521  0.988180      211
# Archivos exportados:
#   - /kaggle/working/tflite_report_per_class.csv
#   - /kaggle/working/tflite_report_summary.csv
#   - /kaggle/working/confusion_matrix_tflite.png
#
# Resumen de auditoria por imagen (TFLite):
#   Total evaluadas: 1484
#   Aciertos       : 1437
#   Errores        : 47
#
# Primeros 20 errores TFLite (mayor confianza en las fallas):
#                                              filename  \
# 0                             IMG_20210811_121728.jpg
# 1                                   1692334247342.jpg
# 2                                        IMG_0290.JPG
# 3                                 20230816_143423.jpg
# 4   3d8e1f90-be34-4da7-b124-a98eddb346d1___RS_Erly...
# 5                                        IMG_9423.JPG
# 6                                        IMG_0355.JPG
# 7                                        IMG_8124.JPG
# 8                                 20230712_154637.jpg
# 9                                           97098.jpg
# 10                                20230712_160344.jpg
# 11                                         116100.jpg
# 12                              Late_Blight (676).jpg
# 13                            IMG_20230816_115039.jpg
# 14  873aa4b3-61f8-473a-8fd3-b39ede9376c4___RS_Late...
# 15                                20230815_113141.jpg
# 16                                          97959.jpg
# 17                            IMG_20210811_122111.jpg
# 18                                          96909.jpg
# 19                                          98070.jpg
#
#                                                  path    true_label  \
# 0   /kaggle/input/datasets/kevinvichicela/potato-3...       healthy
# 1   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 2   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 3   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 4   /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 5   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 6   /kaggle/input/datasets/kevinvichicela/potato-3...          pest
# 7   /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 8   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 9   /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 10  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 11  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 12  /kaggle/input/datasets/kevinvichicela/potato-3...   late_blight
# 13  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 14  /kaggle/input/datasets/kevinvichicela/potato-3...   z_no_potato
# 15  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 16  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 17  /kaggle/input/datasets/kevinvichicela/potato-3...       healthy
# 18  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
# 19  /kaggle/input/datasets/kevinvichicela/potato-3...  early_blight
#
#       pred_label  confidence  correct
# 0   mosaic_virus    0.996094    False
# 1           pest    0.996094    False
# 2           pest    0.996094    False
# 3           pest    0.992188    False
# 4    late_blight    0.980469    False
# 5    late_blight    0.972656    False
# 6    late_blight    0.964844    False
# 7   early_blight    0.957031    False
# 8    late_blight    0.937500    False
# 9    late_blight    0.925781    False
# 10      nematode    0.910156    False
# 11   z_no_potato    0.886719    False
# 12  early_blight    0.867188    False
# 13          pest    0.843750    False
# 14   late_blight    0.824219    False
# 15       healthy    0.820312    False
# 16   late_blight    0.804688    False
# 17  mosaic_virus    0.796875    False
# 18   late_blight    0.796875    False
# 19   late_blight    0.789062    False
# Archivos de auditoria exportados:
#   - /kaggle/working/tflite_test_predictions.csv
#   - /kaggle/working/tflite_test_errors.csv

# %% [markdown]
# ## 13. Generación de Grad-CAM estáticos por clase
# Se calcula el mapa de activación de la última capa conv de MobileNetV2 para una imagen
# representativa de cada clase. Estos mapas se empaquetan en el APK como recursos estáticos —
# latencia extra en inferencia: 0 ms.

# %%
import matplotlib as mpl
import numpy as np
import matplotlib as mpl
from PIL import Image

last_conv_layer = None
for layer in reversed(base_model.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_layer = layer
        break

if last_conv_layer is None:
    raise ValueError("No se encontró ninguna capa Conv2D en base_model")

print("Usando capa:", last_conv_layer.name)
print("Output shape:", last_conv_layer.output.shape)

# Submodelo interno: base_model.input → (base_model.output, conv_outputs)
# Evita el problema de Graph disconnected al no cruzar el límite base→model
base_grad_model = tf.keras.Model(
    inputs=base_model.inputs,
    outputs=[base_model.output, last_conv_layer.output]
)

# Capas superiores del modelo principal (fuera de la base)
gap_layer     = model.get_layer('global_average_pooling2d')
dropout_layer = model.get_layer('dropout')
dense_layer   = model.get_layer('dense')

# Verificación
print("\nVerificación base_grad_model:")
print("  Input shape :", base_grad_model.input_shape)
print("  Output[0]   :", base_grad_model.output[0].shape, "← base output")
print("  Output[1]   :", base_grad_model.output[1].shape, "← conv activations")


def compute_gradcam(img_array: np.ndarray, class_idx: int) -> np.ndarray:
    """Retorna heatmap normalizado [0,1] del tamaño IMG_SIZE×IMG_SIZE."""
    img_tensor = tf.cast(tf.expand_dims(img_array, 0), tf.float32)

    with tf.GradientTape() as tape:
        base_out, conv_outputs = base_grad_model(img_tensor, training=False)
        tape.watch(conv_outputs)
        # Reconstruir el forward pass de las capas superiores
        x      = gap_layer(base_out)
        x      = dropout_layer(x, training=False)
        preds  = dense_layer(x)
        class_score = preds[:, class_idx]

    grads = tape.gradient(class_score, conv_outputs)

    if grads is None:
        raise ValueError(
            f"Gradientes None para clase {class_idx}. "
            "Verificar conexión de base_grad_model."
        )

    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs[0]), axis=-1)
    cam = tf.maximum(cam, 0)
    cam_np = cam.numpy()
    cam_max = np.max(cam_np)
    cam_min = np.min(cam_np)

    
    if (cam_max - cam_min) > 1e-8:
      
        cam_np = (cam_np - cam_min) / (cam_max - cam_min)
    else:
        
        cam_np = np.zeros_like(cam_np)

    cam_img = Image.fromarray((cam_np * 255).astype(np.uint8))
    cam_img = cam_img.resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR)
    
    return np.array(cam_img) / 255.0


def overlay_heatmap(original_arr: np.ndarray,
                    heatmap: np.ndarray,
                    color_alpha: float = 0.6) -> np.ndarray: # CAMBIADO DE alpha A color_alpha
    """Superpone el heatmap coloreado (jet) sobre la imagen original."""

    orig_uint8 = ((original_arr + 1.0) * 127.5).astype(np.uint8)
    orig_img = Image.fromarray(orig_uint8).convert("RGBA")
    
    colormap = mpl.colormaps['jet']
    heatmap_rgb = (colormap(heatmap)[:, :, :3] * 255).astype(np.uint8)
    
    dynamic_alpha = np.power(heatmap, 1.5) 
    
    dynamic_alpha = dynamic_alpha * color_alpha
    
    alpha_mask_uint8 = (dynamic_alpha * 255).astype(np.uint8)
    
    rgba_heatmap_np = np.dstack((heatmap_rgb, alpha_mask_uint8))
    heatmap_img = Image.fromarray(rgba_heatmap_np, "RGBA")
    
    blended_img = Image.alpha_composite(orig_img, heatmap_img)
    
    return np.array(blended_img.convert("RGB"))

print('\nFunciones Grad-CAM listas.')
# Out:
# Usando capa: Conv_1
# Output shape: (None, 7, 7, 1280)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_57/1731408355.py in <cell line: 0>()
#      24
#      25 # Capas superiores del modelo principal (fuera de la base)
# ---> 26 gap_layer     = model.get_layer('global_average_pooling2d')
#      27 dropout_layer = model.get_layer('dropout')
#      28 dense_layer   = model.get_layer('dense')
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/model.py in get_layer(self, name, index)
#     208                 if layer.name == name:
#     209                     return layer
# --> 210             raise ValueError(
#     211                 f"No such layer: {name}. Existing layers are: "
#     212                 f"{list(layer.name for layer in self.layers)}."
#
# ValueError: No such layer: global_average_pooling2d. Existing layers are: ['input_layer_3', 'mobilenetv2_1.00_224', 'global_average_pooling2d_1', 'dropout_1', 'dense_1'].

# %%
# Buscar las TOP 3 imágenes de test con mayor confianza por clase
TOP_N = 3
gradcam_dir = OUTPUT_DIR / 'gradcam_static'
gradcam_dir.mkdir(exist_ok=True)

# Ahora guardamos una lista de resultados por clase, no solo uno
top_per_class = {i: [] for i in range(NUM_CLASSES)}

print("Analizando imágenes y recolectando candidatos...")
for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _   = load_and_preprocess(path, true_idx, augment=False)
    preds    = model.predict(np.expand_dims(arr, 0), verbose=0)[0]
    pred_idx = np.argmax(preds)
    conf     = float(preds[pred_idx])
    
    # Solo candidatos correctamente clasificados y evitando la saturación del 1.0 absoluto
    if pred_idx == true_idx and conf < 0.99:
        top_per_class[true_idx].append({'conf': conf, 'path': path, 'arr': arr})

# Generar y guardar los Grad-CAM en la carpeta
print(f"\nGenerando y guardando las mejores {TOP_N} imágenes por clase...")
for cls_idx, cls_name in enumerate(classes):
    
    # Ordenamos todas las imágenes de esta clase de mayor a menor confianza
    # y nos quedamos solo con la cantidad definida en TOP_N
    candidates = sorted(top_per_class[cls_idx], key=lambda x: x['conf'], reverse=True)[:TOP_N]
    
    if not candidates:
        print(f'  AVISO: no se encontraron imágenes para {cls_name}')
        continue
        
    print(f"  -> Guardando {len(candidates)} opciones para {cls_name}...")
    
    for rank, info in enumerate(candidates):
        arr     = info['arr']
        heatmap = compute_gradcam(arr, cls_idx)
        overlay = overlay_heatmap(arr, heatmap)

        # Guardar directamente la imagen procesada con un nombre descriptivo
        # Ejemplo: gradcam_late_blight_top1_conf0.985.jpg
        filename = f'gradcam_{cls_name}_top{rank+1}_conf{info["conf"]:.3f}.jpg'
        out_path = gradcam_dir / filename
        Image.fromarray(overlay).save(str(out_path), quality=90)

print(f'\n¡Proceso terminado!')
print(f'Ve al panel derecho de Kaggle, entra a la carpeta: {gradcam_dir}')
print('Ahí tendrás todas las imágenes listas para descargar y elegir la mejor.')

# %% [markdown]
# ## 14. Resumen de archivos generados

# %%
print('=' * 55)
print('ARCHIVOS GENERADOS')
print('=' * 55)

outputs = [
    OUTPUT_DIR / 'potato_classifier.tflite',
    OUTPUT_DIR / 'best_phase2.keras',
    OUTPUT_DIR / 'training_curves.png',
    OUTPUT_DIR / 'confusion_matrix.png',
    OUTPUT_DIR / 'gradcam_all_classes.png',
]
outputs += list(gradcam_dir.glob('*.jpg'))

for f in outputs:
    if Path(f).exists():
        size = Path(f).stat().st_size / 1024
        print(f'  {Path(f).name:<40} {size:>8.1f} KB')
    else:
        print(f'  {Path(f).name:<40}  NO ENCONTRADO')

print('=' * 55)
print()
print('Para Android necesitas:')
print('  1. potato_classifier.tflite  → /assets/ en el proyecto Android')
print('  2. gradcam_*.jpg             → /res/drawable/ en el proyecto Android')
print()
print('class_to_idx (para el clasificador en Kotlin):')
for cls, idx in class_to_idx.items():
    print(f'  {idx}: "{cls}"')
