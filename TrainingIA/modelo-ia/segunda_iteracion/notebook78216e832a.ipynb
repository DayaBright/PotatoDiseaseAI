# %% [markdown]
# # Entrenamiento — MobileNetV2 + TFLite
# Pipeline completo: tf.data en memoria → transfer learning → fine-tuning → exportación TFLite + GradCAM estático.
#
# **No escribe imágenes procesadas a disco.** Todo el preprocesamiento ocurre en el pipeline de tf.data durante el entrenamiento.

# %% [markdown]
# ## 1. Configuración

# %%
import os, random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from pathlib import Path
from PIL import Image, ImageOps, ImageEnhance
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

print('TensorFlow:', tf.__version__)
print('GPU disponible:', tf.config.list_physical_devices('GPU'))

# ---------------------------------------------------------
# CONFIGURACION - ajusta esta seccion
# ---------------------------------------------------------
DATASET_PATH   = Path('/kaggle/input/datasets/kevinvichicela/leaf-potato-disease')
OUTPUT_DIR     = Path('/kaggle/working')
IMG_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp', '.webp'}

IMG_SIZE       = 224
BATCH_SIZE     = 32
RANDOM_SEED    = 42
MEAN_SAMPLE_N  = 500

# Desbalance y oversampling (solo train)
OVERSAMPLE_ENABLED       = True
IMBALANCE_TRIGGER_RATIO  = 1.5   # activar oversampling si max/min supera este valor
OVERSAMPLE_TO_MAX_FRAC   = 0.80  # objetivo por clase minoritaria = 80% de la clase mayor
MAX_OVERSAMPLE_MULTIPLER = 3.0   # no duplicar mas de 3x una clase

# Hiperparametros fase 1 (base congelada)
LR_PHASE1      = 1e-3
EPOCHS_PHASE1  = 15

# Hiperparametros fase 2 (fine-tuning)
LR_PHASE2      = 1e-4
EPOCHS_PHASE2  = 20
UNFREEZE_FROM  = 100

# Pérdida para controlar desbalance
USE_FOCAL_LOSS = True
FOCAL_GAMMA    = 2.0
LABEL_SMOOTHING = 0.05

# Split
TRAIN_RATIO    = 0.70
VAL_RATIO      = 0.15
# TEST_RATIO   = 0.15 (implicito)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print('Configuracion cargada.')
# Out:
# TensorFlow: 2.19.0
# GPU disponible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Configuracion cargada.

# %% [markdown]
# ## 2. Inventario, split estratificado y diagnostico de desbalance

# %%
records = []
for class_dir in sorted(DATASET_PATH.iterdir()):
    if not class_dir.is_dir():
        continue
    for img_path in class_dir.iterdir():
        if img_path.suffix.lower() in IMG_EXTENSIONS:
            records.append({'class': class_dir.name, 'path': str(img_path)})

classes      = sorted(set(r['class'] for r in records))
class_to_idx = {c: i for i, c in enumerate(classes)}
idx_to_class = {i: c for c, i in class_to_idx.items()}
NUM_CLASSES  = len(classes)

paths  = [r['path'] for r in records]
labels = [r['class'] for r in records]

# Split estratificado en dos pasos
train_paths, temp_paths, train_labels, temp_labels = train_test_split(
    paths, labels, test_size=VAL_RATIO * 2,
    stratify=labels, random_state=RANDOM_SEED
)
val_paths, test_paths, val_labels, test_labels = train_test_split(
    temp_paths, temp_labels, test_size=0.5,
    stratify=temp_labels, random_state=RANDOM_SEED
)

print(f'Clases ({NUM_CLASSES}): {classes}')
print(f'Train: {len(train_paths)} | Val: {len(val_paths)} | Test: {len(test_paths)}')


def summarize_split(split_labels, split_name):
    counts = Counter(split_labels)
    vals = np.array([counts[c] for c in classes], dtype=np.int32)
    max_count = int(vals.max())
    min_count = int(vals.min())
    ratio = (max_count / min_count) if min_count > 0 else float('inf')
    print(f'[{split_name}] max={max_count} | min={min_count} | ratio max/min={ratio:.2f}')
    for c in classes:
        print(f'  - {c:<20} {counts[c]:>5}')
    return counts, ratio

print('\nDiagnostico de desbalance por split:')
train_count, train_imbalance_ratio = summarize_split(train_labels, 'Train')
_, _ = summarize_split(val_labels, 'Val')
_, _ = summarize_split(test_labels, 'Test')


def build_oversample_plan(counts):
    max_count = max(counts.values())
    target = int(max_count * OVERSAMPLE_TO_MAX_FRAC)
    plan = {}

    if (not OVERSAMPLE_ENABLED) or (train_imbalance_ratio <= IMBALANCE_TRIGGER_RATIO):
        return plan

    for cls in classes:
        n = counts[cls]
        if n >= target:
            continue
        capped_target = min(target, int(round(n * MAX_OVERSAMPLE_MULTIPLER)))
        if capped_target > n:
            plan[cls] = capped_target
    return plan

oversample_plan = build_oversample_plan(train_count)

print('\nPlan de oversampling (solo train):')
if oversample_plan:
    for cls in classes:
        if cls in oversample_plan:
            print(f'  - {cls}: {train_count[cls]} -> {oversample_plan[cls]}')
else:
    print('  No se aplicara oversampling (dataset suficientemente balanceado o desactivado).')
# Out:
# Clases (7): ['early_blight', 'healthy', 'late_blight', 'leafroll_virus', 'mosaic_virus', 'nematode', 'pest']
# Train: 6734 | Val: 1443 | Test: 1443
#
# Diagnostico de desbalance por split:
# [Train] max=2087 | min=396 | ratio max/min=5.27
#   - early_blight          2087
#   - healthy                853
#   - late_blight           1767
#   - leafroll_virus         396
#   - mosaic_virus           463
#   - nematode               564
#   - pest                   604
# [Val] max=447 | min=85 | ratio max/min=5.26
#   - early_blight           447
#   - healthy                182
#   - late_blight            379
#   - leafroll_virus          85
#   - mosaic_virus           100
#   - nematode               120
#   - pest                   130
# [Test] max=447 | min=85 | ratio max/min=5.26
#   - early_blight           447
#   - healthy                183
#   - late_blight            379
#   - leafroll_virus          85
#   - mosaic_virus            99
#   - nematode               121
#   - pest                   129
#
# Plan de oversampling (solo train):
#   - healthy: 853 -> 1669
#   - leafroll_virus: 396 -> 1188
#   - mosaic_virus: 463 -> 1389
#   - nematode: 564 -> 1669
#   - pest: 604 -> 1669

# %% [markdown]
# ## 3. Color medio del dataset (para padding)

# %%
sample_paths = random.sample(paths, min(MEAN_SAMPLE_N, len(paths)))
r_vals, g_vals, b_vals = [], [], []
for p in sample_paths:
    try:
        arr = np.array(Image.open(p).convert('RGB').resize((64, 64)))
        r_vals.append(arr[:,:,0].mean())
        g_vals.append(arr[:,:,1].mean())
        b_vals.append(arr[:,:,2].mean())
    except Exception:
        pass

MEAN_COLOR = (
    int(round(np.mean(r_vals))),
    int(round(np.mean(g_vals))),
    int(round(np.mean(b_vals)))
)
print(f'Color medio del dataset (RGB): {MEAN_COLOR}')
# Out:
# Color medio del dataset (RGB): (115, 127, 96)

# %% [markdown]
# ## 4. Funciones de preprocesamiento y augmentation

# %%
def letterbox_pil(img: Image.Image) -> Image.Image:
    """Padding con color medio → imagen cuadrada, sin deformar."""
    img  = img.convert('RGB')
    w, h = img.size
    side = max(w, h)
    pl   = (side - w) // 2
    pt   = (side - h) // 2
    img  = ImageOps.expand(img, border=(pl, pt, side-w-pl, side-h-pt), fill=MEAN_COLOR)
    return img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)

def augment_pil(img: Image.Image) -> Image.Image:
    """Augmentation estándar + efectos climáticos simples (solo para train)."""
    # Geométricas
    if random.random() < 0.5:
        img = ImageOps.mirror(img)
    if random.random() < 0.3:
        img = ImageOps.flip(img)
    img = img.rotate(random.uniform(-20, 20), fillcolor=MEAN_COLOR, expand=False)
    # Zoom
    zf  = random.uniform(0.85, 1.0)
    w, h = img.size
    nw, nh = int(w*zf), int(h*zf)
    l, t = (w-nw)//2, (h-nh)//2
    img = img.crop((l, t, l+nw, t+nh)).resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
    # Fotométricas
    img = ImageEnhance.Brightness(img).enhance(random.uniform(0.70, 1.30))
    img = ImageEnhance.Contrast(img).enhance(random.uniform(0.75, 1.25))
    img = ImageEnhance.Color(img).enhance(random.uniform(0.80, 1.20))
    # Efecto climático leve (niebla: blend con blanco)
    if random.random() < 0.15:
        fog = Image.new('RGB', img.size, (220, 220, 220))
        img = Image.blend(img, fog, alpha=random.uniform(0.05, 0.20))
    return img

def load_and_preprocess(path: str, label: int,
                         augment: bool = False) -> tuple:
    """Carga, letterbox, opcional augment, normalización MobileNetV2."""
    img = Image.open(path)
    img = letterbox_pil(img)
    if augment:
        img = augment_pil(img)
    arr = np.array(img, dtype=np.float32)
    # Normalización específica de MobileNetV2: [-1, 1]
    arr = tf.keras.applications.mobilenet_v2.preprocess_input(arr)
    return arr, label

print('Funciones de preprocesamiento listas.')
# Out:
# Funciones de preprocesamiento listas.

# %% [markdown]
# ## 5. Pipeline tf.data con augmentation en memoria

# %%
def build_augmented_train_lists():
    """
    Expande solo clases minoritarias segun oversample_plan.
    Duplica paths solo en train; el augment visual se aplica en cada epoch.
    """
    count = Counter(train_labels)
    aug_paths, aug_labels = list(train_paths), list(train_labels)

    if not oversample_plan:
        return aug_paths, aug_labels

    for cls in classes:
        target = oversample_plan.get(cls)
        if target is None:
            continue

        n = count[cls]
        needed = target - n
        if needed <= 0:
            continue

        cls_pool = [p for p, l in zip(train_paths, train_labels) if l == cls]
        extras = random.choices(cls_pool, k=needed)
        aug_paths.extend(extras)
        aug_labels.extend([cls] * needed)
        print(f'  {cls}: {n} -> {n + needed}')

    return aug_paths, aug_labels

print('Construyendo listas de train con oversampling + augmentation...')
aug_train_paths, aug_train_labels = build_augmented_train_lists()
aug_train_idx = [class_to_idx[l] for l in aug_train_labels]
val_idx       = [class_to_idx[l] for l in val_labels]
test_idx      = [class_to_idx[l] for l in test_labels]

# Shuffle antes de crear el dataset
combined = list(zip(aug_train_paths, aug_train_idx))
random.shuffle(combined)
aug_train_paths, aug_train_idx = zip(*combined)

print(f'Train original: {len(train_paths)}')
print(f'Train final (oversampling): {len(aug_train_paths)}')


def make_dataset(paths_list, labels_list, augment=False, cache=False):
    def load_fn(path, label):
        arr, lbl = tf.py_function(
            func=lambda p, l: load_and_preprocess(
                p.numpy().decode(), int(l.numpy()), augment),
            inp=[path, label],
            Tout=[tf.float32, tf.int32]
        )
        arr.set_shape([IMG_SIZE, IMG_SIZE, 3])
        lbl.set_shape([])
        return arr, lbl

    ds = tf.data.Dataset.from_tensor_slices(
        (list(paths_list), list(labels_list))
    )
    if augment:
        ds = ds.shuffle(buffer_size=2000, seed=RANDOM_SEED)
    ds = ds.map(load_fn, num_parallel_calls=tf.data.AUTOTUNE)
    if cache:
        ds = ds.cache()
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

# Oversampling y augmentation solo en train
train_ds = make_dataset(aug_train_paths, aug_train_idx, augment=True)
val_ds   = make_dataset(val_paths,  val_idx,  augment=False, cache=True)
test_ds  = make_dataset(test_paths, test_idx, augment=False, cache=True)

print('Datasets listos.')
print(f'Steps por epoch: {math.ceil(len(aug_train_paths) / BATCH_SIZE)}')
# Out:
# Construyendo listas de train con oversampling + augmentation...
#   healthy: 853 -> 1669
#   leafroll_virus: 396 -> 1188
#   mosaic_virus: 463 -> 1389
#   nematode: 564 -> 1669
#   pest: 604 -> 1669
# Train original: 6734
# Train final (oversampling): 11438
# I0000 00:00:1776130317.813469      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Datasets listos.
# Steps por epoch: 358

# %% [markdown]
# ## 6. Construcción del modelo — MobileNetV2

# %%
def build_model(num_classes: int, trainable_base: bool = False):
    base = tf.keras.applications.MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights='imagenet'
    )
    base.trainable = trainable_base

    inputs  = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x       = base(inputs, training=False)
    x       = tf.keras.layers.GlobalAveragePooling2D()(x)
    x       = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model, base

model, base_model = build_model(NUM_CLASSES, trainable_base=False)
model.summary(line_length=80)
print(f'\nCapas en base: {len(base_model.layers)}')
print(f'Parámetros entrenables: {model.trainable_variables.__len__()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224 (Functional) │ (None, 7, 7, 1280)       │     2,257,984 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 1280)             │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dropout (Dropout)                 │ (None, 1280)             │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 7)                │         8,967 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 2,266,951 (8.65 MB)
#  Trainable params: 8,967 (35.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Capas en base: 154
# Parámetros entrenables: 2

# %% [markdown]
# ## 7. Estrategia anti-desbalance: class_weight + focal loss

# %%
# class_weight sobre train original (sin duplicados de oversampling)
train_idx_orig = np.array([class_to_idx[l] for l in train_labels], dtype=np.int32)

weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=train_idx_orig
)
class_weight_dict = {i: float(w) for i, w in enumerate(weights)}

# alpha por clase para focal loss (normalizado)
alpha_vector = (weights / np.sum(weights)).astype(np.float32)

print('class_weight_dict:')
for i, cls in enumerate(classes):
    print(f'  {i} ({cls}): {weights[i]:.4f}')


def sparse_categorical_focal_loss(alpha, gamma=2.0, label_smoothing=0.0):
    alpha = tf.constant(alpha, dtype=tf.float32)

    def loss_fn(y_true, y_pred):
        y_true_int = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_true_oh = tf.one_hot(y_true_int, depth=NUM_CLASSES, dtype=tf.float32)

        if label_smoothing > 0.0:
            y_true_oh = y_true_oh * (1.0 - label_smoothing) + (label_smoothing / NUM_CLASSES)

        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        ce = -tf.reduce_sum(y_true_oh * tf.math.log(y_pred), axis=-1)
        p_t = tf.reduce_sum(y_true_oh * y_pred, axis=-1)
        focal_factor = tf.pow(1.0 - p_t, gamma)
        alpha_t = tf.reduce_sum(y_true_oh * alpha, axis=-1)

        return tf.reduce_mean(alpha_t * focal_factor * ce)

    return loss_fn

if USE_FOCAL_LOSS:
    training_loss = sparse_categorical_focal_loss(
        alpha=alpha_vector,
        gamma=FOCAL_GAMMA,
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: Focal loss (gamma={FOCAL_GAMMA}, label_smoothing={LABEL_SMOOTHING})')
else:
    training_loss = tf.keras.losses.SparseCategoricalCrossentropy(
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: SparseCategoricalCrossentropy (label_smoothing={LABEL_SMOOTHING})')
# Out:
# class_weight_dict:
#   0 (early_blight): 0.4609
#   1 (healthy): 1.1278
#   2 (late_blight): 0.5444
#   3 (leafroll_virus): 2.4293
#   4 (mosaic_virus): 2.0778
#   5 (nematode): 1.7057
#   6 (pest): 1.5927
# Loss activa: Focal loss (gamma=2.0, label_smoothing=0.05)

# %% [markdown]
# ## 8. Fase 1 — Entrenamiento con base congelada
# Solo se entrenan las capas densas superiores. La base MobileNetV2 actúa como extractor de características fijo.

# %%
callbacks_phase1 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=5,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=3, min_lr=1e-6, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase1.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE1),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 1 ({EPOCHS_PHASE1} epocas max., base congelada)...')
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE1,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase1,
    verbose=1
)
# Out:
# Iniciando fase 1 (15 epocas max., base congelada)...
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776130326.914813     122 service.cc:152] XLA service 0x7af85010ffa0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776130326.914856     122 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1776130329.205486     122 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1776130336.048786     122 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.5988 - loss: 0.1165
# Epoch 1: val_accuracy improved from -inf to 0.81220, saving model to /kaggle/working/best_phase1.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 191s 492ms/step - accuracy: 0.5992 - loss: 0.1164 - val_accuracy: 0.8122 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 2/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.8519 - loss: 0.0326
# Epoch 2: val_accuracy improved from 0.81220 to 0.84685, saving model to /kaggle/working/best_phase1.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 142s 398ms/step - accuracy: 0.8519 - loss: 0.0326 - val_accuracy: 0.8468 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 3/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.8738 - loss: 0.0268
# Epoch 3: val_accuracy improved from 0.84685 to 0.86625, saving model to /kaggle/working/best_phase1.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 142s 396ms/step - accuracy: 0.8738 - loss: 0.0268 - val_accuracy: 0.8663 - val_loss: 0.0154 - learning_rate: 0.0010
# Epoch 4/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.8814 - loss: 0.0242
# Epoch 4: val_accuracy did not improve from 0.86625
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 152s 424ms/step - accuracy: 0.8814 - loss: 0.0242 - val_accuracy: 0.8496 - val_loss: 0.0171 - learning_rate: 0.0010
# Epoch 5/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.8908 - loss: 0.0216
# Epoch 5: val_accuracy improved from 0.86625 to 0.89397, saving model to /kaggle/working/best_phase1.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 143s 400ms/step - accuracy: 0.8908 - loss: 0.0216 - val_accuracy: 0.8940 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 6/15
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8918 - loss: 0.0207
# Epoch 6: val_accuracy did not improve from 0.89397
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.8918 - loss: 0.0207 - val_accuracy: 0.8933 - val_loss: 0.0120 - learning_rate: 0.0010
# Epoch 7/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.8915 - loss: 0.0210
# Epoch 7: val_accuracy did not improve from 0.89397
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 137s 381ms/step - accuracy: 0.8915 - loss: 0.0210 - val_accuracy: 0.8863 - val_loss: 0.0135 - learning_rate: 0.0010
# Epoch 8/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.8930 - loss: 0.0209
# Epoch 8: val_accuracy improved from 0.89397 to 0.90714, saving model to /kaggle/working/best_phase1.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 137s 381ms/step - accuracy: 0.8930 - loss: 0.0209 - val_accuracy: 0.9071 - val_loss: 0.0120 - learning_rate: 0.0010
# Epoch 9/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.8997 - loss: 0.0203
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_accuracy did not improve from 0.90714
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 138s 386ms/step - accuracy: 0.8997 - loss: 0.0203 - val_accuracy: 0.8870 - val_loss: 0.0133 - learning_rate: 0.0010
# Epoch 10/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9051 - loss: 0.0177
# Epoch 10: val_accuracy did not improve from 0.90714
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 137s 382ms/step - accuracy: 0.9050 - loss: 0.0177 - val_accuracy: 0.8940 - val_loss: 0.0119 - learning_rate: 5.0000e-04
# Epoch 11/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.9027 - loss: 0.0187
# Epoch 11: val_accuracy did not improve from 0.90714
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 148s 398ms/step - accuracy: 0.9027 - loss: 0.0187 - val_accuracy: 0.8773 - val_loss: 0.0139 - learning_rate: 5.0000e-04
# Epoch 12/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9043 - loss: 0.0180
# Epoch 12: val_accuracy did not improve from 0.90714
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 141s 394ms/step - accuracy: 0.9043 - loss: 0.0180 - val_accuracy: 0.8988 - val_loss: 0.0119 - learning_rate: 5.0000e-04
# Epoch 13/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9040 - loss: 0.0183
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 13: val_accuracy did not improve from 0.90714
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 139s 388ms/step - accuracy: 0.9040 - loss: 0.0183 - val_accuracy: 0.8884 - val_loss: 0.0124 - learning_rate: 5.0000e-04
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %% [markdown]
# ## 9. Fase 2 — Fine-tuning
# Se descongelan las últimas capas de la base (desde `UNFREEZE_FROM` en adelante) con learning rate reducido.

# %%
base_model.trainable = True
for layer in base_model.layers[:UNFREEZE_FROM]:
    layer.trainable = False

trainable_count = sum(1 for l in base_model.layers if l.trainable)
print(f'Capas descongeladas en base: {trainable_count} / {len(base_model.layers)}')

callbacks_phase2 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=7,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=3, min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase2.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE2),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 2 ({EPOCHS_PHASE2} epocas max., fine-tuning)...')
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE2,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase2,
    initial_epoch=len(history1.history['loss']),
    verbose=1
)
# Out:
# Capas descongeladas en base: 54 / 154
# Iniciando fase 2 (20 epocas max., fine-tuning)...
# Epoch 14/20
# 2026-04-14 02:03:50.866746: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-14 02:03:51.063365: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 357/358 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.8314 - loss: 0.0507
# 2026-04-14 02:06:15.072616: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-14 02:06:15.268317: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.8315 - loss: 0.0507
# Epoch 14: val_accuracy improved from -inf to 0.74220, saving model to /kaggle/working/best_phase2.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 176s 427ms/step - accuracy: 0.8317 - loss: 0.0506 - val_accuracy: 0.7422 - val_loss: 0.0746 - learning_rate: 1.0000e-04
# Epoch 15/20
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9296 - loss: 0.0135
# Epoch 15: val_accuracy improved from 0.74220 to 0.79764, saving model to /kaggle/working/best_phase2.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 139s 388ms/step - accuracy: 0.9296 - loss: 0.0135 - val_accuracy: 0.7976 - val_loss: 0.0620 - learning_rate: 1.0000e-04
# Epoch 16/20
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9439 - loss: 0.0095
# Epoch 16: val_accuracy improved from 0.79764 to 0.87318, saving model to /kaggle/working/best_phase2.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 138s 386ms/step - accuracy: 0.9439 - loss: 0.0095 - val_accuracy: 0.8732 - val_loss: 0.0313 - learning_rate: 1.0000e-04
# Epoch 17/20
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9572 - loss: 0.0073
# Epoch 17: val_accuracy improved from 0.87318 to 0.93971, saving model to /kaggle/working/best_phase2.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 141s 392ms/step - accuracy: 0.9572 - loss: 0.0073 - val_accuracy: 0.9397 - val_loss: 0.0115 - learning_rate: 1.0000e-04
# Epoch 18/20
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9623 - loss: 0.0059
# Epoch 18: val_accuracy improved from 0.93971 to 0.95911, saving model to /kaggle/working/best_phase2.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 139s 388ms/step - accuracy: 0.9623 - loss: 0.0059 - val_accuracy: 0.9591 - val_loss: 0.0074 - learning_rate: 1.0000e-04
# Epoch 19/20
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9700 - loss: 0.0047
# Epoch 19: val_accuracy improved from 0.95911 to 0.96604, saving model to /kaggle/working/best_phase2.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 142s 395ms/step - accuracy: 0.9700 - loss: 0.0047 - val_accuracy: 0.9660 - val_loss: 0.0070 - learning_rate: 1.0000e-04
# Epoch 20/20
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9714 - loss: 0.0045
# Epoch 20: val_accuracy improved from 0.96604 to 0.97089, saving model to /kaggle/working/best_phase2.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 141s 395ms/step - accuracy: 0.9714 - loss: 0.0045 - val_accuracy: 0.9709 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 10. Curvas de entrenamiento

# %%
def plot_history(h1, h2):
    acc  = h1.history['accuracy']  + h2.history['accuracy']
    val  = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    vloss= h1.history['val_loss'] + h2.history['val_loss']
    sep  = len(h1.history['accuracy'])  # época donde empieza fase 2

    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    for ax, train_m, val_m, title in zip(
        axes,
        [acc, loss], [val, vloss],
        ['Accuracy', 'Loss']
    ):
        ax.plot(train_m, label='Train', color='steelblue')
        ax.plot(val_m,   label='Val',   color='coral')
        ax.axvline(sep, color='gray', linestyle='--', linewidth=1, label='Fine-tuning')
        ax.set_title(title)
        ax.set_xlabel('Época')
        ax.legend(fontsize=8)
        ax.spines[['top','right']].set_visible(False)

    plt.suptitle('Curvas de entrenamiento — fase 1 + fase 2', fontsize=11)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'training_curves.png', dpi=150, bbox_inches='tight')
    plt.show()

plot_history(history1, history2)

# %% [markdown]
# ## 11. Evaluación en test — métricas completas

# %%
from sklearn.metrics import (classification_report, confusion_matrix,
                              ConfusionMatrixDisplay)

y_true, y_pred = [], []
for batch_imgs, batch_labels in test_ds:
    preds = model.predict(batch_imgs, verbose=0)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(batch_labels.numpy())

print('=' * 60)
print('REPORTE DE CLASIFICACIÓN — TEST SET')
print('=' * 60)
print(classification_report(
    y_true, y_pred,
    target_names=classes,
    digits=4
))

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(9, 7))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusión — test set', fontsize=11)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# ============================================================
# REPORTE DE CLASIFICACIÓN — TEST SET
# ============================================================
#                 precision    recall  f1-score   support
#
#   early_blight     0.9747    0.9463    0.9603       447
#        healthy     0.9381    0.9945    0.9655       183
#    late_blight     0.9761    0.9710    0.9735       379
# leafroll_virus     1.0000    1.0000    1.0000        85
#   mosaic_virus     1.0000    0.9798    0.9898        99
#       nematode     0.9917    0.9917    0.9917       121
#           pest     0.8741    0.9147    0.8939       129
#
#       accuracy                         0.9653      1443
#      macro avg     0.9650    0.9712    0.9678      1443
#   weighted avg     0.9661    0.9653    0.9655      1443

# %% [markdown]
# ## 12. Exportación a TFLite (int8)
# Cuantización post-entrenamiento. Reduce el modelo a ~14–25 MB para el APK.

# %%
# Dataset representativo para calibración int8 (100 imágenes de val)
def representative_dataset():
    count = 0
    for img_batch, _ in val_ds:
        for img in img_batch:
            yield [tf.expand_dims(img, 0)]
            count += 1
            if count >= 100:
                return

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.uint8

# Guardar el modelo base .tflite
tflite_model = converter.convert()
tflite_path = OUTPUT_DIR / 'potato_classifier.tflite'
tflite_path.write_bytes(tflite_model)

# Guardar las etiquetas aparte (ya que no se pueden incrustar directamente aquí)
labels_path = OUTPUT_DIR / 'labels.txt'
with open(labels_path, 'w') as f:
    f.write('\n'.join(classes))

size_mb = tflite_path.stat().st_size / 1_048_576
print(f'Modelo TFLite guardado: {tflite_path}')
print(f'Etiquetas guardadas en: {labels_path}')
print(f'Tamaño del modelo: {size_mb:.2f} MB')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpjatmp79z/assets
# INFO:tensorflow:Assets written to: /tmp/tmpjatmp79z/assets
# Saved artifact at '/tmp/tmpjatmp79z'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   135210022048912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022051024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022053520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022052944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022052176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022050832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022053712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022054480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022054096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022051216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022053136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022055632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022055824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022052752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022052560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022056400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022058512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022058704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022057552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022056976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022055440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022057360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022059664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022059280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022056784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022057744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022058896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022058320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022059856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022059472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022600784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022600976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022601168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022602704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022602128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022602320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022602512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022601552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022603664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022604048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022604240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022603280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022603856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022604816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022605200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022605392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022604432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022605008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022605968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022603472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022605584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022605776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022602896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022606928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022606352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022606544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022606736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022607888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022607312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022607504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022607696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022604624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022608848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022608272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022608464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022608656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022606160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022609808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022609232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022609424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022609616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022607120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022610768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022610192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022610384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022610576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022608080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022611728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022611152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022611344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022611536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022609040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022612688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022612112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022612304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022612496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022610000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022613648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022613072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022613264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022613456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022610960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022614608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022614032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022614224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022614416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022611920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022615568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022614992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022615184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022615376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022612880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022616528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022615952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022613840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022616720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022616144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022616912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022616336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002235856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022614800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210022615760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002236624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002235664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002237776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002237200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002237584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002238736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002238160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002236240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002239120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002239312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002239504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002240656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002240272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002240464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002237968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002241616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002241040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002241232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002241424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002238928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002242000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002242192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002242384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002239888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002242960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002243152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002241808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002245072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002246416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002245840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002246992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002247184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002244688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002248336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002248720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002246608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002250256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002249680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002250640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002248528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002250832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002251600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002251024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001024016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001023440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002249488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210002250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001023056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001024208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001024400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001023824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001025360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001024784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001024976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001025168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001023248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001026320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001025744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001025936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001026128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001023632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001027280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001026704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001026896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001027088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001024592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001027856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001028048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001025552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001029200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001028624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001028816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001026512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001030160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001029584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001029776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001029968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001027472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001031120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001030544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001030736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001030928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001028432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001031696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001031888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001029392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001033040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001032464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001032656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001032848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001030352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001034000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001033424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001033808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001031312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001034576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001032272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001035920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001035152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135210001036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1776133266.750448      55 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1776133266.750530      55 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1776133266.902645      55 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Modelo TFLite guardado: /kaggle/working/potato_classifier.tflite
# Etiquetas guardadas en: /kaggle/working/labels.txt
# Tamaño del modelo: 2.59 MB
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %%
from sklearn.metrics import accuracy_score

# Cargar el modelo TFLite exportado
interpreter = tf.lite.Interpreter(model_path=str(tflite_path))
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

in_scale, in_zero_point = input_details['quantization']
out_scale, out_zero_point = output_details['quantization']

print('Entrada TFLite:', input_details['dtype'], input_details['shape'], input_details['quantization'])
print('Salida TFLite :', output_details['dtype'], output_details['shape'], output_details['quantization'])


def run_tflite_int8_single(img_float_m1_1):
    """
    img_float_m1_1: np.ndarray [H,W,3] normalizada en [-1, 1]
    Retorna probs float32 des-cuantizadas.
    """
    x = np.expand_dims(img_float_m1_1, axis=0).astype(np.float32)

    # Cuantizar entrada float -> uint8 usando parametros del tensor de entrada
    if in_scale > 0:
        x_q = np.round(x / in_scale + in_zero_point)
    else:
        x_q = x
    x_q = np.clip(x_q, 0, 255).astype(np.uint8)

    interpreter.set_tensor(input_details['index'], x_q)
    interpreter.invoke()
    y_q = interpreter.get_tensor(output_details['index'])

    # Des-cuantizar salida uint8 -> float
    if out_scale > 0:
        y = (y_q.astype(np.float32) - out_zero_point) * out_scale
    else:
        y = y_q.astype(np.float32)

    return y[0]


# Evaluacion del TFLite en el mismo test set
y_true_tflite, y_pred_tflite = [], []
for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    probs = run_tflite_int8_single(arr)
    pred_idx = int(np.argmax(probs))

    y_true_tflite.append(true_idx)
    y_pred_tflite.append(pred_idx)

acc_tflite = accuracy_score(y_true_tflite, y_pred_tflite)

# Accuracy Keras float ya calculada antes (si no existe, la recalculamos rapido)
if 'y_true' in globals() and 'y_pred' in globals() and len(y_true) == len(y_pred):
    acc_keras = accuracy_score(y_true, y_pred)
else:
    y_true_keras, y_pred_keras = [], []
    for batch_imgs, batch_labels in test_ds:
        preds = model.predict(batch_imgs, verbose=0)
        y_pred_keras.extend(np.argmax(preds, axis=1))
        y_true_keras.extend(batch_labels.numpy())
    acc_keras = accuracy_score(y_true_keras, y_pred_keras)

print('\n' + '=' * 65)
print('COMPARACION DE ACCURACY EN TEST')
print('=' * 65)
print(f'Keras (float32): {acc_keras:.4f}')
print(f'TFLite (int8) : {acc_tflite:.4f}')
print(f'Delta (int8 - float): {acc_tflite - acc_keras:+.4f}')
print('=' * 65)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Entrada TFLite: <class 'numpy.uint8'> [  1 224 224   3] (0.007843137718737125, 127)
# Salida TFLite : <class 'numpy.uint8'> [1 7] (0.00390625, 0)
#
# =================================================================
# COMPARACION DE ACCURACY EN TEST
# =================================================================
# Keras (float32): 0.9653
# TFLite (int8) : 0.9570
# Delta (int8 - float): -0.0083
# =================================================================

# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# -----------------------------
# 1) Reporte de clasificacion
# -----------------------------
report_dict = classification_report(
    y_true_tflite,
    y_pred_tflite,
    target_names=classes,
    digits=4,
    output_dict=True,
    zero_division=0
)

# Tabla por clase
rows = []
for cls in classes:
    rows.append({
        'clase': cls,
        'precision': report_dict[cls]['precision'],
        'recall': report_dict[cls]['recall'],
        'f1-score': report_dict[cls]['f1-score'],
        'support': int(report_dict[cls]['support'])
    })

df_cls = pd.DataFrame(rows)

# Tabla de resumen
df_summary = pd.DataFrame([
    {
        'metrica': 'accuracy',
        'valor': float(report_dict['accuracy'])
    },
    {
        'metrica': 'macro avg precision',
        'valor': float(report_dict['macro avg']['precision'])
    },
    {
        'metrica': 'macro avg recall',
        'valor': float(report_dict['macro avg']['recall'])
    },
    {
        'metrica': 'macro avg f1-score',
        'valor': float(report_dict['macro avg']['f1-score'])
    },
    {
        'metrica': 'weighted avg precision',
        'valor': float(report_dict['weighted avg']['precision'])
    },
    {
        'metrica': 'weighted avg recall',
        'valor': float(report_dict['weighted avg']['recall'])
    },
    {
        'metrica': 'weighted avg f1-score',
        'valor': float(report_dict['weighted avg']['f1-score'])
    }
])

print('=' * 70)
print('REPORTE TFLITE (INT8) - LISTO PARA TESIS')
print('=' * 70)
print('\nMetricas globales:')
display(df_summary)
print('\nMetricas por clase:')
display(df_cls)

# -----------------------------
# 2) Matriz de confusion
# -----------------------------
cm_tflite = confusion_matrix(y_true_tflite, y_pred_tflite)

fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_tflite, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusion - Modelo TFLite int8 (Test)', fontsize=12)
plt.tight_layout()

cm_img_path = OUTPUT_DIR / 'confusion_matrix_tflite.png'
plt.savefig(cm_img_path, dpi=160, bbox_inches='tight')
plt.show()

# -----------------------------
# 3) Guardar tablas para tesis
# -----------------------------
cls_csv_path = OUTPUT_DIR / 'tflite_report_per_class.csv'
sum_csv_path = OUTPUT_DIR / 'tflite_report_summary.csv'

# Redondeo para reporte
df_cls_out = df_cls.copy()
df_cls_out[['precision', 'recall', 'f1-score']] = df_cls_out[['precision', 'recall', 'f1-score']].round(4)
df_summary_out = df_summary.copy()
df_summary_out['valor'] = df_summary_out['valor'].round(4)

df_cls_out.to_csv(cls_csv_path, index=False, encoding='utf-8-sig')
df_summary_out.to_csv(sum_csv_path, index=False, encoding='utf-8-sig')

print('\nArchivos exportados:')
print(f'  - {cls_csv_path}')
print(f'  - {sum_csv_path}')
print(f'  - {cm_img_path}')
# Out:
# ======================================================================
# REPORTE TFLITE (INT8) - LISTO PARA TESIS
# ======================================================================
#
# Metricas globales:
#                   metrica     valor
# 0                accuracy  0.957034
# 1     macro avg precision  0.957960
# 2        macro avg recall  0.964890
# 3      macro avg f1-score  0.961038
# 4  weighted avg precision  0.958206
# 5     weighted avg recall  0.957034
# 6   weighted avg f1-score  0.957210
# Metricas por clase:
#             clase  precision    recall  f1-score  support
# 0    early_blight   0.974178  0.928412  0.950745      447
# 1         healthy   0.918782  0.989071  0.952632      183
# 2     late_blight   0.960733  0.968338  0.964520      379
# 3  leafroll_virus   1.000000  1.000000  1.000000       85
# 4    mosaic_virus   1.000000  0.969697  0.984615       99
# 5        nematode   0.991736  0.991736  0.991736      121
# 6            pest   0.860294  0.906977  0.883019      129
# Archivos exportados:
#   - /kaggle/working/tflite_report_per_class.csv
#   - /kaggle/working/tflite_report_summary.csv
#   - /kaggle/working/confusion_matrix_tflite.png

# %% [markdown]
# ## 13. Generación de Grad-CAM estáticos por clase
# Se calcula el mapa de activación de la última capa conv de MobileNetV2 para una imagen
# representativa de cada clase. Estos mapas se empaquetan en el APK como recursos estáticos —
# latencia extra en inferencia: 0 ms.

# %%
import matplotlib as mpl
import numpy as np
import matplotlib as mpl
from PIL import Image

last_conv_layer = None
for layer in reversed(base_model.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_layer = layer
        break

if last_conv_layer is None:
    raise ValueError("No se encontró ninguna capa Conv2D en base_model")

print("Usando capa:", last_conv_layer.name)
print("Output shape:", last_conv_layer.output.shape)

# Submodelo interno: base_model.input → (base_model.output, conv_outputs)
# Evita el problema de Graph disconnected al no cruzar el límite base→model
base_grad_model = tf.keras.Model(
    inputs=base_model.inputs,
    outputs=[base_model.output, last_conv_layer.output]
)

# Capas superiores del modelo principal (fuera de la base)
gap_layer     = model.get_layer('global_average_pooling2d')
dropout_layer = model.get_layer('dropout')
dense_layer   = model.get_layer('dense')

# Verificación
print("\nVerificación base_grad_model:")
print("  Input shape :", base_grad_model.input_shape)
print("  Output[0]   :", base_grad_model.output[0].shape, "← base output")
print("  Output[1]   :", base_grad_model.output[1].shape, "← conv activations")


def compute_gradcam(img_array: np.ndarray, class_idx: int) -> np.ndarray:
    """Retorna heatmap normalizado [0,1] del tamaño IMG_SIZE×IMG_SIZE."""
    img_tensor = tf.cast(tf.expand_dims(img_array, 0), tf.float32)

    with tf.GradientTape() as tape:
        base_out, conv_outputs = base_grad_model(img_tensor, training=False)
        tape.watch(conv_outputs)
        # Reconstruir el forward pass de las capas superiores
        x      = gap_layer(base_out)
        x      = dropout_layer(x, training=False)
        preds  = dense_layer(x)
        class_score = preds[:, class_idx]

    grads = tape.gradient(class_score, conv_outputs)

    if grads is None:
        raise ValueError(
            f"Gradientes None para clase {class_idx}. "
            "Verificar conexión de base_grad_model."
        )

    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs[0]), axis=-1)
    cam = tf.maximum(cam, 0)
    cam_np = cam.numpy()
    cam_max = np.max(cam_np)
    cam_min = np.min(cam_np)

    
    if (cam_max - cam_min) > 1e-8:
      
        cam_np = (cam_np - cam_min) / (cam_max - cam_min)
    else:
        
        cam_np = np.zeros_like(cam_np)

    cam_img = Image.fromarray((cam_np * 255).astype(np.uint8))
    cam_img = cam_img.resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR)
    
    return np.array(cam_img) / 255.0


def overlay_heatmap(original_arr: np.ndarray,
                    heatmap: np.ndarray,
                    color_alpha: float = 0.6) -> np.ndarray: # CAMBIADO DE alpha A color_alpha
    """Superpone el heatmap coloreado (jet) sobre la imagen original."""

    orig_uint8 = ((original_arr + 1.0) * 127.5).astype(np.uint8)
    orig_img = Image.fromarray(orig_uint8).convert("RGBA")
    
    colormap = mpl.colormaps['jet']
    heatmap_rgb = (colormap(heatmap)[:, :, :3] * 255).astype(np.uint8)
    
    dynamic_alpha = np.power(heatmap, 1.5) 
    
    dynamic_alpha = dynamic_alpha * color_alpha
    
    alpha_mask_uint8 = (dynamic_alpha * 255).astype(np.uint8)
    
    rgba_heatmap_np = np.dstack((heatmap_rgb, alpha_mask_uint8))
    heatmap_img = Image.fromarray(rgba_heatmap_np, "RGBA")
    
    blended_img = Image.alpha_composite(orig_img, heatmap_img)
    
    return np.array(blended_img.convert("RGB"))

print('\nFunciones Grad-CAM listas.')
# Out:
# Usando capa: Conv_1
# Output shape: (None, 7, 7, 1280)
#
# Verificación base_grad_model:
#   Input shape : (None, 224, 224, 3)
#   Output[0]   : (None, 7, 7, 1280) ← base output
#   Output[1]   : (None, 7, 7, 1280) ← conv activations
#
# Funciones Grad-CAM listas.

# %%
# Buscar las TOP 10 imágenes de test con mayor confianza por clase
TOP_N = 5
gradcam_dir = OUTPUT_DIR / 'gradcam_static'
gradcam_dir.mkdir(exist_ok=True)

# Ahora guardamos una lista de resultados por clase, no solo uno
top_per_class = {i: [] for i in range(NUM_CLASSES)}

print("Analizando imágenes y recolectando candidatos...")
for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _   = load_and_preprocess(path, true_idx, augment=False)
    preds    = model.predict(np.expand_dims(arr, 0), verbose=0)[0]
    pred_idx = np.argmax(preds)
    conf     = float(preds[pred_idx])
    
    # Solo candidatos correctamente clasificados y evitando la saturación del 1.0 absoluto
    if pred_idx == true_idx and conf < 0.99:
        top_per_class[true_idx].append({'conf': conf, 'path': path, 'arr': arr})

# Generar y guardar los Grad-CAM en la carpeta
print(f"\nGenerando y guardando las mejores {TOP_N} imágenes por clase...")
for cls_idx, cls_name in enumerate(classes):
    
    # Ordenamos todas las imágenes de esta clase de mayor a menor confianza
    # y nos quedamos solo con la cantidad definida en TOP_N
    candidates = sorted(top_per_class[cls_idx], key=lambda x: x['conf'], reverse=True)[:TOP_N]
    
    if not candidates:
        print(f'  AVISO: no se encontraron imágenes para {cls_name}')
        continue
        
    print(f"  -> Guardando {len(candidates)} opciones para {cls_name}...")
    
    for rank, info in enumerate(candidates):
        arr     = info['arr']
        heatmap = compute_gradcam(arr, cls_idx)
        overlay = overlay_heatmap(arr, heatmap)

        # Guardar directamente la imagen procesada con un nombre descriptivo
        # Ejemplo: gradcam_late_blight_top1_conf0.985.jpg
        filename = f'gradcam_{cls_name}_top{rank+1}_conf{info["conf"]:.3f}.jpg'
        out_path = gradcam_dir / filename
        Image.fromarray(overlay).save(str(out_path), quality=90)

print(f'\n¡Proceso terminado!')
print(f'Ve al panel derecho de Kaggle, entra a la carpeta: {gradcam_dir}')
print('Ahí tendrás todas las imágenes listas para descargar y elegir la mejor.')
# Out:
# Analizando imágenes y recolectando candidatos...
#
# Generando y guardando las mejores 5 imágenes por clase...
#   -> Guardando 5 opciones para early_blight...
#   -> Guardando 5 opciones para healthy...
#   -> Guardando 5 opciones para late_blight...
#   -> Guardando 1 opciones para leafroll_virus...
#   -> Guardando 5 opciones para mosaic_virus...
#   -> Guardando 5 opciones para nematode...
#   -> Guardando 5 opciones para pest...
#
# ¡Proceso terminado!
# Ve al panel derecho de Kaggle, entra a la carpeta: /kaggle/working/gradcam_static
# Ahí tendrás todas las imágenes listas para descargar y elegir la mejor.

# %% [markdown]
# ## 14. Resumen de archivos generados

# %%
print('=' * 55)
print('ARCHIVOS GENERADOS')
print('=' * 55)

outputs = [
    OUTPUT_DIR / 'potato_classifier.tflite',
    OUTPUT_DIR / 'best_phase2.keras',
    OUTPUT_DIR / 'training_curves.png',
    OUTPUT_DIR / 'confusion_matrix.png',
    OUTPUT_DIR / 'gradcam_all_classes.png',
]
outputs += list(gradcam_dir.glob('*.jpg'))

for f in outputs:
    if Path(f).exists():
        size = Path(f).stat().st_size / 1024
        print(f'  {Path(f).name:<40} {size:>8.1f} KB')
    else:
        print(f'  {Path(f).name:<40}  NO ENCONTRADO')

print('=' * 55)
print()
print('Para Android necesitas:')
print('  1. potato_classifier.tflite  → /assets/ en el proyecto Android')
print('  2. gradcam_*.jpg             → /res/drawable/ en el proyecto Android')
print()
print('class_to_idx (para el clasificador en Kotlin):')
for cls, idx in class_to_idx.items():
    print(f'  {idx}: "{cls}"')
# Out:
# =======================================================
# ARCHIVOS GENERADOS
# =======================================================
#   potato_classifier.tflite                   2654.9 KB
#   best_phase2.keras                         24080.5 KB
#   training_curves.png                         100.4 KB
#   confusion_matrix.png                         85.5 KB
#   gradcam_all_classes.png                   NO ENCONTRADO
#   gradcam_pest_top5_conf0.989.jpg              14.8 KB
#   gradcam_mosaic_virus_top4_conf0.980.jpg      11.7 KB
#   gradcam_nematode_top3_conf0.986.jpg          13.0 KB
#   gradcam_pest_top4_conf0.989.jpg              14.0 KB
#   gradcam_late_blight_top3_conf0.989.jpg       19.6 KB
#   gradcam_mosaic_virus_top2_conf0.986.jpg      11.7 KB
#   gradcam_early_blight_top5_conf0.989.jpg      17.5 KB
#   gradcam_late_blight_top5_conf0.989.jpg       16.9 KB
#   gradcam_pest_top2_conf0.989.jpg              15.6 KB
#   gradcam_pest_top1_conf0.990.jpg              18.0 KB
#   gradcam_mosaic_virus_top5_conf0.976.jpg      10.3 KB
#   gradcam_healthy_top1_conf0.990.jpg           19.0 KB
#   gradcam_healthy_top3_conf0.989.jpg           15.8 KB
#   gradcam_early_blight_top1_conf0.990.jpg       9.6 KB
#   gradcam_late_blight_top2_conf0.990.jpg       16.1 KB
#   gradcam_healthy_top4_conf0.988.jpg           19.5 KB
#   gradcam_nematode_top5_conf0.984.jpg          14.8 KB
#   gradcam_early_blight_top3_conf0.989.jpg      19.6 KB
#   gradcam_healthy_top5_conf0.987.jpg           20.0 KB
#   gradcam_early_blight_top4_conf0.989.jpg      21.2 KB
#   gradcam_nematode_top2_conf0.986.jpg          17.1 KB
#   gradcam_pest_top3_conf0.989.jpg              16.5 KB
#   gradcam_mosaic_virus_top1_conf0.987.jpg       8.6 KB
#   gradcam_leafroll_virus_top1_conf0.969.jpg      9.0 KB
#   gradcam_nematode_top4_conf0.984.jpg          14.7 KB
#   gradcam_healthy_top2_conf0.989.jpg           15.5 KB
#   gradcam_late_blight_top1_conf0.990.jpg       14.8 KB
#   gradcam_nematode_top1_conf0.987.jpg          15.4 KB
#   gradcam_mosaic_virus_top3_conf0.981.jpg      12.5 KB
#   gradcam_early_blight_top2_conf0.990.jpg      13.5 KB
#   gradcam_late_blight_top4_conf0.989.jpg       19.4 KB
# =======================================================
#
# Para Android necesitas:
#   1. potato_classifier.tflite  → /assets/ en el proyecto Android
#   2. gradcam_*.jpg             → /res/drawable/ en el proyecto Android
#
# class_to_idx (para el clasificador en Kotlin):
#   0: "early_blight"
#   1: "healthy"
#   2: "late_blight"
#   3: "leafroll_virus"
#   4: "mosaic_virus"
#   5: "nematode"
#   6: "pest"
