# %% [markdown]
# # Entrenamiento — MobileNetV2 + TFLite
# Pipeline completo: tf.data en memoria → transfer learning → fine-tuning → exportación TFLite + GradCAM estático.
#
# **No escribe imágenes procesadas a disco.** Todo el preprocesamiento ocurre en el pipeline de tf.data durante el entrenamiento.

# %% [markdown]
# ## 1. Configuración

# %%
import os, random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from pathlib import Path
from PIL import Image, ImageOps, ImageEnhance
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

print('TensorFlow:', tf.__version__)
print('GPU disponible:', tf.config.list_physical_devices('GPU'))

# ---------------------------------------------------------
# CONFIGURACION - ajusta esta seccion
# ---------------------------------------------------------
DATASET_PATH   = Path('/kaggle/input/datasets/kevinvichicela/dataset1-1')
OUTPUT_DIR     = Path('/kaggle/working')
IMG_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp', '.webp'}

IMG_SIZE       = 224
BATCH_SIZE     = 32
RANDOM_SEED    = 42
MEAN_SAMPLE_N  = 500

# Desbalance y oversampling (solo train)
OVERSAMPLE_ENABLED       = True
IMBALANCE_TRIGGER_RATIO  = 1.5   # activar oversampling si max/min supera este valor
OVERSAMPLE_TO_MAX_FRAC   = 0.80  # objetivo por clase minoritaria = 80% de la clase mayor
MAX_OVERSAMPLE_MULTIPLER = 3.0   # no duplicar mas de 3x una clase

# Hiperparametros fase 1 (base congelada)
LR_PHASE1      = 1e-3
EPOCHS_PHASE1  = 15

# Hiperparametros fase 2 (fine-tuning)
LR_PHASE2      = 1e-4
EPOCHS_PHASE2  = 20
UNFREEZE_FROM  = 100

# Pérdida para controlar desbalance
USE_FOCAL_LOSS = True
FOCAL_GAMMA    = 2.0
LABEL_SMOOTHING = 0.05

# Split
TRAIN_RATIO    = 0.70
VAL_RATIO      = 0.15
# TEST_RATIO   = 0.15 (implicito)

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print('Configuracion cargada.')
# Out:
# 2026-04-14 04:53:48.508090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776142428.688712      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776142428.743046      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776142429.181180      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776142429.181223      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776142429.181225      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776142429.181227      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow: 2.19.0
# GPU disponible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Configuracion cargada.

# %% [markdown]
# ## 2. Inventario, split estratificado y diagnostico de desbalance

# %%
records = []
for class_dir in sorted(DATASET_PATH.iterdir()):
    if not class_dir.is_dir():
        continue
    for img_path in class_dir.iterdir():
        if img_path.suffix.lower() in IMG_EXTENSIONS:
            records.append({'class': class_dir.name, 'path': str(img_path)})

classes      = sorted(set(r['class'] for r in records))
class_to_idx = {c: i for i, c in enumerate(classes)}
idx_to_class = {i: c for c, i in class_to_idx.items()}
NUM_CLASSES  = len(classes)

paths  = [r['path'] for r in records]
labels = [r['class'] for r in records]

# Split estratificado en dos pasos
train_paths, temp_paths, train_labels, temp_labels = train_test_split(
    paths, labels, test_size=VAL_RATIO * 2,
    stratify=labels, random_state=RANDOM_SEED
)
val_paths, test_paths, val_labels, test_labels = train_test_split(
    temp_paths, temp_labels, test_size=0.5,
    stratify=temp_labels, random_state=RANDOM_SEED
)

print(f'Clases ({NUM_CLASSES}): {classes}')
print(f'Train: {len(train_paths)} | Val: {len(val_paths)} | Test: {len(test_paths)}')


def summarize_split(split_labels, split_name):
    counts = Counter(split_labels)
    vals = np.array([counts[c] for c in classes], dtype=np.int32)
    max_count = int(vals.max())
    min_count = int(vals.min())
    ratio = (max_count / min_count) if min_count > 0 else float('inf')
    print(f'[{split_name}] max={max_count} | min={min_count} | ratio max/min={ratio:.2f}')
    for c in classes:
        print(f'  - {c:<20} {counts[c]:>5}')
    return counts, ratio

print('\nDiagnostico de desbalance por split:')
train_count, train_imbalance_ratio = summarize_split(train_labels, 'Train')
_, _ = summarize_split(val_labels, 'Val')
_, _ = summarize_split(test_labels, 'Test')


def build_oversample_plan(counts):
    max_count = max(counts.values())
    target = int(max_count * OVERSAMPLE_TO_MAX_FRAC)
    plan = {}

    if (not OVERSAMPLE_ENABLED) or (train_imbalance_ratio <= IMBALANCE_TRIGGER_RATIO):
        return plan

    for cls in classes:
        n = counts[cls]
        if n >= target:
            continue
        capped_target = min(target, int(round(n * MAX_OVERSAMPLE_MULTIPLER)))
        if capped_target > n:
            plan[cls] = capped_target
    return plan

oversample_plan = build_oversample_plan(train_count)

print('\nPlan de oversampling (solo train):')
if oversample_plan:
    for cls in classes:
        if cls in oversample_plan:
            print(f'  - {cls}: {train_count[cls]} -> {oversample_plan[cls]}')
else:
    print('  No se aplicara oversampling (dataset suficientemente balanceado o desactivado).')
# Out:
# Clases (7): ['early_blight', 'healthy', 'late_blight', 'leafroll_virus', 'mosaic_virus', 'nematode', 'pest']
# Train: 6765 | Val: 1450 | Test: 1450
#
# Diagnostico de desbalance por split:
# [Train] max=2087 | min=432 | ratio max/min=4.83
#   - early_blight          2087
#   - healthy                853
#   - late_blight           1767
#   - leafroll_virus         432
#   - mosaic_virus           463
#   - nematode               563
#   - pest                   600
# [Val] max=447 | min=93 | ratio max/min=4.81
#   - early_blight           447
#   - healthy                182
#   - late_blight            379
#   - leafroll_virus          93
#   - mosaic_virus            99
#   - nematode               121
#   - pest                   129
# [Test] max=447 | min=92 | ratio max/min=4.86
#   - early_blight           447
#   - healthy                183
#   - late_blight            379
#   - leafroll_virus          92
#   - mosaic_virus           100
#   - nematode               121
#   - pest                   128
#
# Plan de oversampling (solo train):
#   - healthy: 853 -> 1669
#   - leafroll_virus: 432 -> 1296
#   - mosaic_virus: 463 -> 1389
#   - nematode: 563 -> 1669
#   - pest: 600 -> 1669

# %% [markdown]
# ## 3. Color medio del dataset (para padding)

# %%
sample_paths = random.sample(paths, min(MEAN_SAMPLE_N, len(paths)))
r_vals, g_vals, b_vals = [], [], []
for p in sample_paths:
    try:
        arr = np.array(Image.open(p).convert('RGB').resize((64, 64)))
        r_vals.append(arr[:,:,0].mean())
        g_vals.append(arr[:,:,1].mean())
        b_vals.append(arr[:,:,2].mean())
    except Exception:
        pass

MEAN_COLOR = (
    int(round(np.mean(r_vals))),
    int(round(np.mean(g_vals))),
    int(round(np.mean(b_vals)))
)
print(f'Color medio del dataset (RGB): {MEAN_COLOR}')
# Out:
# Color medio del dataset (RGB): (113, 127, 95)

# %% [markdown]
# ## 4. Funciones de preprocesamiento y augmentation

# %%
def letterbox_pil(img: Image.Image) -> Image.Image:
    """Padding con color medio → imagen cuadrada, sin deformar."""
    img  = img.convert('RGB')
    w, h = img.size
    side = max(w, h)
    pl   = (side - w) // 2
    pt   = (side - h) // 2
    img  = ImageOps.expand(img, border=(pl, pt, side-w-pl, side-h-pt), fill=MEAN_COLOR)
    return img.resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)

def augment_pil(img: Image.Image) -> Image.Image:
    """Augmentation estándar + efectos climáticos simples (solo para train)."""
    # Geométricas
    if random.random() < 0.5:
        img = ImageOps.mirror(img)
    if random.random() < 0.3:
        img = ImageOps.flip(img)
    img = img.rotate(random.uniform(-20, 20), fillcolor=MEAN_COLOR, expand=False)
    # Zoom
    zf  = random.uniform(0.85, 1.0)
    w, h = img.size
    nw, nh = int(w*zf), int(h*zf)
    l, t = (w-nw)//2, (h-nh)//2
    img = img.crop((l, t, l+nw, t+nh)).resize((IMG_SIZE, IMG_SIZE), Image.LANCZOS)
    # Fotométricas
    img = ImageEnhance.Brightness(img).enhance(random.uniform(0.70, 1.30))
    img = ImageEnhance.Contrast(img).enhance(random.uniform(0.75, 1.25))
    img = ImageEnhance.Color(img).enhance(random.uniform(0.80, 1.20))
    # Efecto climático leve (niebla: blend con blanco)
    if random.random() < 0.15:
        fog = Image.new('RGB', img.size, (220, 220, 220))
        img = Image.blend(img, fog, alpha=random.uniform(0.05, 0.20))
    return img

def load_and_preprocess(path: str, label: int,
                         augment: bool = False) -> tuple:
    """Carga, letterbox, opcional augment, normalización MobileNetV2."""
    img = Image.open(path)
    img = letterbox_pil(img)
    if augment:
        img = augment_pil(img)
    arr = np.array(img, dtype=np.float32)
    # Normalización específica de MobileNetV2: [-1, 1]
    arr = tf.keras.applications.mobilenet_v2.preprocess_input(arr)
    return arr, label

print('Funciones de preprocesamiento listas.')
# Out:
# Funciones de preprocesamiento listas.

# %% [markdown]
# ## 5. Pipeline tf.data con augmentation en memoria

# %%
def build_augmented_train_lists():
    """
    Expande solo clases minoritarias segun oversample_plan.
    Duplica paths solo en train; el augment visual se aplica en cada epoch.
    """
    count = Counter(train_labels)
    aug_paths, aug_labels = list(train_paths), list(train_labels)

    if not oversample_plan:
        return aug_paths, aug_labels

    for cls in classes:
        target = oversample_plan.get(cls)
        if target is None:
            continue

        n = count[cls]
        needed = target - n
        if needed <= 0:
            continue

        cls_pool = [p for p, l in zip(train_paths, train_labels) if l == cls]
        extras = random.choices(cls_pool, k=needed)
        aug_paths.extend(extras)
        aug_labels.extend([cls] * needed)
        print(f'  {cls}: {n} -> {n + needed}')

    return aug_paths, aug_labels

print('Construyendo listas de train con oversampling + augmentation...')
aug_train_paths, aug_train_labels = build_augmented_train_lists()
aug_train_idx = [class_to_idx[l] for l in aug_train_labels]
val_idx       = [class_to_idx[l] for l in val_labels]
test_idx      = [class_to_idx[l] for l in test_labels]

# Shuffle antes de crear el dataset
combined = list(zip(aug_train_paths, aug_train_idx))
random.shuffle(combined)
aug_train_paths, aug_train_idx = zip(*combined)

print(f'Train original: {len(train_paths)}')
print(f'Train final (oversampling): {len(aug_train_paths)}')


def make_dataset(paths_list, labels_list, augment=False, cache=False):
    def load_fn(path, label):
        arr, lbl = tf.py_function(
            func=lambda p, l: load_and_preprocess(
                p.numpy().decode(), int(l.numpy()), augment),
            inp=[path, label],
            Tout=[tf.float32, tf.int32]
        )
        arr.set_shape([IMG_SIZE, IMG_SIZE, 3])
        lbl.set_shape([])
        return arr, lbl

    ds = tf.data.Dataset.from_tensor_slices(
        (list(paths_list), list(labels_list))
    )
    if augment:
        ds = ds.shuffle(buffer_size=2000, seed=RANDOM_SEED)
    ds = ds.map(load_fn, num_parallel_calls=tf.data.AUTOTUNE)
    if cache:
        ds = ds.cache()
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

# Oversampling y augmentation solo en train
train_ds = make_dataset(aug_train_paths, aug_train_idx, augment=True)
val_ds   = make_dataset(val_paths,  val_idx,  augment=False, cache=True)
test_ds  = make_dataset(test_paths, test_idx, augment=False, cache=True)

print('Datasets listos.')
print(f'Steps por epoch: {math.ceil(len(aug_train_paths) / BATCH_SIZE)}')
# Out:
# Construyendo listas de train con oversampling + augmentation...
#   healthy: 853 -> 1669
#   leafroll_virus: 432 -> 1296
#   mosaic_virus: 463 -> 1389
#   nematode: 563 -> 1669
#   pest: 600 -> 1669
# Train original: 6765
# Train final (oversampling): 11546
# I0000 00:00:1776142462.347765      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Datasets listos.
# Steps por epoch: 361

# %% [markdown]
# ## 6. Construcción del modelo — MobileNetV2

# %%
def build_model(num_classes: int, trainable_base: bool = False):
    base = tf.keras.applications.MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights='imagenet'
    )
    base.trainable = trainable_base

    inputs  = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x       = base(inputs, training=False)
    x       = tf.keras.layers.GlobalAveragePooling2D()(x)
    x       = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model, base

model, base_model = build_model(NUM_CLASSES, trainable_base=False)
model.summary(line_length=80)
print(f'\nCapas en base: {len(base_model.layers)}')
print(f'Parámetros entrenables: {model.trainable_variables.__len__()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224 (Functional) │ (None, 7, 7, 1280)       │     2,257,984 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 1280)             │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dropout (Dropout)                 │ (None, 1280)             │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 7)                │         8,967 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 2,266,951 (8.65 MB)
#  Trainable params: 8,967 (35.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Capas en base: 154
# Parámetros entrenables: 2

# %% [markdown]
# ## 7. Estrategia anti-desbalance: class_weight + focal loss

# %%
# class_weight sobre train original (sin duplicados de oversampling)
train_idx_orig = np.array([class_to_idx[l] for l in train_labels], dtype=np.int32)

weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=train_idx_orig
)
class_weight_dict = {i: float(w) for i, w in enumerate(weights)}

# alpha por clase para focal loss (normalizado)
alpha_vector = (weights / np.sum(weights)).astype(np.float32)

print('class_weight_dict:')
for i, cls in enumerate(classes):
    print(f'  {i} ({cls}): {weights[i]:.4f}')


def sparse_categorical_focal_loss(alpha, gamma=2.0, label_smoothing=0.0):
    alpha = tf.constant(alpha, dtype=tf.float32)

    def loss_fn(y_true, y_pred):
        y_true_int = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_true_oh = tf.one_hot(y_true_int, depth=NUM_CLASSES, dtype=tf.float32)

        if label_smoothing > 0.0:
            y_true_oh = y_true_oh * (1.0 - label_smoothing) + (label_smoothing / NUM_CLASSES)

        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        ce = -tf.reduce_sum(y_true_oh * tf.math.log(y_pred), axis=-1)
        p_t = tf.reduce_sum(y_true_oh * y_pred, axis=-1)
        focal_factor = tf.pow(1.0 - p_t, gamma)
        alpha_t = tf.reduce_sum(y_true_oh * alpha, axis=-1)

        return tf.reduce_mean(alpha_t * focal_factor * ce)

    return loss_fn

if USE_FOCAL_LOSS:
    training_loss = sparse_categorical_focal_loss(
        alpha=alpha_vector,
        gamma=FOCAL_GAMMA,
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: Focal loss (gamma={FOCAL_GAMMA}, label_smoothing={LABEL_SMOOTHING})')
else:
    training_loss = tf.keras.losses.SparseCategoricalCrossentropy(
        label_smoothing=LABEL_SMOOTHING
    )
    print(f'Loss activa: SparseCategoricalCrossentropy (label_smoothing={LABEL_SMOOTHING})')
# Out:
# class_weight_dict:
#   0 (early_blight): 0.4631
#   1 (healthy): 1.1330
#   2 (late_blight): 0.5469
#   3 (leafroll_virus): 2.2371
#   4 (mosaic_virus): 2.0873
#   5 (nematode): 1.7166
#   6 (pest): 1.6107
# Loss activa: Focal loss (gamma=2.0, label_smoothing=0.05)

# %% [markdown]
# ## 8. Fase 1 — Entrenamiento con base congelada
# Solo se entrenan las capas densas superiores. La base MobileNetV2 actúa como extractor de características fijo.

# %%
callbacks_phase1 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=5,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=3, min_lr=1e-6, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase1.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE1),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 1 ({EPOCHS_PHASE1} epocas max., base congelada)...')
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE1,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase1,
    verbose=1
)
# Out:
# Iniciando fase 1 (15 epocas max., base congelada)...
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776142472.754118     121 service.cc:152] XLA service 0x7f60a003f8b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776142472.754154     121 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1776142474.794507     121 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1776142481.528495     121 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.6098 - loss: 0.1186
# Epoch 1: val_accuracy improved from -inf to 0.85034, saving model to /kaggle/working/best_phase1.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 189s 485ms/step - accuracy: 0.6102 - loss: 0.1184 - val_accuracy: 0.8503 - val_loss: 0.0220 - learning_rate: 0.0010
# Epoch 2/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.8528 - loss: 0.0338
# Epoch 2: val_accuracy did not improve from 0.85034
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 141s 391ms/step - accuracy: 0.8528 - loss: 0.0338 - val_accuracy: 0.8455 - val_loss: 0.0206 - learning_rate: 0.0010
# Epoch 3/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.8739 - loss: 0.0280
# Epoch 3: val_accuracy improved from 0.85034 to 0.86897, saving model to /kaggle/working/best_phase1.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 142s 393ms/step - accuracy: 0.8739 - loss: 0.0280 - val_accuracy: 0.8690 - val_loss: 0.0190 - learning_rate: 0.0010
# Epoch 4/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8811 - loss: 0.0242
# Epoch 4: val_accuracy improved from 0.86897 to 0.88621, saving model to /kaggle/working/best_phase1.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 146s 405ms/step - accuracy: 0.8811 - loss: 0.0242 - val_accuracy: 0.8862 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 5/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8917 - loss: 0.0235
# Epoch 5: val_accuracy did not improve from 0.88621
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 138s 382ms/step - accuracy: 0.8917 - loss: 0.0235 - val_accuracy: 0.8669 - val_loss: 0.0185 - learning_rate: 0.0010
# Epoch 6/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9022 - loss: 0.0205
# Epoch 6: val_accuracy did not improve from 0.88621
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 146s 403ms/step - accuracy: 0.9022 - loss: 0.0205 - val_accuracy: 0.8828 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 7/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8918 - loss: 0.0210
# Epoch 7: val_accuracy improved from 0.88621 to 0.90069, saving model to /kaggle/working/best_phase1.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 140s 386ms/step - accuracy: 0.8918 - loss: 0.0210 - val_accuracy: 0.9007 - val_loss: 0.0146 - learning_rate: 0.0010
# Epoch 8/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9013 - loss: 0.0207
# Epoch 8: val_accuracy did not improve from 0.90069
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 138s 382ms/step - accuracy: 0.9013 - loss: 0.0207 - val_accuracy: 0.9000 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 9/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.8971 - loss: 0.0208
# Epoch 9: val_accuracy did not improve from 0.90069
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 141s 390ms/step - accuracy: 0.8971 - loss: 0.0208 - val_accuracy: 0.8917 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 10/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9041 - loss: 0.0205
# Epoch 10: val_accuracy did not improve from 0.90069
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 137s 380ms/step - accuracy: 0.9041 - loss: 0.0205 - val_accuracy: 0.8883 - val_loss: 0.0151 - learning_rate: 0.0010
# Epoch 11/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9001 - loss: 0.0199
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_accuracy did not improve from 0.90069
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 139s 384ms/step - accuracy: 0.9001 - loss: 0.0199 - val_accuracy: 0.8800 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 12/15
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.9027 - loss: 0.0187
# Epoch 12: val_accuracy did not improve from 0.90069
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 138s 381ms/step - accuracy: 0.9027 - loss: 0.0187 - val_accuracy: 0.8876 - val_loss: 0.0155 - learning_rate: 5.0000e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %% [markdown]
# ## 9. Fase 2 — Fine-tuning
# Se descongelan las últimas capas de la base (desde `UNFREEZE_FROM` en adelante) con learning rate reducido.

# %%
base_model.trainable = True
for layer in base_model.layers[:UNFREEZE_FROM]:
    layer.trainable = False

trainable_count = sum(1 for l in base_model.layers if l.trainable)
print(f'Capas descongeladas en base: {trainable_count} / {len(base_model.layers)}')

callbacks_phase2 = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=7,
        restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.3,
        patience=3, min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        str(OUTPUT_DIR / 'best_phase2.keras'),
        monitor='val_accuracy', save_best_only=True, verbose=1
    )
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR_PHASE2),
    loss=training_loss,
    metrics=['accuracy']
)

print(f'Iniciando fase 2 ({EPOCHS_PHASE2} epocas max., fine-tuning)...')
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE2,
    class_weight=class_weight_dict,
    callbacks=callbacks_phase2,
    initial_epoch=len(history1.history['loss']),
    verbose=1
)
# Out:
# Capas descongeladas en base: 54 / 154
# Iniciando fase 2 (20 epocas max., fine-tuning)...
# Epoch 13/20
# 2026-04-14 05:23:39.728998: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-14 05:23:39.926936: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 360/361 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.8383 - loss: 0.0484
# 2026-04-14 05:26:04.470692: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-14 05:26:04.670084: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8384 - loss: 0.0484
# Epoch 13: val_accuracy improved from -inf to 0.75172, saving model to /kaggle/working/best_phase2.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 177s 428ms/step - accuracy: 0.8385 - loss: 0.0483 - val_accuracy: 0.7517 - val_loss: 0.0869 - learning_rate: 1.0000e-04
# Epoch 14/20
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9312 - loss: 0.0131
# Epoch 14: val_accuracy did not improve from 0.75172
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 141s 390ms/step - accuracy: 0.9312 - loss: 0.0131 - val_accuracy: 0.7110 - val_loss: 0.0945 - learning_rate: 1.0000e-04
# Epoch 15/20
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9470 - loss: 0.0095
# Epoch 15: val_accuracy improved from 0.75172 to 0.90828, saving model to /kaggle/working/best_phase2.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 151s 418ms/step - accuracy: 0.9470 - loss: 0.0095 - val_accuracy: 0.9083 - val_loss: 0.0192 - learning_rate: 1.0000e-04
# Epoch 16/20
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9613 - loss: 0.0069
# Epoch 16: val_accuracy improved from 0.90828 to 0.94207, saving model to /kaggle/working/best_phase2.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 141s 389ms/step - accuracy: 0.9614 - loss: 0.0069 - val_accuracy: 0.9421 - val_loss: 0.0112 - learning_rate: 1.0000e-04
# Epoch 17/20
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9683 - loss: 0.0058
# Epoch 17: val_accuracy improved from 0.94207 to 0.95034, saving model to /kaggle/working/best_phase2.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 139s 386ms/step - accuracy: 0.9683 - loss: 0.0058 - val_accuracy: 0.9503 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 18/20
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9715 - loss: 0.0049
# Epoch 18: val_accuracy improved from 0.95034 to 0.95448, saving model to /kaggle/working/best_phase2.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 147s 407ms/step - accuracy: 0.9715 - loss: 0.0049 - val_accuracy: 0.9545 - val_loss: 0.0087 - learning_rate: 1.0000e-04
# Epoch 19/20
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9776 - loss: 0.0035
# Epoch 19: val_accuracy did not improve from 0.95448
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 139s 385ms/step - accuracy: 0.9776 - loss: 0.0035 - val_accuracy: 0.9538 - val_loss: 0.0077 - learning_rate: 1.0000e-04
# Epoch 20/20
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9741 - loss: 0.0044
# Epoch 20: val_accuracy improved from 0.95448 to 0.95862, saving model to /kaggle/working/best_phase2.keras
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 140s 386ms/step - accuracy: 0.9741 - loss: 0.0044 - val_accuracy: 0.9586 - val_loss: 0.0084 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 10. Curvas de entrenamiento

# %%
def plot_history(h1, h2):
    acc  = h1.history['accuracy']  + h2.history['accuracy']
    val  = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    vloss= h1.history['val_loss'] + h2.history['val_loss']
    sep  = len(h1.history['accuracy'])  # época donde empieza fase 2

    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    for ax, train_m, val_m, title in zip(
        axes,
        [acc, loss], [val, vloss],
        ['Accuracy', 'Loss']
    ):
        ax.plot(train_m, label='Train', color='steelblue')
        ax.plot(val_m,   label='Val',   color='coral')
        ax.axvline(sep, color='gray', linestyle='--', linewidth=1, label='Fine-tuning')
        ax.set_title(title)
        ax.set_xlabel('Época')
        ax.legend(fontsize=8)
        ax.spines[['top','right']].set_visible(False)

    plt.suptitle('Curvas de entrenamiento — fase 1 + fase 2', fontsize=11)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'training_curves.png', dpi=150, bbox_inches='tight')
    plt.show()

plot_history(history1, history2)

# %% [markdown]
# ## 11. Evaluación en test — métricas completas

# %%
import pandas as pd
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

# Auditoria detallada por imagen para saber en cuales falla el modelo
records_eval = []
y_true, y_pred = [], []

for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    probs = model.predict(np.expand_dims(arr, 0), verbose=0)[0]

    pred_idx = int(np.argmax(probs))
    pred_label = idx_to_class[pred_idx]
    conf = float(probs[pred_idx])

    y_true.append(true_idx)
    y_pred.append(pred_idx)

    records_eval.append({
        'filename': Path(path).name,
        'path': path,
        'true_label': true_label,
        'pred_label': pred_label,
        'confidence': conf,
        'correct': pred_label == true_label,
    })

print('=' * 60)
print('REPORTE DE CLASIFICACION - TEST SET (KERAS FLOAT32)')
print('=' * 60)
print(classification_report(
    y_true,
    y_pred,
    target_names=classes,
    digits=4,
    zero_division=0,
))

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(9, 7))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusion - test set (Keras float32)', fontsize=11)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# Tabla completa de predicciones y subset de errores
df_test_predictions = pd.DataFrame(records_eval)
df_test_errors = (
    df_test_predictions[~df_test_predictions['correct']]
    .sort_values('confidence', ascending=False)
    .reset_index(drop=True)
)

print('\nResumen de auditoria por imagen:')
print(f"  Total evaluadas: {len(df_test_predictions)}")
print(f"  Aciertos       : {int(df_test_predictions['correct'].sum())}")
print(f"  Errores        : {len(df_test_errors)}")

print('\nPrimeras 20 predicciones:')
display(df_test_predictions.head(20))

print('\nPrimeros 30 errores (si existen):')
display(df_test_errors.head(30))

pred_csv_path = OUTPUT_DIR / 'keras_test_predictions.csv'
err_csv_path = OUTPUT_DIR / 'keras_test_errors.csv'
df_test_predictions.to_csv(pred_csv_path, index=False, encoding='utf-8-sig')
df_test_errors.to_csv(err_csv_path, index=False, encoding='utf-8-sig')

print('\nCSV exportados:')
print(f'  - {pred_csv_path}')
print(f'  - {err_csv_path}')
# Out:
# ============================================================
# REPORTE DE CLASIFICACION - TEST SET (KERAS FLOAT32)
# ============================================================
#                 precision    recall  f1-score   support
#
#   early_blight     0.9724    0.9441    0.9580       447
#        healthy     0.9663    0.9399    0.9529       183
#    late_blight     0.9836    0.9499    0.9664       379
# leafroll_virus     1.0000    0.9348    0.9663        92
#   mosaic_virus     0.9340    0.9900    0.9612       100
#       nematode     0.9756    0.9917    0.9836       121
#           pest     0.8025    0.9844    0.8842       128
#
#       accuracy                         0.9552      1450
#      macro avg     0.9478    0.9621    0.9532      1450
#   weighted avg     0.9589    0.9552    0.9559      1450
# Resumen de auditoria por imagen:
#   Total evaluadas: 1450
#   Aciertos       : 1385
#   Errores        : 65
#
# Primeras 20 predicciones:
#                          filename  \
# 0   potato cyst nematode (76).jpg
# 1                       97139.jpg
# 2                       68939.jpg
# 3                       97980.jpg
# 4                       97342.jpg
# 5         IMG_20230816_134943.jpg
# 6                    IMG_9533.JPG
# 7                    DSC_0715.JPG
# 8           early blight (56).JPG
# 9                    IMG_9467.JPG
# 10                      97433.jpg
# 11          plant pests (325).JPG
# 12                      96795.jpg
# 13        IMG_20230815_112322.jpg
# 14              1692334247364.jpg
# 15                      97022.jpg
# 16          Late_Blight (469).jpg
# 17                   DSC_0117.JPG
# 18                   IMG_8288.JPG
# 19          Late_Blight (867).jpg
#
#                                                  path      true_label  \
# 0   /kaggle/input/datasets/kevinvichicela/dataset1...        nematode
# 1   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 2   /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
# 3   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 4   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 5   /kaggle/input/datasets/kevinvichicela/dataset1...            pest
# 6   /kaggle/input/datasets/kevinvichicela/dataset1...            pest
# 7   /kaggle/input/datasets/kevinvichicela/dataset1...  leafroll_virus
# 8   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 9   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 10  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 11  /kaggle/input/datasets/kevinvichicela/dataset1...            pest
# 12  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 13  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 14  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 15  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 16  /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
# 17  /kaggle/input/datasets/kevinvichicela/dataset1...    mosaic_virus
# 18  /kaggle/input/datasets/kevinvichicela/dataset1...            pest
# 19  /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
#
#         pred_label  confidence  correct
# 0         nematode    0.999905     True
# 1     early_blight    0.947633     True
# 2      late_blight    0.944980     True
# 3     early_blight    0.999134     True
# 4     early_blight    0.921436     True
# 5             pest    0.997847     True
# 6             pest    0.999624     True
# 7   leafroll_virus    0.999941     True
# 8     early_blight    0.997603     True
# 9     early_blight    0.998146     True
# 10    early_blight    0.999846     True
# 11            pest    0.999847     True
# 12    early_blight    0.999977     True
# 13    early_blight    0.730538     True
# 14    early_blight    0.950203     True
# 15    early_blight    0.999975     True
# 16     late_blight    0.995664     True
# 17    mosaic_virus    0.999994     True
# 18            pest    0.999943     True
# 19     late_blight    0.998815     True
# Primeros 30 errores (si existen):
#                      filename  \
# 0      20230802_105507586.jpg
# 1                IMG_0240.JPG
# 2      20230802_124140776.jpg
# 3                IMG_4779.JPG
# 4       Late_Blight (259).JPG
# 5                IMG_9423.JPG
# 6           IMG_1252_aug1.jpg
# 7       Late_Blight (681).jpg
# 8                IMG_4797.JPG
# 9     IMG_20230816_122247.jpg
# 10          1692335403497.jpg
# 11           IMG_0257 (1).JPG
# 12        20230816_084203.jpg
# 13  IMG_20230815_120159~2.jpg
# 14        20230815_113141.jpg
# 15               IMG_0468.JPG
# 16               IMG_0291.JPG
# 17          healthy (119).jpg
# 18    IMG_20230815_112257.jpg
# 19               DSC_0499.JPG
# 20        20230815_121818.jpg
# 21                  97933.jpg
# 22           Healthy (76).JPG
# 23        20230712_154128.jpg
# 24        20230712_144547.jpg
# 25               IMG_0219.JPG
# 26        20230712_154637.jpg
# 27      Late_Blight (751).jpg
# 28          IMG_9419_aug1.jpg
# 29               IMG_4785.JPG
#
#                                                  path      true_label  \
# 0   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 1   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 2   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 3   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 4   /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
# 5   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 6   /kaggle/input/datasets/kevinvichicela/dataset1...         healthy
# 7   /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
# 8   /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 9   /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
# 10  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 11  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 12  /kaggle/input/datasets/kevinvichicela/dataset1...        nematode
# 13  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 14  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 15  /kaggle/input/datasets/kevinvichicela/dataset1...  leafroll_virus
# 16  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 17  /kaggle/input/datasets/kevinvichicela/dataset1...         healthy
# 18  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 19  /kaggle/input/datasets/kevinvichicela/dataset1...  leafroll_virus
# 20  /kaggle/input/datasets/kevinvichicela/dataset1...  leafroll_virus
# 21  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 22  /kaggle/input/datasets/kevinvichicela/dataset1...         healthy
# 23  /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
# 24  /kaggle/input/datasets/kevinvichicela/dataset1...            pest
# 25  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 26  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
# 27  /kaggle/input/datasets/kevinvichicela/dataset1...     late_blight
# 28  /kaggle/input/datasets/kevinvichicela/dataset1...         healthy
# 29  /kaggle/input/datasets/kevinvichicela/dataset1...    early_blight
#
#       pred_label  confidence  correct
# 0        healthy    0.993307    False
# 1           pest    0.991614    False
# 2           pest    0.987184    False
# 3           pest    0.983261    False
# 4        healthy    0.976881    False
# 5    late_blight    0.923915    False
# 6           pest    0.918458    False
# 7   early_blight    0.912420    False
# 8           pest    0.907312    False
# 9           pest    0.898475    False
# 10          pest    0.889241    False
# 11          pest    0.876512    False
# 12          pest    0.852367    False
# 13          pest    0.838805    False
# 14          pest    0.823825    False
# 15  mosaic_virus    0.805558    False
# 16          pest    0.804566    False
# 17          pest    0.803405    False
# 18          pest    0.802963    False
# 19  mosaic_virus    0.799538    False
# 20  mosaic_virus    0.797571    False
# 21          pest    0.777518    False
# 22   late_blight    0.765604    False
# 23          pest    0.761052    False
# 24   late_blight    0.752520    False
# 25          pest    0.751614    False
# 26   late_blight    0.744238    False
# 27  early_blight    0.743069    False
# 28          pest    0.733119    False
# 29   late_blight    0.708842    False
# CSV exportados:
#   - /kaggle/working/keras_test_predictions.csv
#   - /kaggle/working/keras_test_errors.csv

# %% [markdown]
# ## 12. Exportación a TFLite (int8)
# Cuantización post-entrenamiento. Reduce el modelo a ~14–25 MB para el APK.

# %%
# Dataset representativo para calibración int8 (100 imágenes de val)
def representative_dataset():
    count = 0
    for img_batch, _ in val_ds:
        for img in img_batch:
            yield [tf.expand_dims(img, 0)]
            count += 1
            if count >= 100:
                return

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type  = tf.uint8
converter.inference_output_type = tf.uint8

# Guardar el modelo base .tflite
tflite_model = converter.convert()
tflite_path = OUTPUT_DIR / 'potato_classifier.tflite'
tflite_path.write_bytes(tflite_model)

# Guardar las etiquetas aparte (ya que no se pueden incrustar directamente aquí)
labels_path = OUTPUT_DIR / 'labels.txt'
with open(labels_path, 'w') as f:
    f.write('\n'.join(classes))

size_mb = tflite_path.stat().st_size / 1_048_576
print(f'Modelo TFLite guardado: {tflite_path}')
print(f'Etiquetas guardadas en: {labels_path}')
print(f'Tamaño del modelo: {size_mb:.2f} MB')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp_luf7btl/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_luf7btl/assets
# Saved artifact at '/tmp/tmp_luf7btl'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   140056284676368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284683856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284686352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284685776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284685008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284683664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284686544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284687312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284686928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284684048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284685968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284688464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284688656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284685584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284685392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284689232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284691344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284691536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284690384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284689808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284688272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284692112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284690576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284691152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284689616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284690192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978164688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978165648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284692304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140056284691728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978165456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978164496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978164304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978164880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978166608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978166032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978166224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978166416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978165264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978167568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978167952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978168144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978167184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978167760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978168720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978169104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978169296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978168336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978168912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978169872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978167376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978169488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978169680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978166800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978170832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978170256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978170448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978170640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978166992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978171792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978171216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978171408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978171600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978168528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978172752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978172176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978172368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978172560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978170064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978173712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978173136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978173328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978173520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978171024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978174672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978174096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978174288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978174480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978171984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978175632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978175056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978175248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978175440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978172944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978176592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978176016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978176208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978176400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978173904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978177552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978176976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978177168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978177360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978174864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978178512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978177936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978178128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978178320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978175824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978179472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978178896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978179088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978179856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978176784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978180432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978179280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978180048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978177744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978180240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978179664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978178704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978853968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978854160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978853392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978852624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978853776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978853584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978853200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978855120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978854544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978854736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978854928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978852432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978856080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978855504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978855696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978855888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978857040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978856464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978856656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978856848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978854352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978858000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978857424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978857616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978857808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978855312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978858960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978858384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978858576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978858768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978856272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978859920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978859344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978859536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978859728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978857232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978860880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978860304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978860496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978860688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978858192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978861840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978861264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978861456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978861648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978859152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978862800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978862224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978862416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978862608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978860112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978863760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978863184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978863376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978863568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978861072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978864720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978864144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978864336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978864528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978862032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978865680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978865104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978865296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978865488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978862992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978866640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978866064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978866256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978866448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978863952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978867600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978867024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978867216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978867984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978864912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978868560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978867408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978868176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978865872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978868368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978867792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140055978866832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848308816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848309008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848308240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848307664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848307472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848308624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848308432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848308048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848309968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848309392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848309584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848309776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848307280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848310928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848310352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848310544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848310736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848307856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848311888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848311312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848311504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848311696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848309200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848312848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848312272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848312464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848312656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848310160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848313808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848313232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848313424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848313616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848311120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848314768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848314192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848314576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848312080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848315728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848315152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848315344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848315536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848313040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848316688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848316112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848316304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848316496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848314000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848317648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848317072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848317264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848317456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848314960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848318608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848318032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848318224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848318416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848315920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848319568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848318992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848319376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848320528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848320720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140054848321104: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1776145524.098314      55 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1776145524.098349      55 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1776145524.233871      55 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Modelo TFLite guardado: /kaggle/working/potato_classifier.tflite
# Etiquetas guardadas en: /kaggle/working/labels.txt
# Tamaño del modelo: 2.59 MB
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %%
from sklearn.metrics import accuracy_score

# Cargar el modelo TFLite exportado
interpreter = tf.lite.Interpreter(model_path=str(tflite_path))
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

in_scale, in_zero_point = input_details['quantization']
out_scale, out_zero_point = output_details['quantization']

print('Entrada TFLite:', input_details['dtype'], input_details['shape'], input_details['quantization'])
print('Salida TFLite :', output_details['dtype'], output_details['shape'], output_details['quantization'])


def run_tflite_int8_single(img_float_m1_1):
    """
    img_float_m1_1: np.ndarray [H,W,3] normalizada en [-1, 1]
    Retorna probs float32 des-cuantizadas.
    """
    x = np.expand_dims(img_float_m1_1, axis=0).astype(np.float32)

    # Cuantizar entrada float -> uint8 usando parametros del tensor de entrada
    if in_scale > 0:
        x_q = np.round(x / in_scale + in_zero_point)
    else:
        x_q = x
    x_q = np.clip(x_q, 0, 255).astype(np.uint8)

    interpreter.set_tensor(input_details['index'], x_q)
    interpreter.invoke()
    y_q = interpreter.get_tensor(output_details['index'])

    # Des-cuantizar salida uint8 -> float
    if out_scale > 0:
        y = (y_q.astype(np.float32) - out_zero_point) * out_scale
    else:
        y = y_q.astype(np.float32)

    return y[0]


# Evaluacion del TFLite en el mismo test set
y_true_tflite, y_pred_tflite = [], []
for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _ = load_and_preprocess(path, true_idx, augment=False)
    probs = run_tflite_int8_single(arr)
    pred_idx = int(np.argmax(probs))

    y_true_tflite.append(true_idx)
    y_pred_tflite.append(pred_idx)

acc_tflite = accuracy_score(y_true_tflite, y_pred_tflite)

# Accuracy Keras float ya calculada antes (si no existe, la recalculamos rapido)
if 'y_true' in globals() and 'y_pred' in globals() and len(y_true) == len(y_pred):
    acc_keras = accuracy_score(y_true, y_pred)
else:
    y_true_keras, y_pred_keras = [], []
    for batch_imgs, batch_labels in test_ds:
        preds = model.predict(batch_imgs, verbose=0)
        y_pred_keras.extend(np.argmax(preds, axis=1))
        y_true_keras.extend(batch_labels.numpy())
    acc_keras = accuracy_score(y_true_keras, y_pred_keras)

print('\n' + '=' * 65)
print('COMPARACION DE ACCURACY EN TEST')
print('=' * 65)
print(f'Keras (float32): {acc_keras:.4f}')
print(f'TFLite (int8) : {acc_tflite:.4f}')
print(f'Delta (int8 - float): {acc_tflite - acc_keras:+.4f}')
print('=' * 65)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Entrada TFLite: <class 'numpy.uint8'> [  1 224 224   3] (0.007843137718737125, 127)
# Salida TFLite : <class 'numpy.uint8'> [1 7] (0.00390625, 0)
#
# =================================================================
# COMPARACION DE ACCURACY EN TEST
# =================================================================
# Keras (float32): 0.9552
# TFLite (int8) : 0.9552
# Delta (int8 - float): +0.0000
# =================================================================

# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# -----------------------------
# 1) Reporte de clasificacion
# -----------------------------
report_dict = classification_report(
    y_true_tflite,
    y_pred_tflite,
    target_names=classes,
    digits=4,
    output_dict=True,
    zero_division=0
)

# Tabla por clase
rows = []
for cls in classes:
    rows.append({
        'clase': cls,
        'precision': report_dict[cls]['precision'],
        'recall': report_dict[cls]['recall'],
        'f1-score': report_dict[cls]['f1-score'],
        'support': int(report_dict[cls]['support'])
    })

df_cls = pd.DataFrame(rows)

# Tabla de resumen
df_summary = pd.DataFrame([
    {
        'metrica': 'accuracy',
        'valor': float(report_dict['accuracy'])
    },
    {
        'metrica': 'macro avg precision',
        'valor': float(report_dict['macro avg']['precision'])
    },
    {
        'metrica': 'macro avg recall',
        'valor': float(report_dict['macro avg']['recall'])
    },
    {
        'metrica': 'macro avg f1-score',
        'valor': float(report_dict['macro avg']['f1-score'])
    },
    {
        'metrica': 'weighted avg precision',
        'valor': float(report_dict['weighted avg']['precision'])
    },
    {
        'metrica': 'weighted avg recall',
        'valor': float(report_dict['weighted avg']['recall'])
    },
    {
        'metrica': 'weighted avg f1-score',
        'valor': float(report_dict['weighted avg']['f1-score'])
    }
])

print('=' * 70)
print('REPORTE TFLITE (INT8) - LISTO PARA TESIS')
print('=' * 70)
print('\nMetricas globales:')
display(df_summary)
print('\nMetricas por clase:')
display(df_cls)

# -----------------------------
# 2) Matriz de confusion
# -----------------------------
cm_tflite = confusion_matrix(y_true_tflite, y_pred_tflite)

fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_tflite, display_labels=classes)
disp.plot(ax=ax, colorbar=True, cmap='Blues', xticks_rotation=35)
ax.set_title('Matriz de confusion - Modelo TFLite int8 (Test)', fontsize=12)
plt.tight_layout()

cm_img_path = OUTPUT_DIR / 'confusion_matrix_tflite.png'
plt.savefig(cm_img_path, dpi=160, bbox_inches='tight')
plt.show()

# -----------------------------
# 3) Guardar tablas para tesis
# -----------------------------
cls_csv_path = OUTPUT_DIR / 'tflite_report_per_class.csv'
sum_csv_path = OUTPUT_DIR / 'tflite_report_summary.csv'

# Redondeo para reporte
df_cls_out = df_cls.copy()
df_cls_out[['precision', 'recall', 'f1-score']] = df_cls_out[['precision', 'recall', 'f1-score']].round(4)
df_summary_out = df_summary.copy()
df_summary_out['valor'] = df_summary_out['valor'].round(4)

df_cls_out.to_csv(cls_csv_path, index=False, encoding='utf-8-sig')
df_summary_out.to_csv(sum_csv_path, index=False, encoding='utf-8-sig')

print('\nArchivos exportados:')
print(f'  - {cls_csv_path}')
print(f'  - {sum_csv_path}')
print(f'  - {cm_img_path}')
# Out:
# ======================================================================
# REPORTE TFLITE (INT8) - LISTO PARA TESIS
# ======================================================================
#
# Metricas globales:
#                   metrica     valor
# 0                accuracy  0.955172
# 1     macro avg precision  0.948175
# 2        macro avg recall  0.963923
# 3      macro avg f1-score  0.954526
# 4  weighted avg precision  0.958877
# 5     weighted avg recall  0.955172
# 6   weighted avg f1-score  0.955980
# Metricas por clase:
#             clase  precision    recall  f1-score  support
# 0    early_blight   0.974419  0.937360  0.955530      447
# 1         healthy   0.961538  0.956284  0.958904      183
# 2     late_blight   0.980926  0.949868  0.965147      379
# 3  leafroll_virus   0.988636  0.945652  0.966667       92
# 4    mosaic_virus   0.951923  0.990000  0.970588      100
# 5        nematode   0.983607  0.991736  0.987654      121
# 6            pest   0.796178  0.976562  0.877193      128
# Archivos exportados:
#   - /kaggle/working/tflite_report_per_class.csv
#   - /kaggle/working/tflite_report_summary.csv
#   - /kaggle/working/confusion_matrix_tflite.png

# %% [markdown]
# ## 13. Generación de Grad-CAM estáticos por clase
# Se calcula el mapa de activación de la última capa conv de MobileNetV2 para una imagen
# representativa de cada clase. Estos mapas se empaquetan en el APK como recursos estáticos —
# latencia extra en inferencia: 0 ms.

# %%
import matplotlib as mpl
import numpy as np
import matplotlib as mpl
from PIL import Image

last_conv_layer = None
for layer in reversed(base_model.layers):
    if isinstance(layer, tf.keras.layers.Conv2D):
        last_conv_layer = layer
        break

if last_conv_layer is None:
    raise ValueError("No se encontró ninguna capa Conv2D en base_model")

print("Usando capa:", last_conv_layer.name)
print("Output shape:", last_conv_layer.output.shape)

# Submodelo interno: base_model.input → (base_model.output, conv_outputs)
# Evita el problema de Graph disconnected al no cruzar el límite base→model
base_grad_model = tf.keras.Model(
    inputs=base_model.inputs,
    outputs=[base_model.output, last_conv_layer.output]
)

# Capas superiores del modelo principal (fuera de la base)
gap_layer     = model.get_layer('global_average_pooling2d')
dropout_layer = model.get_layer('dropout')
dense_layer   = model.get_layer('dense')

# Verificación
print("\nVerificación base_grad_model:")
print("  Input shape :", base_grad_model.input_shape)
print("  Output[0]   :", base_grad_model.output[0].shape, "← base output")
print("  Output[1]   :", base_grad_model.output[1].shape, "← conv activations")


def compute_gradcam(img_array: np.ndarray, class_idx: int) -> np.ndarray:
    """Retorna heatmap normalizado [0,1] del tamaño IMG_SIZE×IMG_SIZE."""
    img_tensor = tf.cast(tf.expand_dims(img_array, 0), tf.float32)

    with tf.GradientTape() as tape:
        base_out, conv_outputs = base_grad_model(img_tensor, training=False)
        tape.watch(conv_outputs)
        # Reconstruir el forward pass de las capas superiores
        x      = gap_layer(base_out)
        x      = dropout_layer(x, training=False)
        preds  = dense_layer(x)
        class_score = preds[:, class_idx]

    grads = tape.gradient(class_score, conv_outputs)

    if grads is None:
        raise ValueError(
            f"Gradientes None para clase {class_idx}. "
            "Verificar conexión de base_grad_model."
        )

    weights = tf.reduce_mean(grads, axis=(0, 1, 2))
    cam = tf.reduce_sum(tf.multiply(weights, conv_outputs[0]), axis=-1)
    cam = tf.maximum(cam, 0)
    cam_np = cam.numpy()
    cam_max = np.max(cam_np)
    cam_min = np.min(cam_np)

    
    if (cam_max - cam_min) > 1e-8:
      
        cam_np = (cam_np - cam_min) / (cam_max - cam_min)
    else:
        
        cam_np = np.zeros_like(cam_np)

    cam_img = Image.fromarray((cam_np * 255).astype(np.uint8))
    cam_img = cam_img.resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR)
    
    return np.array(cam_img) / 255.0


def overlay_heatmap(original_arr: np.ndarray,
                    heatmap: np.ndarray,
                    color_alpha: float = 0.6) -> np.ndarray: # CAMBIADO DE alpha A color_alpha
    """Superpone el heatmap coloreado (jet) sobre la imagen original."""

    orig_uint8 = ((original_arr + 1.0) * 127.5).astype(np.uint8)
    orig_img = Image.fromarray(orig_uint8).convert("RGBA")
    
    colormap = mpl.colormaps['jet']
    heatmap_rgb = (colormap(heatmap)[:, :, :3] * 255).astype(np.uint8)
    
    dynamic_alpha = np.power(heatmap, 1.5) 
    
    dynamic_alpha = dynamic_alpha * color_alpha
    
    alpha_mask_uint8 = (dynamic_alpha * 255).astype(np.uint8)
    
    rgba_heatmap_np = np.dstack((heatmap_rgb, alpha_mask_uint8))
    heatmap_img = Image.fromarray(rgba_heatmap_np, "RGBA")
    
    blended_img = Image.alpha_composite(orig_img, heatmap_img)
    
    return np.array(blended_img.convert("RGB"))

print('\nFunciones Grad-CAM listas.')
# Out:
# Usando capa: Conv_1
# Output shape: (None, 7, 7, 1280)
#
# Verificación base_grad_model:
#   Input shape : (None, 224, 224, 3)
#   Output[0]   : (None, 7, 7, 1280) ← base output
#   Output[1]   : (None, 7, 7, 1280) ← conv activations
#
# Funciones Grad-CAM listas.

# %%
# Buscar las TOP 10 imágenes de test con mayor confianza por clase
TOP_N = 5
gradcam_dir = OUTPUT_DIR / 'gradcam_static'
gradcam_dir.mkdir(exist_ok=True)

# Ahora guardamos una lista de resultados por clase, no solo uno
top_per_class = {i: [] for i in range(NUM_CLASSES)}

print("Analizando imágenes y recolectando candidatos...")
for path, true_label in zip(test_paths, test_labels):
    true_idx = class_to_idx[true_label]
    arr, _   = load_and_preprocess(path, true_idx, augment=False)
    preds    = model.predict(np.expand_dims(arr, 0), verbose=0)[0]
    pred_idx = np.argmax(preds)
    conf     = float(preds[pred_idx])
    
    # Solo candidatos correctamente clasificados y evitando la saturación del 1.0 absoluto
    if pred_idx == true_idx and conf < 0.99:
        top_per_class[true_idx].append({'conf': conf, 'path': path, 'arr': arr})

# Generar y guardar los Grad-CAM en la carpeta
print(f"\nGenerando y guardando las mejores {TOP_N} imágenes por clase...")
for cls_idx, cls_name in enumerate(classes):
    
    # Ordenamos todas las imágenes de esta clase de mayor a menor confianza
    # y nos quedamos solo con la cantidad definida en TOP_N
    candidates = sorted(top_per_class[cls_idx], key=lambda x: x['conf'], reverse=True)[:TOP_N]
    
    if not candidates:
        print(f'  AVISO: no se encontraron imágenes para {cls_name}')
        continue
        
    print(f"  -> Guardando {len(candidates)} opciones para {cls_name}...")
    
    for rank, info in enumerate(candidates):
        arr     = info['arr']
        heatmap = compute_gradcam(arr, cls_idx)
        overlay = overlay_heatmap(arr, heatmap)

        # Guardar directamente la imagen procesada con un nombre descriptivo
        # Ejemplo: gradcam_late_blight_top1_conf0.985.jpg
        filename = f'gradcam_{cls_name}_top{rank+1}_conf{info["conf"]:.3f}.jpg'
        out_path = gradcam_dir / filename
        Image.fromarray(overlay).save(str(out_path), quality=90)

print(f'\n¡Proceso terminado!')
print(f'Ve al panel derecho de Kaggle, entra a la carpeta: {gradcam_dir}')
print('Ahí tendrás todas las imágenes listas para descargar y elegir la mejor.')
# Out:
# Analizando imágenes y recolectando candidatos...
#
# Generando y guardando las mejores 5 imágenes por clase...
#   -> Guardando 5 opciones para early_blight...
#   -> Guardando 5 opciones para healthy...
#   -> Guardando 5 opciones para late_blight...
#   -> Guardando 5 opciones para leafroll_virus...
#   -> Guardando 5 opciones para mosaic_virus...
#   -> Guardando 5 opciones para nematode...
#   -> Guardando 5 opciones para pest...
#
# ¡Proceso terminado!
# Ve al panel derecho de Kaggle, entra a la carpeta: /kaggle/working/gradcam_static
# Ahí tendrás todas las imágenes listas para descargar y elegir la mejor.

# %% [markdown]
# ## 14. Resumen de archivos generados

# %%
print('=' * 55)
print('ARCHIVOS GENERADOS')
print('=' * 55)

outputs = [
    OUTPUT_DIR / 'potato_classifier.tflite',
    OUTPUT_DIR / 'best_phase2.keras',
    OUTPUT_DIR / 'training_curves.png',
    OUTPUT_DIR / 'confusion_matrix.png',
    OUTPUT_DIR / 'gradcam_all_classes.png',
]
outputs += list(gradcam_dir.glob('*.jpg'))

for f in outputs:
    if Path(f).exists():
        size = Path(f).stat().st_size / 1024
        print(f'  {Path(f).name:<40} {size:>8.1f} KB')
    else:
        print(f'  {Path(f).name:<40}  NO ENCONTRADO')

print('=' * 55)
print()
print('Para Android necesitas:')
print('  1. potato_classifier.tflite  → /assets/ en el proyecto Android')
print('  2. gradcam_*.jpg             → /res/drawable/ en el proyecto Android')
print()
print('class_to_idx (para el clasificador en Kotlin):')
for cls, idx in class_to_idx.items():
    print(f'  {idx}: "{cls}"')
# Out:
# =======================================================
# ARCHIVOS GENERADOS
# =======================================================
#   potato_classifier.tflite                   2654.9 KB
#   best_phase2.keras                         24080.5 KB
#   training_curves.png                          92.5 KB
#   confusion_matrix.png                         88.3 KB
#   gradcam_all_classes.png                   NO ENCONTRADO
#   gradcam_healthy_top1_conf0.990.jpg           10.0 KB
#   gradcam_healthy_top4_conf0.987.jpg           19.4 KB
#   gradcam_nematode_top3_conf0.985.jpg          15.2 KB
#   gradcam_leafroll_virus_top5_conf0.972.jpg      9.2 KB
#   gradcam_leafroll_virus_top4_conf0.979.jpg      5.4 KB
#   gradcam_pest_top3_conf0.989.jpg              13.0 KB
#   gradcam_early_blight_top3_conf0.989.jpg      11.4 KB
#   gradcam_late_blight_top4_conf0.989.jpg       15.8 KB
#   gradcam_healthy_top5_conf0.987.jpg           15.5 KB
#   gradcam_mosaic_virus_top2_conf0.988.jpg      20.9 KB
#   gradcam_nematode_top2_conf0.986.jpg          13.7 KB
#   gradcam_late_blight_top2_conf0.990.jpg       17.2 KB
#   gradcam_early_blight_top2_conf0.990.jpg      19.0 KB
#   gradcam_pest_top5_conf0.988.jpg              18.4 KB
#   gradcam_late_blight_top1_conf0.990.jpg       21.3 KB
#   gradcam_nematode_top4_conf0.984.jpg          15.3 KB
#   gradcam_nematode_top5_conf0.983.jpg          14.6 KB
#   gradcam_nematode_top1_conf0.989.jpg          16.3 KB
#   gradcam_leafroll_virus_top3_conf0.983.jpg     11.1 KB
#   gradcam_late_blight_top3_conf0.989.jpg       17.8 KB
#   gradcam_leafroll_virus_top1_conf0.988.jpg      6.9 KB
#   gradcam_leafroll_virus_top2_conf0.985.jpg      7.6 KB
#   gradcam_mosaic_virus_top1_conf0.989.jpg      13.2 KB
#   gradcam_healthy_top2_conf0.988.jpg           18.2 KB
#   gradcam_early_blight_top4_conf0.989.jpg      12.2 KB
#   gradcam_late_blight_top5_conf0.989.jpg       21.4 KB
#   gradcam_mosaic_virus_top3_conf0.986.jpg      11.3 KB
#   gradcam_mosaic_virus_top4_conf0.951.jpg       7.7 KB
#   gradcam_pest_top1_conf0.990.jpg              13.3 KB
#   gradcam_early_blight_top1_conf0.990.jpg      20.1 KB
#   gradcam_early_blight_top5_conf0.988.jpg       9.7 KB
#   gradcam_healthy_top3_conf0.988.jpg           14.6 KB
#   gradcam_mosaic_virus_top5_conf0.939.jpg      14.0 KB
#   gradcam_pest_top2_conf0.989.jpg              14.5 KB
#   gradcam_pest_top4_conf0.988.jpg              16.2 KB
# =======================================================
#
# Para Android necesitas:
#   1. potato_classifier.tflite  → /assets/ en el proyecto Android
#   2. gradcam_*.jpg             → /res/drawable/ en el proyecto Android
#
# class_to_idx (para el clasificador en Kotlin):
#   0: "early_blight"
#   1: "healthy"
#   2: "late_blight"
#   3: "leafroll_virus"
#   4: "mosaic_virus"
#   5: "nematode"
#   6: "pest"
